# %%
import pandas as pd

# %%
df = pd.read_csv('/content/fashion_products.csv')

# %%
df.head()
# Out:
#    User ID  Product ID Product Name   Brand         Category  Price    Rating  \
# 0       19           1        Dress  Adidas    Men's Fashion     40  1.043159
# 1       97           2        Shoes     H&M  Women's Fashion     82  4.026416
# 2       25           3        Dress  Adidas  Women's Fashion     44  3.337938
# 3       57           4        Shoes    Zara    Men's Fashion     23  1.049523
# 4       79           5      T-shirt  Adidas    Men's Fashion     79  4.302773
#
#     Color Size
# 0   Black   XL
# 1   Black    L
# 2  Yellow   XL
# 3   White    S
# 4   Black    M

# %%
df.tail()
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 998        8         999      T-shirt    Zara  Women's Fashion     68
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating  Color Size
# 995  1.620081  Black    M
# 996  1.544464  Green    L
# 997  3.961913  White    L
# 998  3.089722   Blue    S
# 999  3.093553  White    L

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User ID       1000 non-null   int64
#  1   Product ID    1000 non-null   int64
#  2   Product Name  1000 non-null   object
#  3   Brand         1000 non-null   object
#  4   Category      1000 non-null   object
#  5   Price         1000 non-null   int64
#  6   Rating        1000 non-null   float64
#  7   Color         1000 non-null   object
#  8   Size          1000 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#           User ID   Product ID        Price       Rating
# count  1000.00000  1000.000000  1000.000000  1000.000000
# mean     50.41900   500.500000    55.785000     2.993135
# std      28.78131   288.819436    26.291748     1.153185
# min       1.00000     1.000000    10.000000     1.000967
# 25%      26.00000   250.750000    33.000000     1.992786
# 50%      50.00000   500.500000    57.000000     2.984003
# 75%      75.00000   750.250000    78.250000     3.985084
# max     100.00000  1000.000000   100.000000     4.987964

# %%
df.columns
# Out:
# Index(['User ID', 'Product ID', 'Product Name', 'Brand', 'Category', 'Price',
#        'Rating', 'Color', 'Size'],
#       dtype='object')

# %%
df.shape[0]
# Out:
# 1000

# %%
df.shape[1]
# Out:
# 9

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.isnull().sum()
# Out:
# User ID         0
# Product ID      0
# Product Name    0
# Brand           0
# Category        0
# Price           0
# Rating          0
# Color           0
# Size            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Product Name']
# Out:
# 0        Dress
# 1        Shoes
# 2        Dress
# 3        Shoes
# 4      T-shirt
#         ...
# 995      Shoes
# 996    Sweater
# 997    Sweater
# 998    T-shirt
# 999      Shoes
# Name: Product Name, Length: 1000, dtype: object

# %%
df[['Brand', 'Category']]
# Out:
#       Brand         Category
# 0    Adidas    Men's Fashion
# 1       H&M  Women's Fashion
# 2    Adidas  Women's Fashion
# 3      Zara    Men's Fashion
# 4    Adidas    Men's Fashion
# ..      ...              ...
# 995    Zara  Women's Fashion
# 996    Nike    Kids' Fashion
# 997    Zara    Men's Fashion
# 998    Zara  Women's Fashion
# 999  Adidas  Women's Fashion
#
# [1000 rows x 2 columns]

# %%
df['Color']
# Out:
# 0       Black
# 1       Black
# 2      Yellow
# 3       White
# 4       Black
#         ...
# 995     Black
# 996     Green
# 997     White
# 998      Blue
# 999     White
# Name: Color, Length: 1000, dtype: object

# %%
df[df['Product Name'] == 'Shoes']
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 1         97           2        Shoes     H&M  Women's Fashion     82
# 3         57           4        Shoes    Zara    Men's Fashion     23
# 14        31          15        Shoes    Zara    Men's Fashion     54
# 18        84          19        Shoes   Gucci  Women's Fashion     54
# 27        87          28        Shoes    Zara  Women's Fashion     32
# ..       ...         ...          ...     ...              ...    ...
# 986       77         987        Shoes     H&M  Women's Fashion     42
# 990       60         991        Shoes    Nike    Kids' Fashion     25
# 992       89         993        Shoes     H&M  Women's Fashion     33
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 1    4.026416   Black    L
# 3    1.049523   White    S
# 14   3.670412  Yellow    M
# ...

# %%
df['Product Name'] == 'Shoes'
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Product Name, Length: 1000, dtype: bool

# %%
df[df['Color'] == 'Yellow']
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 2         25           3        Dress  Adidas  Women's Fashion     44
# 5         98           6        Dress  Adidas    Men's Fashion     47
# 11        87          12      Sweater   Gucci    Kids' Fashion     91
# 14        31          15        Shoes    Zara    Men's Fashion     54
# 20        87          21        Jeans     H&M    Men's Fashion     56
# ..       ...         ...          ...     ...              ...    ...
# 947       37         948      Sweater   Gucci  Women's Fashion     83
# 958      100         959      Sweater     H&M    Kids' Fashion     45
# 964       21         965      Sweater    Nike    Men's Fashion     55
# 989       51         990      T-shirt   Gucci    Men's Fashion     16
# 992       89         993        Shoes     H&M  Women's Fashion     33
#
#        Rating   Color Size
# 2    3.337938  Yellow   XL
# 5    1.379566  Yellow    L
# 11   2.699736  Yellow    M
# ...

# %%
df.loc[(df['Rating'] == 2.609587) & (df['Size'] == 'XL')]
# Out:
# Empty DataFrame
# Columns: [User ID, Product ID, Product Name, Brand, Category, Price, Rating, Color, Size]
# Index: []

# %%
df.loc[(df['Product Name'] == 'Sweater') & (df['Category'] == "Men's Fashion")]
# Out:
#      User ID  Product ID Product Name  Brand       Category  Price    Rating  \
# 8         96           9      Sweater    H&M  Men's Fashion     53  4.466182
# 85         4          86      Sweater   Zara  Men's Fashion     50  3.276222
# 106       19         107      Sweater   Zara  Men's Fashion     23  3.321347
# 107       80         108      Sweater  Gucci  Men's Fashion     13  4.278043
# 123       65         124      Sweater    H&M  Men's Fashion     62  1.090813
# ..       ...         ...          ...    ...            ...    ...       ...
# 935       72         936      Sweater  Gucci  Men's Fashion     33  1.881447
# 955       39         956      Sweater    H&M  Men's Fashion     88  3.912169
# 964       21         965      Sweater   Nike  Men's Fashion     55  3.504892
# 993       59         994      Sweater    H&M  Men's Fashion     89  4.440833
# 997        9         998      Sweater   Zara  Men's Fashion     47  3.961913
#
#       Color Size
# 8     Green   XL
# ...

# %%
df.loc[(df['User ID'] == 19) & (df['Size'] == 'L')]
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 83        19          84      Sweater  Adidas  Women's Fashion     42
# 106       19         107      Sweater    Zara    Men's Fashion     23
#
#        Rating Color Size
# 83   2.560174   Red    L
# 106  3.321347   Red    L

# %%
df.iloc[10:30, 2:8]
# Out:
#    Product Name   Brand         Category  Price    Rating   Color
# 10      T-shirt  Adidas    Men's Fashion     51  1.160988     Red
# 11      Sweater   Gucci    Kids' Fashion     91  2.699736  Yellow
# 12        Jeans    Nike    Kids' Fashion     35  1.601194     Red
# 13        Dress    Zara  Women's Fashion     34  2.921004   White
# 14        Shoes    Zara    Men's Fashion     54  3.670412  Yellow
# 15        Dress  Adidas  Women's Fashion     27  1.422716    Blue
# 16        Dress   Gucci  Women's Fashion     75  1.480632    Blue
# 17        Jeans   Gucci  Women's Fashion     73  4.498245     Red
# 18        Shoes   Gucci  Women's Fashion     54  3.278341   White
# 19        Dress   Gucci    Men's Fashion     53  3.785245   Green
# 20        Jeans     H&M    Men's Fashion     56  2.609587  Yellow
# 21        Jeans   Gucci  Women's Fashion     89  4.568632   Green
# 22        Jeans    Zara    Kids' Fashion     91  4.072725  Yellow
# ...

# %%
df.hist(figsize = (20,12), bins = 100)
# Out:
# array([[<Axes: title={'center': 'User ID'}>,
#         <Axes: title={'center': 'Product ID'}>],
#        [<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Rating'}>]], dtype=object)
