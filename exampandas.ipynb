# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df.shape[0]
# Out:
# 301

# %%
df.shape[1]
# Out:
# 9

# %%
df.shape
# Out:
# (301, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.isnull()
# Out:
#      Car_Name   Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       False  False          False          False       False      False
# 1       False  False          False          False       False      False
# 2       False  False          False          False       False      False
# 3       False  False          False          False       False      False
# 4       False  False          False          False       False      False
# ..        ...    ...            ...            ...         ...        ...
# 296     False  False          False          False       False      False
# 297     False  False          False          False       False      False
# 298     False  False          False          False       False      False
# 299     False  False          False          False       False      False
# 300     False  False          False          False       False      False
#
#      Seller_Type  Transmission  Owner
# 0          False         False  False
# ...

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df['Present_Price']
# Out:
# 0       5.59
# 1       9.54
# 2       9.85
# 3       4.15
# 4       6.87
#        ...
# 296    11.60
# 297     5.90
# 298    11.00
# 299    12.50
# 300     5.90
# Name: Present_Price, Length: 301, dtype: float64

# %%
df['Car_Name']
# Out:
# 0         ritz
# 1          sx4
# 2         ciaz
# 3      wagon r
# 4        swift
#         ...
# 296       city
# 297       brio
# 298       city
# 299       city
# 300       brio
# Name: Car_Name, Length: 301, dtype: object

# %%
df['Transmission']
# Out:
# 0      Manual
# 1      Manual
# 2      Manual
# 3      Manual
# 4      Manual
#         ...
# 296    Manual
# 297    Manual
# 298    Manual
# 299    Manual
# 300    Manual
# Name: Transmission, Length: 301, dtype: object

# %%
df.hist (figsize = (20,12), bins = 100)
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Selling_Price'}>],
#        [<Axes: title={'center': 'Present_Price'}>,
#         <Axes: title={'center': 'Kms_Driven'}>],
#        [<Axes: title={'center': 'Owner'}>, <Axes: >]], dtype=object)

# %%
df['Present_Price'].head()
# Out:
# 0    5.59
# 1    9.54
# 2    9.85
# 3    4.15
# 4    6.87
# Name: Present_Price, dtype: float64

# %%
df['Present_Price'].value_counts(dropna = False)
# Out:
# Present_Price
# 9.40     15
# 13.60    13
# 5.70      8
# 4.43      7
# 1.47      7
#          ..
# 18.54     1
# 7.27      1
# 15.04     1
# 10.21     1
# 12.50     1
# Name: count, Length: 147, dtype: int64

# %%
df['Owner'].value_counts(dropna = False).head(10)
# Out:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
df.describe(include= 'object')
# Out:
#        Car_Name Fuel_Type Seller_Type Transmission
# count       301       301         301          301
# unique       98         3           2            2
# top        city    Petrol      Dealer       Manual
# freq         26       239         195          261

# %%
df[df['Car_Name'] == 'model']
# Out:
# Empty DataFrame
# Columns: [Car_Name, Year, Selling_Price, Present_Price, Kms_Driven, Fuel_Type, Seller_Type, Transmission, Owner]
# Index: []

# %%
df = df.dropna()
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df [['Car_Name','Seller_Type']]
# Out:
#     Car_Name Seller_Type
# 0       ritz      Dealer
# 1        sx4      Dealer
# 2       ciaz      Dealer
# 3    wagon r      Dealer
# 4      swift      Dealer
# ..       ...         ...
# 296     city      Dealer
# 297     brio      Dealer
# 298     city      Dealer
# 299     city      Dealer
# 300     brio      Dealer
#
# [301 rows x 2 columns]

# %%
df.loc[df['Seller_Type'] == True]
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.loc[(df['Car_Name']=='city') & (df['Transmission']=='Manual')]
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.loc[(df['Car_Name']=='city') | (df['Transmission']=='Manual') & (df['Selling_Price'] > 5)]
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df1 = df.copy()
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df1 = df.reset_index(drop =True)
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df1 = df.reset_index(drop = True, inplace = True)
df1

# %%
df = df.copy()
df.loc[df['Kms_Driven'] > 200000, ['Transmission']] = 'Manual'
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.groupby('Selling_Price').mean(numeric_only=True)
# Out:
#                       Year  Present_Price     Kms_Driven  Owner
# Selling_Price
# 0.10           2006.000000           0.75   92233.000000    0.0
# 0.12           2007.000000           0.58   53000.000000    0.0
# 0.15           2011.000000           0.57   35000.000000    1.0
# 0.16           2010.000000           0.51   33000.000000    0.0
# 0.17           2008.000000           0.52  500000.000000    0.0
# ...                    ...            ...            ...    ...
# 20.75          2016.000000          25.39   29000.000000    0.0
# 23.00          2015.666667          28.87   31666.666667    0.0
# 23.50          2015.000000          35.96   47000.000000    0.0
# 33.00          2017.000000          36.23    6000.000000    0.0
# 35.00          2010.000000          92.60   78000.000000    0.0
#
# [156 rows x 4 columns]

# %%
df.groupby(['Selling_Price', '']).count()
# Out:
#                              Car_Name  Year  Kms_Driven  Fuel_Type  \
# Selling_Price Present_Price
# 0.10          0.75                  1     1           1          1
# 0.12          0.58                  1     1           1          1
# 0.15          0.57                  1     1           1          1
# 0.16          0.51                  1     1           1          1
# 0.17          0.52                  1     1           1          1
# ...                               ...   ...         ...        ...
# 23.00         25.39                 1     1           1          1
#               30.61                 2     2           2          2
# 23.50         35.96                 1     1           1          1
# 33.00         36.23                 1     1           1          1
# 35.00         92.60                 1     1           1          1
#
#                              Seller_Type  Transmission  Owner
# Selling_Price Present_Price
# ...

# %%
plt.bar(df['Present_Price'].value_counts().index, df['Present_Price'].value_counts().values)
plt.xlabel('Present_Price')
plt.ylabel('Count')
plt.title('Present_Price Distribution')
plt.show()

# %%
plt.bar(df['Year'].value_counts().index, df['Year'].value_counts().values) # Switched the order of index and values
plt.title('YEARS')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
plt.barh(df['Year'].value_counts().index, df['Year'].value_counts().values) # Switched the order of index and values
plt.title('YEARS')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
df.insert(2,'Model', ['Audi'] * len(df), True)
print(df)
# Out:
#     Car_Name  Year Model  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014  Audi           3.35           5.59       27000    Petrol
# 1        sx4  2013  Audi           4.75           9.54       43000    Diesel
# 2       ciaz  2017  Audi           7.25           9.85        6900    Petrol
# 3    wagon r  2011  Audi           2.85           4.15        5200    Petrol
# 4      swift  2014  Audi           4.60           6.87       42450    Diesel
# ..       ...   ...   ...            ...            ...         ...       ...
# 296     city  2016  Audi           9.50          11.60       33988    Diesel
# 297     brio  2015  Audi           4.00           5.90       60000    Petrol
# 298     city  2009  Audi           3.35          11.00       87934    Petrol
# 299     city  2017  Audi          11.50          12.50        9000    Diesel
# 300     brio  2016  Audi           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# ...

# %%
df[df.isna().any(axis = 1)]
df
# Out:
#     Car_Name  Year Model  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014  Audi           3.35           5.59       27000    Petrol
# 1        sx4  2013  Audi           4.75           9.54       43000    Diesel
# 2       ciaz  2017  Audi           7.25           9.85        6900    Petrol
# 3    wagon r  2011  Audi           2.85           4.15        5200    Petrol
# 4      swift  2014  Audi           4.60           6.87       42450    Diesel
# ..       ...   ...   ...            ...            ...         ...       ...
# 296     city  2016  Audi           9.50          11.60       33988    Diesel
# 297     brio  2015  Audi           4.00           5.90       60000    Petrol
# 298     city  2009  Audi           3.35          11.00       87934    Petrol
# 299     city  2017  Audi          11.50          12.50        9000    Diesel
# 300     brio  2016  Audi           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# ...

# %%
df.drop(['Transmission'], axis=1)
df
# Out:
#     Car_Name  Year Model  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014  Audi           3.35           5.59       27000    Petrol
# 1        sx4  2013  Audi           4.75           9.54       43000    Diesel
# 2       ciaz  2017  Audi           7.25           9.85        6900    Petrol
# 3    wagon r  2011  Audi           2.85           4.15        5200    Petrol
# 4      swift  2014  Audi           4.60           6.87       42450    Diesel
# ..       ...   ...   ...            ...            ...         ...       ...
# 296     city  2016  Audi           9.50          11.60       33988    Diesel
# 297     brio  2015  Audi           4.00           5.90       60000    Petrol
# 298     city  2009  Audi           3.35          11.00       87934    Petrol
# 299     city  2017  Audi          11.50          12.50        9000    Diesel
# 300     brio  2016  Audi           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission
# ...

# %%
df.iloc[0:4]
# Out:
#   Car_Name  Year Model  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014  Audi           3.35           5.59       27000    Petrol
# 1      sx4  2013  Audi           4.75           9.54       43000    Diesel
# 2     ciaz  2017  Audi           7.25           9.85        6900    Petrol
# 3  wagon r  2011  Audi           2.85           4.15        5200    Petrol
#
#   Seller_Type Transmission
# 0      Dealer       Manual
# 1      Dealer       Manual
# 2      Dealer       Manual
# 3      Dealer       Manual

# %%
df.iloc[:, 0 :2]
# Out:
#     Car_Name  Year
# 0       ritz  2014
# 1        sx4  2013
# 2       ciaz  2017
# 3    wagon r  2011
# 4      swift  2014
# ..       ...   ...
# 296     city  2016
# 297     brio  2015
# 298     city  2009
# 299     city  2017
# 300     brio  2016
#
# [301 rows x 2 columns]

# %%
df.iloc[2,3]
# Out:
# 7.25

# %%
df.iloc[:10]
# Out:
#         Car_Name  Year Model  Selling_Price  Present_Price  Kms_Dri