# %%
import pandas as pd

# %%
df = pd.read_csv('/content/mental-and-substance-use-as-share-of-disease.csv')

# %%
df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                           1.696670
# 1                                           1.734281
# 2                                           1.791189
# 3                                           1.776779
# 4                                           1.712986

# %%
df.tail()
# Out:
#         Entity Code  Year  \
# 6835  Zimbabwe  ZWE  2015
# 6836  Zimbabwe  ZWE  2016
# 6837  Zimbabwe  ZWE  2017
# 6838  Zimbabwe  ZWE  2018
# 6839  Zimbabwe  ZWE  2019
#
#       DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 6835                                           2.193166
# 6836                                           2.279813
# 6837                                           2.364265
# 6838                                           2.472949
# 6839                                           2.525892

# %%
df.isnull().sum()
# Out:
# Entity                                                                                               0
# Code                                                                                               690
# Year                                                                                                 0
# DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Entity                                                                                              object
# Code                                                                                                object
# Year                                                                                                 int64
# DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)    float64
# dtype: object

# %%
df.describe()
# Out:
#               Year  \
# count  6840.000000
# mean   2004.500000
# std       8.656074
# min    1990.000000
# 25%    1997.000000
# 50%    2004.500000
# 75%    2012.000000
# max    2019.000000
#
#        DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# count                                        6840.000000
# mean                                            4.818062
# std                                             2.294029
# min                                             0.215647
# 25%                                             3.006507
# 50%                                             4.679177
# 75%                                             6.387488
# max                                            13.761517

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 4 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   Entity                                                                                           6840 non-null   object
#  1   Code                                                                                             6150 non-null   object
#  2   Year                                                                                             6840 non-null   int64
#  3   DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)  6840 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 213.9+ KB

# %%
df.shape
# Out:
# (6840, 4)

# %%
df = df.fillna(0)
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                              1.696670
# 1                                              1.734281
# 2                                              1.791189
# 3                                              1.776779
# 4                                              1.712986
# ...                                                 ...
# 6835                                           2.193166
# 6836                                           2.279813
# ...

# %%
df.isnull().sum()
# Out:
# Entity                                                                                             0
# Code                                                                                               0
# Year                                                                                               0
# DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)    0
# dtype: int64

# %%
df['Entity']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 6835       Zimbabwe
# 6836       Zimbabwe
# 6837       Zimbabwe
# 6838       Zimbabwe
# 6839       Zimbabwe
# Name: Entity, Length: 6840, dtype: object

# %%
df['Code']
# Out:
# 0       AFG
# 1       AFG
# 2       AFG
# 3       AFG
# 4       AFG
#        ...
# 6835    ZWE
# 6836    ZWE
# 6837    ZWE
# 6838    ZWE
# 6839    ZWE
# Name: Code, Length: 6840, dtype: object

# %%
df[df['Code'] == 'ZWE']
# Out:
#         Entity Code  Year  \
# 6810  Zimbabwe  ZWE  1990
# 6811  Zimbabwe  ZWE  1991
# 6812  Zimbabwe  ZWE  1992
# 6813  Zimbabwe  ZWE  1993
# 6814  Zimbabwe  ZWE  1994
# 6815  Zimbabwe  ZWE  1995
# 6816  Zimbabwe  ZWE  1996
# 6817  Zimbabwe  ZWE  1997
# 6818  Zimbabwe  ZWE  1998
# 6819  Zimbabwe  ZWE  1999
# 6820  Zimbabwe  ZWE  2000
# 6821  Zimbabwe  ZWE  2001
# 6822  Zimbabwe  ZWE  2002
# 6823  Zimbabwe  ZWE  2003
# 6824  Zimbabwe  ZWE  2004
# 6825  Zimbabwe  ZWE  2005
# 6826  Zimbabwe  ZWE  2006
# 6827  Zimbabwe  ZWE  2007
# 6828  Zimbabwe  ZWE  2008
# 6829  Zimbabwe  ZWE  2009
# 6830  Zimbabwe  ZWE  2010
# 6831  Zimbabwe  ZWE  2011
# 6832  Zimbabwe  ZWE  2012
# 6833  Zimbabwe  ZWE  2013
# 6834  Zimbabwe  ZWE  2014
# 6835  Zimbabwe  ZWE  2015
# 6836  Zimbabwe  ZWE  2016
# 6837  Zimbabwe  ZWE  2017
# 6838  Zimbabwe  ZWE  2018
# 6839  Zimbabwe  ZWE  2019
#
#       DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# ...

# %%
df[df['Year'] == 2019]
# Out:
#                               Entity Code  Year  \
# 29                       Afghanistan  AFG  2019
# 59              African Region (WHO)    0  2019
# 89                           Albania  ALB  2019
# 119                          Algeria  DZA  2019
# 149                   American Samoa  ASM  2019
# ...                              ...  ...   ...
# 6719  World Bank Lower Middle Income    0  2019
# 6749  World Bank Upper Middle Income    0  2019
# 6779                           Yemen  YEM  2019
# 6809                          Zambia  ZMB  2019
# 6839                        Zimbabwe  ZWE  2019
#
#       DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 29                                             3.991275
# 59                                             3.069142
# 89                                             5.350385
# 119                                            7.807097
# 149                                            4.384950
# ...

# %%
df.loc[(df['Entity'] == 'Zimbabwe') & (df['Year'] == 2017)]
# Out:
#         Entity Code  Year  \
# 6837  Zimbabwe  ZWE  2017
#
#       DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 6837                                           2.364265

# %%
df.loc[(df['Code'] == 'YEM') & (df['Year'] == 2015)]
# Out:
#      Entity Code  Year  \
# 6775  Yemen  YEM  2015
#
#       DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 6775                                            4.75221

# %%
df.iloc[50:100, 0:2]
# Out:
#                   Entity Code
# 50  African Region (WHO)    0
# 51  African Region (WHO)    0
# 52  African Region (WHO)    0
# 53  African Region (WHO)    0
# 54  African Region (WHO)    0
# 55  African Region (WHO)    0
# 56  African Region (WHO)    0
# 57  African Region (WHO)    0
# 58  African Region (WHO)    0
# 59  African Region (WHO)    0
# 60               Albania  ALB
# 61               Albania  ALB
# 62               Albania  ALB
# 63               Albania  ALB
# 64               Albania  ALB
# 65               Albania  ALB
# 66               Albania  ALB
# 67               Albania  ALB
# 68               Albania  ALB
# 69               Albania  ALB
# 70               Albania  ALB
# 71               Albania  ALB
# 72               Albania  ALB
# 73               Albania  ALB
# 74               Albania  ALB
# 75               Albania  ALB
# 76               Albania  ALB
# 77               Albania  ALB
# 78               Albania  ALB
# 79               Albania  ALB
# ...

# %%
df.hist(figsize=(20,12), bins = 100)
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)'}>]],
#       dtype=object)
