# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Use pd.read_csv to read the CSV file into a DataFrame
health = pd.read_csv('/content/healthcare_dataset.csv')

# %%
health.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#        Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
health.tail()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 62415  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 62416         KYle pEREz   61  Female        AB-           Obesity
# 62417       HEATher WaNG   38  Female         B+      Hypertension
# 62418     JENniFER JOneS   43    Male         O-         Arthritis
# 62419       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 62415        2020-08-16    Joshua Jarvis                Jones-Thompson
# 62416        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 62417        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 62418        2019-05-25   Kimberly Curry      Jackson Todd and Castro,
# 62419        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider      Billing Amount  Room Number Admission Type  \
# ...

# %%
health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62420 entries, 0 to 62419
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                62420 non-null  object
#  1   Age                 62420 non-null  int64
#  2   Gender              62420 non-null  object
#  3   Blood Type          62420 non-null  object
#  4   Medical Condition   62420 non-null  object
#  5   Date of Admission   62420 non-null  object
#  6   Doctor              62420 non-null  object
#  7   Hospital            62420 non-null  object
#  8   Insurance Provider  62420 non-null  object
#  9   Billing Amount      62420 non-null  object
#  10  Room Number         62419 non-null  float64
#  11  Admission Type      62419 non-null  object
#  12  Discharge Date      62419 non-null  object
#  13  Medication          62419 non-null  object
#  14  Test Results        62419 non-null  object
# ...

# %%
health.describe()
# Out:
#                 Age   Room Number
# count  62420.000000  62419.000000
# mean      51.535598    301.157628
# std       19.590104    115.178985
# min       13.000000    101.000000
# 25%       35.000000    202.000000
# 50%       52.000000    302.000000
# 75%       68.000000    400.000000
# max       89.000000    500.000000

# %%
health.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           1
# Admission Type        1
# Discharge Date        1
# Medication            1
# Test Results          1
# dtype: int64

# %%
health.duplicated().sum()
# Out:
# 7453

# %%
health = health.drop_duplicates()
health
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 62415  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 62416         KYle pEREz   61  Female        AB-           Obesity
# 62417       HEATher WaNG   38  Female         B+      Hypertension
# 62418     JENniFER JOneS   43    Male         O-         Arthritis
# 62419       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
health.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           1
# Admission Type        1
# Discharge Date        1
# Medication            1
# Test Results          1
# dtype: int64

# %%
health = health.fillna(0)
health
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 62415  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 62416         KYle pEREz   61  Female        AB-           Obesity
# 62417       HEATher WaNG   38  Female         B+      Hypertension
# 62418     JENniFER JOneS   43    Male         O-         Arthritis
# 62419       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
health.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
health['Name']
# Out:
# 0            Bobby JacksOn
# 1             LesLie TErRy
# 2              DaNnY sMitH
# 3             andrEw waTtS
# 4            adrIENNE bEll
#                ...
# 62415    eLIZABeTH jaCkSOn
# 62416           KYle pEREz
# 62417         HEATher WaNG
# 62418       JENniFER JOneS
# 62419         jAMES GARCiA
# Name: Name, Length: 54967, dtype: object

# %%
health['Medical Condition']
# Out:
# 0              Cancer
# 1             Obesity
# 2             Obesity
# 3            Diabetes
# 4              Cancer
#              ...
# 62415          Asthma
# 62416         Obesity
# 62417    Hypertension
# 62418       Arthritis
# 62419       Arthritis
# Name: Medical Condition, Length: 54967, dtype: object

# %%
health[['Doctor', 'Hospital']]
# Out:
#                  Doctor                      Hospital
# 0         Matthew Smith               Sons and Miller
# 1       Samantha Davies                       Kim Inc
# 2      Tiffany Mitchell                      Cook PLC
# 3           Kevin Wells    Hernandez Rogers and Vang,
# 4        Kathleen Hanna                   White-White
# ...                 ...                           ...
# 62415     Joshua Jarvis                Jones-Thompson
# 62416   Taylor Sullivan                  Tucker-Moyer
# 62417    Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 62418    Kimberly Curry      Jackson Todd and Castro,
# 62419     Dennis Warren                Henry Sons and
#
# [54967 rows x 2 columns]

# %%
health[['Insurance Provider', 'Medication']]
# Out:
#       Insurance Provider   Medication
# 0             Blue Cross  Paracetamol
# 1               Medicare    Ibuprofen
# 2                  Aetna      Aspirin
# 3               Medicare    Ibuprofen
# 4                  Aetna   Penicillin
# ...                  ...          ...
# 62415         Blue Cross   Penicillin
# 62416              Cigna      Aspirin
# 62417   UnitedHealthcare    Ibuprofen
# 62418           Medicare    Ibuprofen
# 62419              Aetna    Ibuprofen
#
# [54967 rows x 2 columns]

# %%
health['Gender'].value_counts()
# Out:
# Gender
# Male      27497
# Female    27470
# Name: count, dtype: int64

# %%
health.dropna(inplace = True)

# %%
health.fillna(method = 'ffill', inplace = True)
# Out:
# <ipython-input-25-d1ebfd43e867>:1: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %%
health[health['Gender'] == 'Male']
# Out:
#                    Name  Age Gender Blood Type Medical Condition  \
# 0         Bobby JacksOn   30   Male         B-            Cancer
# 1          LesLie TErRy   62   Male         A+           Obesity
# 5         EMILY JOHNSOn   36   Male         A+            Asthma
# 8       JASmINe aGuIlaR   82   Male        AB+            Asthma
# 10     mIchElLe daniELs   72   Male         O+            Cancer
# ...                 ...  ...    ...        ...               ...
# 62409    ANdrEw AGUIlaR   69   Male         O-         Arthritis
# 62410  STepHAniE oliVer   82   Male         B-            Cancer
# 62412  LAuREn MCcormIcK   51   Male         O+         Arthritis
# 62414     JEssIcA WHiTe   67   Male         O+         Arthritis
# 62418    JENniFER JOneS   43   Male         O-         Arthritis
#
#       Date of Admission           Doctor                  Hospital  \
# 0            2024-01-31    Matthew Smith           Sons and Miller
# ...

# %%
health[health['Gender'] == 'Female']
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 2             DaNnY sMitH   76  Female         A-           Obesity
# 3            andrEw waTtS   28  Female         O+          Diabetes
# 4           adrIENNE bEll   43  Female        AB+            Cancer
# 6          edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7      CHrisTInA MARtinez   20  Female         A+            Cancer
# ...                   ...  ...     ...        ...               ...
# 62413        gLoRIA BOWen   57  Female         B-         Arthritis
# 62415   eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 62416          KYle pEREz   61  Female        AB-           Obesity
# 62417        HEATher WaNG   38  Female         B+      Hypertension
# 62419        jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 2            2022-09-22  Tiffany Mitchell                      Cook PLC
# ...

# %%
health[health['Medical Condition'] == 'Diabetes']
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 3             andrEw waTtS   28  Female         O+          Diabetes
# 6           edwArD EDWaRDs   21  Female        AB-          Diabetes
# 12           connOR HANsEn   75  Female         A+          Diabetes
# 27       mr. KenNEth MoORE   34  Female         A+          Diabetes
# 34        NicOlE RodriGUEz   30  Female        AB+          Diabetes
# ...                    ...  ...     ...        ...               ...
# 62340          SteVeN knoX   52  Female         A-          Diabetes
# 62353    RonALd OBRIeN jr.   72  Female         B+          Diabetes
# 62359    cHRiStINE MCCARty   75    Male        AB+          Diabetes
# 62400         LAurEn mills   33  Female         B-          Diabetes
# 62403  kimbErlY RIchArDSoN   15    Male         A-          Diabetes
#
#       Date of Admission               Doctor                      Hospital  \
# ...

# %%
health.loc[(health['Date of Admission'] == '2020-01-17') & (health['Hospital'] == 'UnitedHealthcare')]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Gender, Blood Type, Medical Condition, Date of Admission, Doctor, Hospital, Insurance Provider, Billing Amount, Room Number, Admission Type, Discharge Date, Medication, Test Results]
# Index: []

# %%
health.loc[(health['Blood Type'] == 'AB+') & (health['Doctor'] == 'Lynn Young')]
# Out:
#                 Name  Age  Gender Blood Type Medical Condition  \
# 34  NicOlE RodriGUEz   30  Female        AB+          Diabetes
#
#    Date of Admission      Doctor   Hospital Insurance Provider  \
# 34        2020-01-17  Lynn Young  Poole Inc         Blue Cross
#
#       Billing Amount  Room Number Admission Type Discharge Date Medication  \
# 34  8408.94935429195        285.0      Emergency     2020-02-10    Lipitor
#
#    Test Results
# 34       Normal

# %%
health.loc[(health['Date of Admission'] == '2023-08-12') & (health['Hospital'] == 'Molina-Phelps')]
# Out:
#               Name  Age  Gender Blood Type Medical Condition  \
# 54098  SteVeN knoX   53  Female         A-          Diabetes
# 62340  SteVeN knoX   52  Female         A-          Diabetes
#
#       Date of Admission         Doctor       Hospital Insurance Provider  \
# 54098        2023-08-12  Alicia Garcia  Molina-Phelps   UnitedHealthcare
# 62340        2023-08-12  Alicia Garcia  Molina-Phelps   UnitedHealthcare
#
#           Billing Amount  Room Number Admission Type Discharge Date  \
# 54098  5271.154491140647        379.0       Elective     2023-08-24
# 62340  5271.154491140647        379.0       Elective     2023-08-24
#
#       Medication  Test Results
# 54098  Ibuprofen  Inconclusive
# 62340  Ibuprofen  Inconclusive

# %%
health.iloc[10:20, 2:9]
# Out:
#     Gender Blood Type Medical Condition Date of Admission            Doctor  \
# 10    Male         O+            Cancer        2020-04-19       John Duncan
# 11  Female         A-      Hypertension        2023-08-13      Douglas Mayo
# 12  Female         A+          Diabetes        2019-12-12  Kenneth Fletcher
# 13  Female        AB+            Asthma        2020-05-22   Theresa Freeman
# 14  Female        AB+            Cancer        2021-10-08   Roberta Stewart
# 15  Female        AB-           Obesity        2023-01-01   Maria Dougherty
# 16  Female         A+         Arthritis        2020-06-23     Erica Spencer
# 17    Male        AB-           Obesity        2020-03-08        Justin Kim
# 18  Female         A-      Hypertension        2021-03-04  Justin Moore Jr.
# 19    Male         B+            Asthma        2022-11-15   Denise Galloway
#
#                       Hospital Insurance Provider
# 10             Schaefer-Porter           Medicare
# ...

# %%
health.iloc[50:70, 1:15]
# Out:
#     Age  Gender Blood Type Medical Condition Date of Admission  \
# 50   30    Male        AB-      Hypertension        2024-04-05
# 51   42  Female         A-            Cancer        2019-06-15
# 52   67  Female        AB+            Cancer        2022-10-29
# 53   24  Female         A-           Obesity        2022-04-08
# 54   84  Female         B-            Asthma        2023-08-17
# 55   73  Female         A-      Hypertension        2023-11-05
# 56   55  Female         A+            Cancer        2023-04-09
# 57   23    Male         O-      Hypertension        2022-09-21
# 58   40  Female        AB-            Cancer        2021-01-21
# 59   51    Male         O+      Hypertension        2020-07-10
# 60   83    Male        AB+           Obesity        2019-11-06
# 61   63    Male         A-            Asthma        2024-04-07
# 62   18    Male         A+            Cancer        2022-07-06
# 63   23  Female         B-      Hypertension        2022-08-03
# ...

# %%
health[10:15]
# Out:
#                 Name  Age  Gender Blood Type Medical Condition  \
# 10  mIchElLe daniELs   72    Male         O+            Cancer
# 11    aaRon MARtiNeZ   38  Female         A-      Hypertension
# 12     connOR HANsEn   75  Female         A+          Diabetes
# 13      rObeRt bAuer   68  Female        AB+            Asthma
# 14      bROOkE brady   44  Female        AB+            Cancer
#
#    Date of Admission            Doctor                   Hospital  \
# 10        2020-04-19       John Duncan            Schaefer-Porter
# 11        2023-08-13      Douglas Mayo                Lyons-Blair
# 12        2019-12-12  Kenneth Fletcher  Powers Miller, and Flores
# 13        2020-05-22   Theresa Freeman           Rivera-Gutierrez
# 14        2021-10-08   Roberta Stewart            Morris-Arellano
#
#    Insurance Provider      Billing Amount  Room Number Admission Type  \
# 10           Medicare  12576.795609050234        394.0         Urgent
# ...
