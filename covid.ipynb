# %%
# !pip install seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Admission_dataset.csv')
df
# Out:
#       Student ID  University ranking  Student's University dropout rate  \
# 0           3746                  30                               7.73
# 1            848                  49                              16.59
# 2           2556                  80                              28.86
# 3           3641                  84                              32.95
# 4           4007                  80                              27.50
# ...          ...                 ...                                ...
# 3995        2704                  72                              24.09
# 3996        3690                  46                              13.86
# 3997        2689                  77                              27.50
# 3998        3534                  80                              28.18
# 3999         607                  39                              12.50
#
#       SOP rating  CGPA  ZIP Code  GRE  Employed  Strong LOR  \
# ...

# %%
df.head()
# Out:
#    Student ID  University ranking  Student's University dropout rate  \
# 0        3746                  30                               7.73
# 1         848                  49                              16.59
# 2        2556                  80                              28.86
# 3        3641                  84                              32.95
# 4        4007                  80                              27.50
#
#    SOP rating  CGPA  ZIP Code  GRE  Employed  Strong LOR  \
# 0           1  7.31     90640  317         0           0
# 1           3  6.35     94539  297         0           0
# 2           2  7.12     94143  298         0           0
# 3           3  5.94     95821  298         1           0
# 4           3  5.42     92130  296         0           0
#
#    Have non academic activities  Been abroad  Chanceof admit
# 0                             0            1               0
# 1                             0            1               0
# ...

# %%
df.tail()
# Out:
#       Student ID  University ranking  Student's University dropout rate  \
# 3995        2704                  72                              24.09
# 3996        3690                  46                              13.86
# 3997        2689                  77                              27.50
# 3998        3534                  80                              28.18
# 3999         607                  39                              12.50
#
#       SOP rating  CGPA  ZIP Code  GRE  Employed  Strong LOR  \
# 3995           2  6.31     92521  303         1           0
# 3996           1  6.17     94708  304         1           0
# 3997           2  5.54     94542  293         0           0
# 3998           1  5.88     94545  300         0           0
# 3999           2  6.52     91741  294         0           0
#
#       Have non academic activities  Been abroad  Chanceof admit
# 3995                             0            0               0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Student ID                         4000 non-null   int64
#  1   University ranking                 4000 non-null   int64
#  2   Student's University dropout rate  4000 non-null   float64
#  3   SOP rating                         4000 non-null   int64
#  4   CGPA                               4000 non-null   float64
#  5   ZIP Code                           4000 non-null   int64
#  6   GRE                                4000 non-null   int64
#  7   Employed                           4000 non-null   int64
#  8   Strong LOR                         4000 non-null   int64
#  9   Have non academic activities       4000 non-null   int64
#  10  Been abroad                        4000 non-null   int64
# ...

# %%
df.dtypes
# Out:
# Student ID                             int64
# University ranking                     int64
# Student's University dropout rate    float64
# SOP rating                             int64
# CGPA                                 float64
# ZIP Code                               int64
# GRE                                    int64
# Employed                               int64
# Strong LOR                             int64
# Have non academic activities           int64
# Been abroad                            int64
# Chanceof admit                         int64
# dtype: object

# %%
df.describe()
# Out:
#         Student ID  University ranking  Student's University dropout rate  \
# count  4000.000000         4000.000000                        4000.000000
# mean   2513.380250           59.581500                          20.184942
# std    1450.874343           19.871011                           7.769693
# min       1.000000           20.000000                           5.000000
# 25%    1260.750000           42.000000                          13.180000
# 50%    2520.000000           60.000000                          20.000000
# 75%    3778.250000           77.000000                          26.820000
# max    5000.000000          100.000000                          35.000000
#
#         SOP rating         CGPA      ZIP Code          GRE     Employed  \
# count  4000.000000  4000.000000   4000.000000  4000.000000  4000.000000
# mean      1.865500     6.383407  93137.798500   299.469750     0.290000
# std       0.836113     0.959212   2212.759679     8.780539     0.453819
# ...

# %%
df.isnull().sum()
# Out:
# Student ID                           0
# University ranking                   0
# Student's University dropout rate    0
# SOP rating                           0
# CGPA                                 0
# ZIP Code                             0
# GRE                                  0
# Employed                             0
# Strong LOR                           0
# Have non academic activities         0
# Been abroad                          0
# Chanceof admit                       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Student ID', 'University ranking', 'Student's University dropout rate',
#        'SOP rating', 'CGPA', 'ZIP Code', 'GRE', 'Employed', 'Strong LOR',
#        'Have non academic activities', 'Been abroad', 'Chanceof admit'],
#       dtype='object')

# %%
len(df)
# Out:
# 4000

# %%
df.shape[0]
# Out:
# 4000

# %%
df.shape[1]
# Out:
# 12

# %%
df[:10]
# Out:
#    Student ID  University ranking  Student's University dropout rate  \
# 0        3746                  30                               7.73
# 1         848                  49                              16.59
# 2        2556                  80                              28.86
# 3        3641                  84                              32.95
# 4        4007                  80                              27.50
# 5         363                  80                              28.86
# 6         775                  75                              26.82
# 7        2956                  75                              26.14
# 8        4546                  86                              30.91
# 9        4588                  44                              14.55
#
#    SOP rating  CGPA  ZIP Code  GRE  Employed  Strong LOR  \
# 0           1  7.31     90640  317         0           0
# 1           3  6.35     94539  297         0           0
# ...

# %%
df[10:100]
# Out:
#     Student ID  University ranking  Student's University dropout rate  \
# 10        3205                  86                              30.91
# 11        1725                  58                              20.68
# 12        2593                  80                              28.18
# 13        2366                  56                              18.64
# 14        4798                  44                              14.55
# ..         ...                 ...                                ...
# 95        4868                  46                              15.23
# 96        4810                  58                              18.64
# 97        1693                  80                              28.86
# 98        1031                  86                              30.91
# 99        3038                  28                               7.73
#
#     SOP rating  CGPA  ZIP Code  GRE  Employed  Strong LOR  \
# 10           2  5.85     90095  298         0           0
# ...

# %%
df[50:]
# Out:
#       Student ID  University ranking  Student's University dropout rate  \
# 50          3576                  91                              32.27
# 51          4742                  80                              28.86
# 52          3389                  61                              20.00
# 53          4245                  70                              24.09
# 54           399                  77                              26.14
# ...          ...                 ...                                ...
# 3995        2704                  72                              24.09
# 3996        3690                  46                              13.86
# 3997        2689                  77                              27.50
# 3998        3534                  80                              28.18
# 3999         607                  39                              12.50
#
#       SOP rating  CGPA  ZIP Code  GRE  Employed  Strong LOR  \
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['CGPA'].isin(['University ranking'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3995    False
# 3996    False
# 3997    False
# 3998    False
# 3999    False
# Name: CGPA, Length: 4000, dtype: bool

# %% [markdown]
# 77 ketli var aave che

# %%
df.isin([77]).sum()
# Out:
# Student ID                             1
# University ranking                   105
# Student's University dropout rate      0
# SOP rating                             0
# CGPA                                   0
# ZIP Code                               0
# GRE                                    0
# Employed                               0
# Strong LOR                             0
# Have non academic activities           0
# Been abroad                            0
# Chanceof admit                         0
# dtype: int64

# %%
df[df['Strong LOR'] == 0]
# Out:
#       Student ID  University ranking  Student's University dropout rate  \
# 0           3746                  30                               7.73
# 1            848                  49                              16.59
# 2           2556                  80                              28.86
# 3           3641                  84                              32.95
# 4           4007                  80                              27.50
# ...          ...                 ...                                ...
# 3995        2704                  72                              24.09
# 3996        3690                  46                              13.86
# 3997        2689                  77                              27.50
# 3998        3534                  80                              28.18
# 3999         607                  39                              12.50
#
#       SOP rating  CGPA  ZIP Code  GRE  Employed  Strong LOR  \
# ...

# %%
df[df['University ranking'] == 80]
# Out:
#       Student ID  University ranking  Student's University dropout rate  \
# 2           2556                  80                              28.86
# 4           4007                  80                              27.50
# 5            363                  80                              28.86
# 12          2593                  80                              28.18
# 37          2984                  80                              27.50
# ...          ...                 ...                                ...
# 3810        2822                  80                              28.18
# 3947         721                  80                              28.86
# 3950        1194                  80                              28.86
# 3953        2068                  80                              28.86
# 3998        3534                  80                              28.18
#
#       SOP rating  CGPA  ZIP Code  GRE  Employed  Strong LOR  \
# ...

# %%
df[df['University ranking'] == '80'] ['ZIP Code']
# Out:
# Series([], Name: ZIP Code, dtype: int64)

# %%
df['CGPA'].value_counts()
# Out:
# CGPA
# 5.75    73
# 6.52    68
# 5.62    64
# 5.69    63
# 5.71    62
#         ..
# 8.77     2
# 9.10     2
# 9.38     1
# 9.04     1
# 9.50     1
# Name: count, Length: 161, dtype: int64

# %%
df['University ranking'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='University ranking'>

# %%
plt.bar(df['University ranking'].value_counts().index,df['University ranking'].value_counts().values)
plt.xlabel('University ranking') # Corrected function name to 'xlabel'
plt.ylabel('count') # Corrected function name to 'ylabel'
plt.title('University ranking')
# Out:
# Text(0.5, 1.0, 'University ranking')

# %%
plt.hist(df['CGPA'], bins=10)  # Use a number of bins instead of the unsorted index
plt.xlabel('CGPA')
plt.ylabel('count')
plt.show()
