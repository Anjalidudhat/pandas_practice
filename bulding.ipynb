# %%
import pandas as pd

# %%
df = pd.read_csv('/content/building_data.csv')

# %%
df.head()
# Out:
#         City         Area  Building_Type  Construction_Year  Number_of_Floors  \
# 0  Bangalore    Yelahanka    Residential               1989                12
# 1  Bangalore   Whitefield  Institutional               1980                 6
# 2  Bangalore  Koramangala     Industrial               2006                10
# 3  Bangalore    Jayanagar     Commercial               1985                 1
# 4  Bangalore   HSR Layout     Industrial               2006                12
#
#    Energy_Consumption_Per_SqM  Water_Usage_Per_Building  \
# 0                   50.000000                477.681762
# 1                  225.759107                200.000000
# 2                   98.755927                200.000000
# 3                   68.470692                200.000000
# 4                   50.000000                347.093644
#
#    Waste_Recycled_Percentage  Occupancy_Rate  Indoor_Air_Quality  \
# 0                  48.417266       81.814110           13.780635
# ...

# %%
df.tail()
# Out:
#            City          Area  Building_Type  Construction_Year  \
# 1245  Bangalore  Malleshwaram    Residential               1985
# 1246  Bangalore     Jayanagar     Commercial               2007
# 1247  Bangalore   Koramangala     Commercial               1990
# 1248  Bangalore        Hebbal  Institutional               2021
# 1249  Bangalore     Yelahanka    Residential               2017
#
#       Number_of_Floors  Energy_Consumption_Per_SqM  Water_Usage_Per_Building  \
# 1245                10                  147.613313                677.914745
# 1246                 5                   50.000000                861.042961
# 1247                 1                   50.000000               1500.000000
# 1248                 6                  250.000000               1500.000000
# 1249                 8                  143.821153               1500.000000
#
#       Waste_Recycled_Percentage  Occupancy_Rate  Indoor_Air_Quality  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   City                         1250 non-null   object
#  1   Area                         1250 non-null   object
#  2   Building_Type                1250 non-null   object
#  3   Construction_Year            1250 non-null   int64
#  4   Number_of_Floors             1250 non-null   int64
#  5   Energy_Consumption_Per_SqM   1250 non-null   float64
#  6   Water_Usage_Per_Building     1250 non-null   float64
#  7   Waste_Recycled_Percentage    1250 non-null   float64
#  8   Occupancy_Rate               1250 non-null   float64
#  9   Indoor_Air_Quality           1250 non-null   float64
#  10  Smart_Devices_Count          1250 non-null   int64
#  11  Green_Certified              1250 non-null   int64
#  12  Maintenance_Resolution_Time  1250 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Construction_Year  Number_of_Floors  Energy_Consumption_Per_SqM  \
# count        1250.000000       1250.000000                 1250.000000
# mean         1996.735200          7.118400                  108.745712
# std            15.696515          3.773456                   72.180593
# min          1970.000000          1.000000                   50.000000
# 25%          1983.000000          4.000000                   50.000000
# 50%          1996.000000          7.000000                   72.868797
# 75%          2010.000000         11.000000                  154.658612
# max          2023.000000         13.000000                  250.000000
#
#        Water_Usage_Per_Building  Waste_Recycled_Percentage  Occupancy_Rate  \
# count               1250.000000                1250.000000     1250.000000
# mean                 647.021156                  28.831580       77.285182
# std                  485.194992                  16.250126       15.093523
# ...

# %%
df.shape
# Out:
# (1250, 19)

# %%
df.isnull().sum()
# Out:
# City                           0
# Area                           0
# Building_Type                  0
# Construction_Year              0
# Number_of_Floors               0
# Energy_Consumption_Per_SqM     0
# Water_Usage_Per_Building       0
# Waste_Recycled_Percentage      0
# Occupancy_Rate                 0
# Indoor_Air_Quality             0
# Smart_Devices_Count            0
# Green_Certified                0
# Maintenance_Resolution_Time    0
# Last_Inspection_Date           0
# Building_Status                0
# Maintenance_Priority           0
# Energy_Per_SqM                 0
# Number_of_Residents            0
# Electricity_Bill               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Area']
# Out:
# 0          Yelahanka
# 1         Whitefield
# 2        Koramangala
# 3          Jayanagar
# 4         HSR Layout
#             ...
# 1245    Malleshwaram
# 1246       Jayanagar
# 1247     Koramangala
# 1248          Hebbal
# 1249       Yelahanka
# Name: Area, Length: 1250, dtype: object

# %%
df['Maintenance_Resolution_Time']
# Out:
# 0        7.211768
# 1       34.139492
# 2        6.224612
# 3        5.327398
# 4        7.060854
#           ...
# 1245     8.304416
# 1246     5.810473
# 1247     6.761967
# 1248    14.147058
# 1249     5.844906
# Name: Maintenance_Resolution_Time, Length: 1250, dtype: float64

# %%
df[['Building_Type', 'Smart_Devices_Count']]
# Out:
#       Building_Type  Smart_Devices_Count
# 0       Residential                    6
# 1     Institutional                   10
# 2        Industrial                    2
# 3        Commercial                    2
# 4        Industrial                   19
# ...             ...                  ...
# 1245    Residential                    9
# 1246     Commercial                    5
# 1247     Commercial                    1
# 1248  Institutional                    6
# 1249    Residential                    2
#
# [1250 rows x 2 columns]

# %%
df[df['Area'] == 'Yelahanka']
# Out:
#            City       Area  Building_Type  Construction_Year  \
# 0     Bangalore  Yelahanka    Residential               1989
# 8     Bangalore  Yelahanka     Commercial               2004
# 23    Bangalore  Yelahanka     Industrial               1997
# 54    Bangalore  Yelahanka  Institutional               1988
# 61    Bangalore  Yelahanka     Industrial               1979
# ...         ...        ...            ...                ...
# 1215  Bangalore  Yelahanka  Institutional               2019
# 1219  Bangalore  Yelahanka    Residential               2000
# 1227  Bangalore  Yelahanka    Residential               1985
# 1244  Bangalore  Yelahanka     Industrial               1981
# 1249  Bangalore  Yelahanka    Residential               2017
#
#       Number_of_Floors  Energy_Consumption_Per_SqM  Water_Usage_Per_Building  \
# 0                   12                   50.000000                477.681762
# ...

# %%
df[df['Building_Type'] == 'Commercial']
# Out:
#            City         Area Building_Type  Construction_Year  \
# 3     Bangalore    Jayanagar    Commercial               1985
# 5     Bangalore   HSR Layout    Commercial               2023
# 6     Bangalore  Indiranagar    Commercial               1994
# 8     Bangalore    Yelahanka    Commercial               2004
# 15    Bangalore   Whitefield    Commercial               2014
# ...         ...          ...           ...                ...
# 1235  Bangalore   Whitefield    Commercial               1973
# 1236  Bangalore   HSR Layout    Commercial               2018
# 1243  Bangalore  Koramangala    Commercial               1981
# 1246  Bangalore    Jayanagar    Commercial               2007
# 1247  Bangalore  Koramangala    Commercial               1990
#
#       Number_of_Floors  Energy_Consumption_Per_SqM  Water_Usage_Per_Building  \
# 3                    1                   68.470692                200.000000
# ...

# %%
df[df['Building_Type'] == 'Residential']
# Out:
#            City             Area Building_Type  Construction_Year  \
# 0     Bangalore        Yelahanka   Residential               1989
# 9     Bangalore       BTM Layout   Residential               1991
# 10    Bangalore       Whitefield   Residential               1994
# 13    Bangalore      Koramangala   Residential               1978
# 16    Bangalore       HSR Layout   Residential               2016
# ...         ...              ...           ...                ...
# 1239  Bangalore  Electronic City   Residential               2021
# 1240  Bangalore           Hebbal   Residential               1994
# 1242  Bangalore        Jayanagar   Residential               2023
# 1245  Bangalore     Malleshwaram   Residential               1985
# 1249  Bangalore        Yelahanka   Residential               2017
#
#       Number_of_Floors  Energy_Consumption_Per_SqM  Water_Usage_Per_Building  \
# 0                   12                   50.000000                477.681762
# ...

# %%
df[df['Construction_Year'] == 2021]
# Out:
#            City             Area  Building_Type  Construction_Year  \
# 55    Bangalore           Hebbal     Industrial               2021
# 149   Bangalore        Jayanagar    Residential               2021
# 199   Bangalore           Hebbal    Residential               2021
# 236   Bangalore     Banashankari    Residential               2021
# 313   Bangalore      Koramangala     Commercial               2021
# 321   Bangalore       Whitefield  Institutional               2021
residential               2017
#
#       Number_of_Floors  Energy_Consumption_Per_SqM  Water_Usage_Per_Building  \
# 0                   12                   50.000000                477.681762
# ...

# %%
df.loc[(df['Number_of_Floors'] == 12) & (df['Maintenance_Priority'] == 'Low')]
# Out:
#            City             Area  Building_Type  Construction_Year  \
# 80    Bangalore       Whitefield  Institutional               1978
# 105   Bangalore       HSR Layout     Industrial               1975
# 116   Bangalore       BTM Layout    Residential               1987
# 134   Bangalore     Malleshwaram    Residential               2010
# 188   Bangalore     Banashankari     Industrial               2004
# 253   Bangalore     Malleshwaram     Commercial               2013
# 323   Bangalore       Whitefield     Industrial               2017
# 381   Bangalore        Yelahanka     Industrial               2007
# 392   Bangalore        Jayanagar     Industrial               1989
# 429   Bangalore      Indiranagar  Institutional               2023
# 529   Bangalore        Jayanagar     Commercial               1973
# 547   Bangalore     Malleshwaram     Industrial               1978
# 634   Bangalore  Electronic City     Industrial               1998
# ...

# %%
df[(df['Building_Type'] == 'Industrial') & (df['Construction_Year'] == 1973)]
# Out:
#            City             Area Building_Type  Construction_Year  \
# 654   Bangalore     Malleshwaram    Industrial               1973
# 851   Bangalore        Jayanagar    Industrial               1973
# 1115  Bangalore  Electronic City    Industrial               1973
#
#       Number_of_Floors  Energy_Consumption_Per_SqM  Water_Usage_Per_Building  \
# 654                  3                   84.755197               1369.373461
# 851                  6                  207.920438                761.487837
# 1115                 4                  130.155877                200.000000
#
#       Waste_Recycled_Percentage  Occupancy_Rate  Indoor_Air_Quality  \
# 654                   12.700808       67.318882           46.906918
# 851                   40.877194       58.353887           54.062609
# 1115                  18.685433       65.868914          100.000000
#
#       Smart_Devices_Count  Green_Certified  Maintenance_Resolution_Time  \
# ...

# %%
df.iloc[10:90, 0:3]
# Out:
#          City          Area  Building_Type
# 10  Bangalore    Whitefield    Residential
# 11  Bangalore        Hebbal     Industrial
# 12  Bangalore  Malleshwaram  Institutional
# 13  Bangalore   Koramangala    Residential
# 14  Bangalore   Koramangala     Industrial
# ..        ...           ...            ...
# 85  Bangalore    HSR Layout     Industrial
# 86  Bangalore   Indiranagar     Industrial
# 87  Bangalore  Banashankari    Residential
# 88  Bangalore  Malleshwaram  Institutional
# 89  Bangalore     Jayanagar     Industrial
#
# [80 rows x 3 columns]

# %%
df.iloc[110:150, 4:13]
# Out:
#      Number_of_Floors  Energy_Consumption_Per_SqM  Water_Usage_Per_Building  \
# 110                 3                   50.000000                730.366782
# 111                11                   50.000000                200.000000
# 112                 2                  199.121256                292.626437
# 113                12                  123.816531                299.543400
# 114                11                   75.262064                396.279004
# 115                11                  153.863980                200.000000
# 116                12                  122.097671                377.449473
# 117                 6                   50.000000                719.175962
# 118                 8                  167.311005                200.000000
# 119                 1                   58.132493                200.000000
# 120                 5                  123.551122               1066.253112
# ...

# %%
df.hist(figsize = (12,20), bins = 100)
# Out:
# array([[<Axes: title={'center': 'Construction_Year'}>,
#         <Axes: title={'center': 'Number_of_Floors'}>,
#         <Axes: title={'center': 'Energy_Consumption_Per_SqM'}>,
#         <Axes: title={'center': 'Water_Usage_Per_Building'}>],
#        [<Axes: title={'center': 'Waste_Recycled_Percentage'}>,
#         <Axes: title={'center': 'Occupancy_Rate'}>,
#         <Axes: title={'center': 'Indoor_Air_Quality'}>,
#         <Axes: title={'center': 'Smart_Devices_Count'}>],
#        [<Axes: title={'center': 'Green_Certified'}>,
#         <Axes: title={'center': 'Maintenance_Resolution_Time'}>,
#         <Axes: title={'center': 'Energy_Per_SqM'}>,
#         <Axes: title={'center': 'Number_of_Residents'}>],
#        [<Axes: title={'center': 'Electricity_Bill'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)
