# %%
import pandas as pd

# %%
net = pd.read_csv('/content/netflix_titles_nov_2019.csv')

# %%
net.head()
# Out:
#     show_id                                title                    director  \
# 0  81193313                            Chocolate                         NaN
# 1  81197050  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2  81213894                      The Zoya Factor             Abhishek Sharma
# 3  81082007                            Atlantics                   Mati Diop
# 4  80213643                      Chip and Potato                         NaN
#
#                                                 cast  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4  Abigail Oliver, Andrea Libman, Briana Buckmast...
#
#                     country         date_added  release_year rating  \
# 0               South Korea  November 30, 2019          2019  TV-14
# ...

# %%
net.tail()
# Out:
#        show_id                        title              director  \
# 5832  70141644  Mad Ron's Prevues from Hell            Jim Monaco
# 5833  70127998                     Splatter             Joe Dante
# 5834  70084180      Just Another Love Story          Ole Bornedal
# 5835  70157452              Dinner for Five                   NaN
# 5836  70053412         To and From New York  Sorin Dan Mihalcescu
#
#                                                    cast        country  \
# 5832  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
# 5833  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...  United States
# 5834  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
# 5835                                                NaN  United States
# 5836  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
#
#              date_added  release_year rating  duration  \
# 5832   November 1, 2010          1987     NR    84 min
# ...

# %%
net.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5837 entries, 0 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5837 non-null   int64
#  1   title         5837 non-null   object
#  2   director      3936 non-null   object
#  3   cast          5281 non-null   object
#  4   country       5410 non-null   object
#  5   date_added    5195 non-null   object
#  6   release_year  5837 non-null   int64
#  7   rating        5827 non-null   object
#  8   duration      5837 non-null   object
#  9   listed_in     5837 non-null   object
#  10  description   5837 non-null   object
#  11  type          5837 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 547.3+ KB

# %%
net.describe()
# Out:
#             show_id  release_year
# count  5.837000e+03   5837.000000
# mean   7.730079e+07   2013.688539
# std    9.479777e+06      8.419088
# min    2.698800e+05   1925.000000
# 25%    8.004520e+07   2013.000000
# 50%    8.016353e+07   2016.000000
# 75%    8.024188e+07   2018.000000
# max    8.122720e+07   2020.000000

# %%
net.shape[0]
# Out:
# 5837

# %%
net.shape[1]
# Out:
# 12

# %%
net.isnull().sum()
# Out:
# show_id            0
# title              0
# director        1901
# cast             556
# country          427
# date_added       642
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# type               0
# dtype: int64

# %%
net.drop('director', axis = 1, inplace = True)

# %%
net.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5837 entries, 0 to 5836
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5837 non-null   int64
#  1   title         5837 non-null   object
#  2   cast          5281 non-null   object
#  3   country       5410 non-null   object
#  4   date_added    5195 non-null   object
#  5   release_year  5837 non-null   int64
#  6   rating        5827 non-null   object
#  7   duration      5837 non-null   object
#  8   listed_in     5837 non-null   object
#  9   description   5837 non-null   object
#  10  type          5837 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 501.7+ KB

# %%
net = net.fillna(0)
net
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                                                    cast  \
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                     Christian Morales
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3     Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# ...

# %%
net.isnull().sum()
# Out:
# show_id         0
# title           0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# type            0
# dtype: int64

# %%
net['title']
# Out:
# 0                                 Chocolate
# 1       Guatemala: Heart of the Mayan World
# 2                           The Zoya Factor
# 3                                 Atlantics
# 4                           Chip and Potato
#                        ...
# 5832            Mad Ron's Prevues from Hell
# 5833                               Splatter
# 5834                Just Another Love Story
# 5835                        Dinner for Five
# 5836                   To and From New York
# Name: title, Length: 5837, dtype: object

# %%
net['cast']
# Out:
# 0       Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                       Christian Morales
# 2       Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3       Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4       Abigail Oliver, Andrea Libman, Briana Buckmast...
#                               ...
# 5832    Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...
# 5833    Corey Feldman, Tony Todd, Tara Leigh, Erin Way...
# 5834    Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...
# 5835                                                    0
# 5836    Barbara King, Shaana Diya, John Krisiukenas, Y...
# Name: cast, Length: 5837, dtype: object

# %%
net[10:100]
# Out:
#      show_id                       title  \
# 10  81172899                      Payday
# 11  81094391        Sugar Rush Christmas
# 12  81172908          The Accidental Spy
# 13  81152641        The Charming Stepmom
# 14  81172901                  The Island
# ..       ...                         ...
# 95  70044686                      Zodiac
# 96  81073633  Iliza Shlesinger: Unveiled
# 97  81152642               Miss Culinary
# 98  81105522           No Time for Shame
# 99  81191473                Candy Online
#
#                                                  cast        country  \
# 10  Baaj Adebule, Ebiye Victor, Meg Otanwa, Bisola...        Nigeria
# 11        Hunter March, Candace Nelson, Adriano Zumbo  United States
# 12  Ramsey Nouah, Christine Allado, Ayo Makun, Emm...        Nigeria
# 13  Shahkrit Yamnarm, View Wannarot Sontichai, Kri...              0
# 14  Sambasa Nzeribe, Segun Arinze, Tokunbo Idowu, ...        Nigeria
# ...

# %%
net[net['date_added'] == 'November 29, 2019']
# Out:
#      show_id                                   title  \
# 3   81082007                               Atlantics
# 5   81172754                            Crazy people
# 6   81120982                          I Lost My Body
# 7   81227195  Kalushi: The Story of Solomon Mahlangu
# 9   81172841                    Lagos Real Fake Life
# 10  81172899                                  Payday
# 11  81094391                    Sugar Rush Christmas
# 12  81172908                      The Accidental Spy
# 13  81152641                    The Charming Stepmom
# 14  81172901                              The Island
# 15  80990849                 The Movies That Made Us
#
#                                                  cast  \
# 3   Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 5   Ramsey Nouah, Chigul, Sola Sobowale, Ireti Doy...
# 6   Hakim Faris, Victoire Du Bois, Patrick d'Assum...
# 7   Thabo Rametsi, Thabo Malema, Welile Nzuza, Jaf...
# ...

# %%
net[net['release_year'] == 2019]
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 2120  80209379          Tidying Up with Marie Kondo
# 2321  80229852                       Little Singham
# 2518  80202352                             Incoming
# 3263  80025384            Unbreakable Kimmy Schmidt
# 3264  70140358                 Arrested Development
#
#                                                    cast  \
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                     Christian Morales
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3     Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# ...

# %%
net[net['rating'] == 'TV-G']
# Out:
#        show_id                                title  \
# 1     81197050  Guatemala: Heart of the Mayan World
# 57    80117560            Trolls: The Beat Goes On!
# 76    80244683           Lorena, Light-Footed Woman
# 155   81209203          Luccas Neto in: Summer Camp
# 165   70209267                 A Holiday Engagement
# ...        ...                                  ...
# 5753  80020540                          Richie Rich
# 5758  70266023                     Life on Location
# 5766  70230417                        Oscar's Oasis
# 5800  70253398                    Shrek the Musical
# 5817  60003082                      White Christmas
#
#                                                    cast        country  \
# 1                                     Christian Morales              0
# 57    Amanda Leighton, Skylar Astin, Ron Funches, Da...  United States
# 76                                       Lorena Ramírez         Mexico
# ...

# %%
net[net['duration'] == '8 Seasons']
# Out:
#        show_id                                title  \
# 57    80117560            Trolls: The Beat Goes On!
# 541   70185015                           Portlandia
# 543   70210884                American Horror Story
# 1296  70245163                     Call the Midwife
# 1539  80115432                  Spirit: Riding Free
# 1905  80239798             Club Friday The Series 8
# 2261  80075595          Voltron: Legendary Defender
# 2405  70234440  My Little Pony: Friendship Is Magic
# 3776  80080436                         Under Arrest
# 3863  70136126                               Dexter
# 4127  70155610                       That '70s Show
# 4241  70155629                              Charmed
# 4353  70143860                  The Vampire Diaries
# 4589  70155574               The Andy Griffith Show
# 4731  70143864                          Royal Pains
# 5795  70136122                                Weeds
#
#                                                    cast  \
# ...

# %%
net[net['type'] == 'Movie']
# Out:
#        show_id                                title  \
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 5     81172754                         Crazy people
# 6     81120982                       I Lost My Body
# ...        ...                                  ...
# 5831  70154110                        Even the Rain
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5836  70053412                 To and From New York
#
#                                                    cast  \
# 1                                     Christian Morales
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3     Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 5     Ramsey Nouah, Chigul, Sola Sobowale, Ireti Doy...
# ...

# %%
net.loc[(net['country'] =='India')]
# Out:
#        show_id                title  \
# 2     81213894      The Zoya Factor
# 24    81194544  Evvarikee Cheppoddu
# 34    81215481              Pranaam
# 69    81217738            Dorasaani
# 78    81217739            Mallesham
# ...        ...                  ...
# 5407  70153553                Harud
# 5420  80038288               Umrika
# 5478  80115686               Dhanak
# 5485  80115844          John & Jane
# 5545  80108386   X: Past Is Present
#
#                                                    cast country  \
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...   India
# 24    Rakesh Varre, Gargeyi, Vamsi raj Nekkanti, D P...   India
# 34    Rajeev Khandelwal, Samiksha Singh, S.M. Zaheer...   India
# 69    Anand Deverakonda, Shivatmika Rajasekhar, Kann...   India
# 78       Jhansi, Priyadarshi Pullikonda, Ananya Nagalla   India
# ...                                                 ...     ...
# 5407  Mohammad Amir Naji, Shahnawaz Bhat, Shamim Bas...   India
# ...

# %%
net.loc[(net['country'] == 'India') & (net['duration'] == '105 min')]
# Out:
#        show_id               title  \
# 111   81076114        House Arrest
# 2021  81052265              Adhugo
# 2508  80207447            Siddhant
# 3328  80993495                Ajji
# 3452  80164904             Ittefaq
# 5545  80108386  X: Past Is Present
#
#                                                    cast country  \
# 111   Ali Fazal, Shriya Pilgaonkar, Jim Sarbh, Barkh...   India
# 2021                                                  0   India
# 2508  Vikram Gokhale, Swati Chitnis, Kishore Kadam, ...   India
# 3328  Sushama Deshpande, Abhishek Banerjee, Smita Ta...   India
# 3452  Sidharth Malhotra, Sonakshi Sinha, Akshaye Khanna   India
# 5545  Anshuman Jha, Rajat Kapoor, Pooja Ruparel, Pia...   India
#
#              date_added  release_year rating duration  \
# 111   November 15, 2019          2019  TV-14  105 min
# 2021   January 15, 2019          2018  TV-14  105 min
# 2508   October 30, 2018          2014   TV-G  105 min
# ...

# %%
net.loc[(net['cast'] == 0) & (net['release_year'] == 2018)]
# Out:
#        show_id                                    title cast        country  \
# 441   81191195  Salam - The First ****** Nobel Laureate    0  United States
# 479   81036448                              Miniforce X    0    South Korea
# 650   80174902                               Moving Art    0  United States
# 752   81123826                        Hasta los dientes    0         Mexico
# 778   81087761                            Roll Red Roll    0  United States
# ...        ...                                      ...  ...            ...
# 3589  80219143                             Ladies First    0          India
# 3602  80156688                               Flint Town    0  United States
# 3736  80118913                      The Mortified Guide    0  United States
# 3740  80209006                   The Trader (Sovdagari)    0        Georgia
# 3789  80118100                              Dirty Money    0  United States
#
# ...

# %%
net.loc[(net['cast'] == 0) & (net['release_year'] == 2018) & (net['country'] == 'India')]
# Out:
#        show_id                title cast country         date_added  \
# 826   81155880     Regiment Diaries    0   India     August 1, 2019
# 1577  81066723          The Calling    0   India      April 1, 2019
# 2021  81052265               Adhugo    0   India   January 15, 2019
# 2230  80998331  Anjaan: Rural Myths    0   India  December 15, 2018
# 3589  80219143         Ladies First    0   India      March 8, 2018
#
#       release_year rating  duration  \
# 826           2018  TV-14  1 Season
# 1577          2018  TV-MA  1 Season
# 2021          2018  TV-14   105 min
# 2230          2018  TV-14  1 Season
# 3589          2018   TV-G    40 min
#
#                                               listed_in  \
# 826                  Docuseries, International TV Shows
# 1577                 International TV Shows, Reality TV
# 2021          Comedies, International Movies, Thrillers
# 2230    International TV Shows, TV Horror, TV Thrillers
# ...

# %%
net.iloc[0,0]
# Out:
# 81193313

# %%
net.iloc[0:4,2:5]
# Out:
#                                                 cast  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
#
#                     country         date_added
# 0               South Korea  November 30, 2019
# 1                         0  November 30, 2019
# 2                     India  November 30, 2019
# 3  France, Senegal, Belgium  November 29, 2019

# %%
net.iloc[10:20, 3:9]
# Out:
#           country         date_added  release_year rating  duration  \
# 10        Nigeria  November 29, 2019          2018  TV-MA   110 min
# 11  United States  November 29, 2019          2019  TV-PG  1 Season
# 12        Nigeria  November 29, 2019          2017  TV-14   104 min
# 13              0  November 29, 2019          2019  TV-14  1 Season
# 14        Nigeria  November 29, 2019          2018  TV-14    93 min
# 15  United States  November 29, 2019          2019  TV-MA  1 Season
# 16  United States  November 28, 2019          2019  TV-PG    94 min
# 17          Japan  November 28, 2019          2019  TV-14  1 Season
# 18         Brazil  November 28, 2019          2019  TV-MA  1 Season
# 19  United States  November 28, 2019          2019  TV-PG  1 Season
#
#                                             listed_in
# 10  Comedies, Independent Movies, International Mo...
# 11                                         Reality TV
# 12  Action & Adventure, Comedies, International Mo...
# ...

# %%
net.loc[(net['country'] == 'United States') & (net['release_year'] == 2019)]
# Out:
#        show_id                           title  \
# 11    81094391            Sugar Rush Christmas
# 15    80990849         The Movies That Made Us
# 16    81033086                    Holiday Rush
# 19    80997965            Merry Happy Whatever
# 22    81002391                          Broken
# ...        ...                             ...
# 2085  80050008  A Series of Unfortunate Events
# 2092  81008236          COMEDIANS of the world
# 2120  80209379     Tidying Up with Marie Kondo
# 3263  80025384       Unbreakable Kimmy Schmidt
# 3264  70140358            Arrested Development
#
#                                                    cast        country  \
# 11          Hunter March, Candace Nelson, Adriano Zumbo  United States
# 15                                                    0  United States
# 16    Romany Malco, Sonequa Martin-Green, Darlene Lo...  United States
# 19    Dennis Quaid, Bridgit Mendler, Brent Morin, As...  United States
# ...

# %%
net.iloc[200:250, 0:3]
# Out:
#       show_id                                              title  \
# 200  81184735      Barbie Dreamhouse Adventures: Go Team Roberts
# 201  81183624                                Billy on the Street
# 202  80221999                                       Bondi Rescue
# 203  60002033                                      Butterfield 8
# 204  70046968                              Cat on a Hot Tin Roof
# 205  81154982                                 Christmas Break-In
# 206  81063129                         Christmas in the Heartland
# 207  81074542                                 Christmas Survival
# 208  70204963                                            CLANNAD
# 209    382650                                    Cleopatra Jones
# 210  70044705                             Code Name: The Cleaner
# 211    449931                                     Doctor Zhivago
# 212  81189912                                              Drive
# ...

# %%
net.hist(figsize = (12,20), bins = 100)
# Out:
# array([[<Axes: title={'center': 'show_id'}>,
#         <Axes: title={'center': 'release_year'}>]], dtype=object)
