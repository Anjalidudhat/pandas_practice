# %%
# !pip install pandas

# %%
import pandas as pd

# %%
a = ['Sahaj','Anjali',45]
df = pd.Series(a)
df
# Out:
# 0     Sahaj
# 1    Anjali
# 2        45
# dtype: object

# %%
df = pd.Series(a,index=["Name","Name","Age"])
df
# Out:
# Name     Sahaj
# Name    Anjali
# Age         45
# dtype: object

# %%
personal = {
    "Name": ["Sahaj","Anjali","Nikunj","Priya"],
    "Age": [45,34,32, 28],
    "Gender": ["Male","Female","Male","Female"]
}

print(personal)
# Out:
# {'Name': ['Sahaj', 'Anjali', 'Nikunj', 'Priya'], 'Age': [45, 34, 32, 28], 'Gender': ['Male', 'Female', 'Male', 'Female']}

# %%
df = pd.DataFrame(personal)
df
# Out:
#      Name  Age  Gender
# 0   Sahaj   45    Male
# 1  Anjali   34  Female
# 2  Nikunj   32    Male
# 3   Priya   28  Female

# %%
df1 = df.loc[0]
df1
# Out:
# Name      Sahaj
# Age          45
# Gender     Male
# Name: 0, dtype: object

# %%
df1 = df.loc[[1,3]]
df1
# Out:
#      Name  Age  Gender
# 1  Anjali   34  Female
# 3   Priya   28  Female

# %%
df = pd.read_excel("/content/house.xls")

# %%
df
# Out:
#             hDate    hCommunity hDoorModel   hArea  hTotalPrice  hUnitPrice  \
# 0      2022.02.27  新亚洲体育城星体花园南区       4室2厅   89.24           95       10624
# 1      2022.02.27        俊发城金盏苑       2室2厅   67.14           88       13078
# 2      2022.02.27        万科魅力之城       2室1厅   65.40           87       13303
# 3      2022.02.27        金色交响家园       2室2厅   85.21           94       11032
# 4      2022.02.27          金沙小区       2室1厅   55.00           54        9782
# ...           ...           ...        ...     ...          ...         ...
# 14845  2021.06.19      五大洲·别样院景       2室2厅   69.00           94       13624
# 14846  2021.06.19          碧海秋月       2室2厅   62.46           59        9415
# 14847  2021.06.19        华润中央公园       4室2厅  128.00          152       11866
# 14848  2021.06.19          中洲阳光       2室1厅   44.23           36        8140
# 14849  2021.06.19          华龙人家       2室1厅   87.70           90       10263
#
# ...

# %%
df.head()
# Out:
#         hDate    hCommunity hDoorModel  hArea  hTotalPrice  hUnitPrice  \
# 0  2022.02.27  新亚洲体育城星体花园南区       4室2厅  89.24           95       10624
# 1  2022.02.27        俊发城金盏苑       2室2厅  67.14           88       13078
# 2  2022.02.27        万科魅力之城       2室1厅  65.40           87       13303
# 3  2022.02.27        金色交响家园       2室2厅  85.21           94       11032
# 4  2022.02.27          金沙小区       2室1厅  55.00           54        9782
#
#    hListPrice  hPeriod hToward hDecorate hFloor  hProperty
# 0        96.0      509      东西        精装    中楼层     2009.0
# 1        89.8      141       南        精装    NaN        NaN
# 2        88.8       92       南        精装    中楼层     2013.0
# 3        98.0       42      东北        精装    NaN        NaN
# 4        53.8       70       东        精装    中楼层     2000.0

# %%
df.tail()
# Out:
#             hDate hCommunity hDoorModel   hArea  hTotalPrice  hUnitPrice  \
# 14845  2021.06.19   五大洲·别样院景       2室2厅   69.00           94       13624
# 14846  2021.06.19       碧海秋月       2室2厅   62.46           59        9415
# 14847  2021.06.19     华润中央公园       4室2厅  128.00          152       11866
# 14848  2021.06.19       中洲阳光       2室1厅   44.23           36        8140
# 14849  2021.06.19       华龙人家       2室1厅   87.70           90       10263
#
#        hListPrice  hPeriod hToward hDecorate hFloor  hProperty
# 14845        97.0        4       南        精装    中楼层     2010.0
# 14846        62.0       63      西南        精装    低楼层     2005.0
# 14847       155.0      588       南        毛坯    中楼层     2017.0
# 14848        36.0        1      西南        其他    高楼层     2012.0
# 14849        91.0      106      东南        其他    低楼层     2006.0
