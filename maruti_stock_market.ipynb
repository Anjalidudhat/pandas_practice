# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import datetime as dt

# %%
start_date = "2023-08-01"
end_date = "2024-08-16"

# %%
import yfinance as yf

# %%
data = yf.download("TATAMOTORS.NS", start = start_date, end = end_date)
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-08-01   645.000000   652.900024   642.000000   643.650024   641.669861
# 2023-08-02   644.000000   644.299988   616.450012   622.650024   620.734497
# 2023-08-03   623.000000   626.450012   614.150024   618.950012   617.045837
# 2023-08-04   624.849976   625.000000   613.299988   615.000000   613.107971
# 2023-08-07   619.000000   619.000000   608.500000   609.500000   607.624939
# ...                 ...          ...          ...          ...          ...
# 2024-08-08  1034.949951  1056.400024  1027.000000  1041.750000  1041.750000
# 2024-08-09  1055.000000  1082.949951  1052.050049  1068.099976  1068.099976
# 2024-08-12  1065.000000  1079.900024  1055.000000  1076.150024  1076.150024
# 2024-08-13  1074.849976  1075.500000  1048.199951  1053.449951  1053.449951
# 2024-08-14  1057.000000  1067.050049  1047.000000  1062.349976  1062.349976
#
#               Volume
# Date
# 2023-08-01   8924219
# 2023-08-02  15762687
# 2023-08-03  11458920
# 2023-08-04  11806739
# 2023-08-07   9893466
# ...              ...
# 2024-08-08  19529790
# 2024-08-09  15443008
# 2024-08-12  11311050
# 2024-08-13   7508231
# 2024-08-14   8211830
#
# [254 rows x 6 columns]

# %%
close = data['Close']
ax = close.plot(title = "maruti stock price")
ax.set_xlabel = ("Date")
ax.set_ylabel = ("close price")
ax.grid()
plt.show()
