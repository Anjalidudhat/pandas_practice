# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/police_project.csv')

# %%
df.head(10)
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
# 5  2005-03-23     09:45          NaN             M          1982.0
# 6  2005-04-01     17:30          NaN             M          1969.0
# 7  2005-06-06     13:20          NaN             F          1986.0
# 8  2005-07-13     10:15          NaN             M          1970.0
# 9  2005-07-13     15:45          NaN             M          1970.0
#
#    driver_age driver_race                   violation_raw  violation  \
# 0        20.0       White                        Speeding   Speeding
# 1        40.0       White                        Speeding   Speeding
# 2        33.0       White                        Speeding   Speeding
# 3        19.0       White                Call for Service      Other
# 4        21.0       White                        Speeding   Speeding
# 5        23.0       Black  Equipment/Inspection Violation  Equipment
# 6        36.0       White                        Speeding   Speeding
# 7        19.0       White                        Speeding   Speeding
# 8        35.0       Black                        Speeding   Speeding
# 9        35.0       White                        Speeding   Speeding
#
#    search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0             False         NaN       Citation       False      0-15 Min
# 1             False         NaN       Citation       False      0-15 Min
# 2             False         NaN       Citation       False      0-15 Min
# 3             False         NaN  Arrest Driver        True     16-30 Min
# 4             False         NaN       Citation       False      0-15 Min
# 5             False         NaN       Citation       False      0-15 Min
# 6             False         NaN       Citation       False      0-15 Min
# 7             False         NaN       Citation       False      0-15 Min
# 8             False         NaN       Citation       False      0-15 Min
# 9             False         NaN       Citation       False      0-15 Min
#
#    drugs_related_stop
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# 6               False
# 7               False
# 8               False
# 9               False

# %%
df.tail()
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type stop_outcome  \
# 91736          Speeding             False         NaN      Warning
# 91737         Equipment             False         NaN      Warning
# 91738  Moving violation             False         NaN      Warning
# 91739          Speeding             False         NaN     Citation
# 91740          Speeding             False         NaN     Citation
#
#       is_arrested stop_duration  drugs_related_stop
# 91736       False      0-15 Min               False
# 91737       False      0-15 Min               False
# 91738       False      0-15 Min               False
# 91739       False      0-15 Min               False
# 91740       False      0-15 Min               False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  stop_duration       86408 non-null  object
#  14  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), float64(3), object(10)
# memory usage: 9.3+ MB

# %%
df.describe()
# Out:
#        county_name  driver_age_raw    driver_age
# count          0.0    86414.000000  86120.000000
# mean           NaN     1970.491228     34.011333
# std            NaN      110.914909     12.738564
# min            NaN        0.000000     15.000000
# 25%            NaN     1967.000000     23.000000
# 50%            NaN     1980.000000     31.000000
# 75%            NaN     1987.000000     43.000000
# max            NaN     8801.000000     99.000000

# %%
df.shape[0]
# Out:
# 91741

# %%
df.shape[1]
# Out:
# 15

# %%
df.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
df.drop('county_name', axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   driver_gender       86406 non-null  object
#  3   driver_age_raw      86414 non-null  float64
#  4   driver_age          86120 non-null  float64
#  5   driver_race         86408 non-null  object
#  6   violation_raw       86408 non-null  object
#  7   violation           86408 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   search_type         3196 non-null   object
#  10  stop_outcome        86408 non-null  object
#  11  is_arrested         86408 non-null  object
#  12  stop_duration       86408 non-null  object
#  13  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), float64(2), object(10)
# memory usage: 8.6+ MB

# %%
df1 = df.copy()
df1
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# 0           White                        Speeding          Speeding
# 1           White                        Speeding          Speeding
# 2           White                        Speeding          Speeding
# 3           White                Call for Service             Other
# 4           White                        Speeding          Speeding
# ...           ...                             ...               ...
# 91736       White                        Speeding          Speeding
# 91737       White  Equipment/Inspection Violation         Equipment
# 91738       White         Other Traffic Violation  Moving violation
# 91739       White                        Speeding          Speeding
# 91740    Hispanic                        Speeding          Speeding
#
#        search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0                 False         NaN       Citation       False      0-15 Min
# 1                 False         NaN       Citation       False      0-15 Min
# 2                 False         NaN       Citation       False      0-15 Min
# 3                 False         NaN  Arrest Driver        True     16-30 Min
# 4                 False         NaN       Citation       False      0-15 Min
# ...                 ...         ...            ...         ...           ...
# 91736             False         NaN        Warning       False      0-15 Min
# 91737             False         NaN        Warning       False      0-15 Min
# 91738             False         NaN        Warning       False      0-15 Min
# 91739             False         NaN       Citation       False      0-15 Min
# 91740             False         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 91736               False
# 91737               False
# 91738               False
# 91739               False
# 91740               False
#
# [91741 rows x 14 columns]

# %%
df1.drop('stop_date', axis = 1, inplace = True)

# %%
df1.head
# Out:
# <bound method NDFrame.head of       stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0         01:55             M          1985.0        20.0       White
# 1         08:15             M          1965.0        40.0       White
# 2         23:15             M          1972.0        33.0       White
# 3         17:15             M          1986.0        19.0       White
# 4         10:00             F          1984.0        21.0       White
# ...         ...           ...             ...         ...         ...
# 91736     20:27             M          1986.0        29.0       White
# 91737     20:35             F          1982.0        33.0       White
# 91738     20:45             M          1992.0        23.0       White
# 91739     21:42             M          1993.0        22.0       White
# 91740     22:46             M          1959.0        56.0    Hispanic
#
#                         violation_raw         violation  search_conducted  \
# 0                            Speeding          Speeding             False
# 1                            Speeding          Speeding             False
# 2                            Speeding          Speeding             False
# 3                    Call for Service             Other             False
# 4                            Speeding          Speeding             False
# ...                               ...               ...               ...
# 91736                        Speeding          Speeding             False
# 91737  Equipment/Inspection Violation         Equipment             False
# 91738         Other Traffic Violation  Moving violation             False
# 91739                        Speeding          Speeding             False
# 91740                        Speeding          Speeding             False
#
#       search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# 0             NaN       Citation       False      0-15 Min               False
# 1             NaN       Citation       False      0-15 Min               False
# 2             NaN       Citation       False      0-15 Min               False
# 3             NaN  Arrest Driver        True     16-30 Min               False
# 4             NaN       Citation       False      0-15 Min               False
# ...           ...            ...         ...           ...                 ...
# 91736         NaN        Warning       False      0-15 Min               False
# 91737         NaN        Warning       False      0-15 Min               False
# 91738         NaN        Warning       False      0-15 Min               False
# 91739         NaN       Citation       False      0-15 Min               False
# 91740         NaN       Citation       False      0-15 Min               False
#
# [91741 rows x 13 columns]>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_time           91741 non-null  object
#  1   driver_gender       86406 non-null  object
#  2   driver_age_raw      86414 non-null  float64
#  3   driver_age          86120 non-null  float64
#  4   driver_race         86408 non-null  object
#  5   violation_raw       86408 non-null  object
#  6   violation           86408 non-null  object
#  7   search_conducted    91741 non-null  bool
#  8   search_type         3196 non-null   object
#  9   stop_outcome        86408 non-null  object
#  10  is_arrested         86408 non-null  object
#  11  stop_duration       86408 non-null  object
#  12  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), float64(2), object(9)
# memory usage: 7.9+ MB

# %%
df1.drop(df1.iloc[[],[0,2,3,4,5,7,8,9,10,11,12]],axis=1,inplace=True)

# %%
df1.head()
# Out:
#   driver_gender violation
# 0             M  Speeding
# 1             M  Speeding
# 2             M  Speeding
# 3             M     Other
# 4             F  Speeding

# %%
df1.driver_gender.value_counts()
# Out:
# driver_gender
# M    62895
# F    23511
# Name: count, dtype: int64

# %%
df1.driver_gender.value_counts(normalize=True) # normalize gives the percentages
# Out:
# driver_gender
# M    0.727901
# F    0.272099
# Name: proportion, dtype: float64

# %%
df.violation.value_counts()
# Out:
# violation
# Speeding               48463
# Moving violation       16224
# Equipment              11020
# Other                   4317
# Registration/plates     3432
# Seat belt               2952
# Name: count, dtype: int64

# %%
df1.violation.value_counts(normalize=True)
# Out:
# violation
# Speeding               0.560862
# Moving violation       0.187760
# Equipment              0.127534
# Other                  0.049961
# Registration/plates    0.039719
# Seat belt              0.034164
# Name: proportion, dtype: float64

# %%
df1[df1.violation == 'Speeding'].driver_gender.value_counts() #filtring
# Out:
# driver_gender
# M    32979
# F    15482
# Name: count, dtype: int64

# %%
df1[df.violation == 'Speeding'].driver_gender.value_counts(normalize = True)
# Out:
# driver_gender
# M    0.680527
# F    0.319473
# Name: proportion, dtype: float64

# %%
df1[df.driver_gender == 'M'].violation.value_counts()
# Out:
# violation
# Speeding               32979
# Moving violation       13020
# Equipment               8533
# Other                   3627
# Registration/plates     2419
# Seat belt               2317
# Name: count, dtype: int64

# %%
df1[df.driver_gender == 'M'].violation.value_counts(normalize = True)
# Out:
# violation
# Speeding               0.524350
# Moving violation       0.207012
# Equipment              0.135671
# Other                  0.057668
# Registration/plates    0.038461
# Seat belt              0.036839
# Name: proportion, dtype: float64

# %%
df1[df1.driver_gender == 'F'].violation.value_counts()
# Out:
# violation
# Speeding               15482
# Moving violation        3204
# Equipment               2487
# Registration/plates     1013
# Other                    690
# Seat belt                635
# Name: count, dtype: int64

# %%
df1[df1.driver_gender == 'F'].violation.value_counts(normalize = True)
# Out:
# violation
# Speeding               0.658500
# Moving violation       0.136277
# Equipment              0.105780
# Registration/plates    0.043086
# Other                  0.029348
# Seat belt              0.027009
# Name: proportion, dtype: float64

# %%
df2 = df.copy()
df2
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# 0           White                        Speeding          Speeding
# 1           White                        Speeding          Speeding
# 2           White                        Speeding          Speeding
# 3           White                Call for Service             Other
# 4           White                        Speeding          Speeding
# ...           ...                             ...               ...
# 91736       White                        Speeding          Speeding
# 91737       White  Equipment/Inspection Violation         Equipment
# 91738       White         Other Traffic Violation  Moving violation
# 91739       White                        Speeding          Speeding
# 91740    Hispanic                        Speeding          Speeding
#
#        search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0                 False         NaN       Citation       False      0-15 Min
# 1                 False         NaN       Citation       False      0-15 Min
# 2                 False         NaN       Citation       False      0-15 Min
# 3                 False         NaN  Arrest Driver        True     16-30 Min
# 4                 False         NaN       Citation       False      0-15 Min
# ...                 ...         ...            ...         ...           ...
# 91736             False         NaN        Warning       False      0-15 Min
# 91737             False         NaN        Warning       False      0-15 Min
# 91738             False         NaN        Warning       False      0-15 Min
# 91739             False         NaN       Citation       False      0-15 Min
# 91740             False         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 91736               False
# 91737               False
# 91738               False
# 91739               False
# 91740               False
#
# [91741 rows x 14 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   driver_gender       86406 non-null  object
#  3   driver_age_raw      86414 non-null  float64
#  4   driver_age          86120 non-null  float64
#  5   driver_race         86408 non-null  object
#  6   violation_raw       86408 non-null  object
#  7   violation           86408 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   search_type         3196 non-null   object
#  10  stop_outcome        86408 non-null  object
#  11  is_arrested         86408 non-null  object
#  12  stop_duration       86408 non-null  object
#  13  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), float64(2), object(10)
# memory usage: 8.6+ MB

# %%
df2.drop(df2.iloc[[],[0,1,3,4,5,6,7,9,10,11,12,13]], axis = 1, inplace = True)

# %%
df2.head()
# Out:
#   driver_gender  search_conducted
# 0             M             False
# 1             M             False
# 2             M             False
# 3             M             False
# 4             F             False

# %%
df2.driver_gender.value_counts()
# Out:
# driver_gender
# M    62895
# F    23511
# Name: count, dtype: int64

# %%
df2[df2.search_conducted == False].driver_gender.value_counts()
# Out:
# driver_gender
# M    60170
# F    23040
# Name: count, dtype: int64

# %%
df2[df2.search_conducted == True].driver_gender.value_counts()
# Out:
# driver_gender
# M    2725
# F     471
# Name: count, dtype: int64

# %%
df3 = df.copy()
df3
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# 0           White                        Speeding          Speeding
# 1           White                        Speeding          Speeding
# 2           White                        Speeding          Speeding
# 3           White                Call for Service             Other
# 4           White                        Speeding          Speeding
# ...           ...                             ...               ...
# 91736       White                        Speeding          Speeding
# 91737       White  Equipment/Inspection Violation         Equipment
# 91738       White         Other Traffic Violation  Moving violation
# 91739       White                        Speeding          Speeding
# 91740    Hispanic                        Speeding          Speeding
#
#        search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0                 False         NaN       Citation       False      0-15 Min
# 1                 False         NaN       Citation       False      0-15 Min
# 2                 False         NaN       Citation       False      0-15 Min
# 3                 False         NaN  Arrest Driver        True     16-30 Min
# 4                 False         NaN       Citation       False      0-15 Min
# ...                 ...         ...            ...         ...           ...
# 91736             False         NaN        Warning       False      0-15 Min
# 91737             False         NaN        Warning       False      0-15 Min
# 91738             False         NaN        Warning       False      0-15 Min
# 91739             False         NaN       Citation       False      0-15 Min
# 91740             False         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 91736               False
# 91737               False
# 91738               False
# 91739               False
# 91740               False
#
# [91741 rows x 14 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   driver_gender       86406 non-null  object
#  3   driver_age_raw      86414 non-null  float64
#  4   driver_age          86120 non-null  float64
#  5   driver_race         86408 non-null  object
#  6   violation_raw       86408 non-null  object
#  7   violation           86408 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   search_type         3196 non-null   object
#  10  stop_outcome        86408 non-null  object
#  11  is_arrested         86408 non-null  object
#  12  stop_duration       86408 non-null  object
#  13  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), float64(2), object(10)
# memory usage: 8.6+ MB

# %%
  df3.drop(df3.iloc[[], [0,1,2,3,4,5,6,9,10,11,12,13]], axis = 1, inplace = True)

# %%
df3.head()
# Out:
#   violation  search_conducted
# 0  Speeding             False
# 1  Speeding             False
# 2  Speeding             False
# 3     Other             False
# 4  Speeding             False

# %%
df3[df3.search_conducted == True].violation.value_counts()
# Out:
# violation
# Speeding               957
# Moving violation       895
# Equipment              704
# Registration/plates    334
# Other                  210
# Seat belt               96
# Name: count, dtype: int64

# %%
df3[df3.search_conducted == True].violation.value_counts(normalize=True)
# Out:
# violation
# Speeding               0.299437
# Moving violation       0.280038
# Equipment              0.220275
# Registration/plates    0.104506
# Other                  0.065707
# Seat belt              0.030038
# Name: proportion, dtype: float64

# %%
df4 = df.copy()
df4
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# 0           White                        Speeding          Speeding
# 1           White                        Speeding          Speeding
# 2           White                        Speeding          Speeding
# 3           White                Call for Service             Other
# 4           White                        Speeding          Speeding
# ...           ...                             ...               ...
# 91736       White                        Speeding          Speeding
# 91737       White  Equipment/Inspection Violation         Equipment
# 91738       White         Other Traffic Violation  Moving violation
# 91739       White                        Speeding          Speeding
# 91740    Hispanic                        Speeding          Speeding
#
#        search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0                 False         NaN       Citation       False      0-15 Min
# 1                 False         NaN       Citation       False      0-15 Min
# 2                 False         NaN       Citation       False      0-15 Min
# 3                 False         NaN  Arrest Driver        True     16-30 Min
# 4                 False         NaN       Citation       False      0-15 Min
# ...                 ...         ...            ...         ...           ...
# 91736             False         NaN        Warning       False      0-15 Min
# 91737             False         NaN        Warning       False      0-15 Min
# 91738             False         NaN        Warning       False      0-15 Min
# 91739             False         NaN       Citation       False      0-15 Min
# 91740             False         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 91736               False
# 91737               False
# 91738               False
# 91739               False
# 91740               False
#
# [91741 rows x 14 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   driver_gender       86406 non-null  object
#  3   driver_age_raw      86414 non-null  float64
#  4   driver_age          86120 non-null  float64
#  5   driver_race         86408 non-null  object
#  6   violation_raw       86408 non-null  object
#  7   violation           86408 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   search_type         3196 non-null   object
#  10  stop_outcome        86408 non-null  object
#  11  is_arrested         86408 non-null  object
#  12  stop_duration       86408 non-null  object
#  13  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), float64(2), object(10)
# memory usage: 8.6+ MB

# %%
df4.drop(df4.iloc[[],[0,1,3,4,5,6,9,10,11,12,13]], axis = 1, inplace = True)

# %%
df4.head()
# Out:
#   driver_gender violation  search_conducted
# 0             M  Speeding             False
# 1             M  Speeding             False
# 2             M  Speeding             False
# 3             M     Other             False
# 4             F  Speeding             False

# %%
df4[df4.search_conducted == True].violation.value_counts()
# Out:
# violation
# Speeding               957
# Moving violation       895
# Equipment              704
# Registration/plates    334
# Other                  210
# Seat belt               96
# Name: count, dtype: int64

# %%
df4.groupby(['driver_gender', 'violation']).search_conducted.value_counts()
# Out:
# driver_gender  violation            search_conducted
# F              Equipment            False                2381
#                                     True                  106
#                Moving violation     False                3088
#                                     True                  116
#                Other                False                 651
#                                     True                   39
#                Registration/plates  False                 946
#                                     True                   67
#                Seat belt            False                 627
#                                     True                    8
#                Speeding             False               15347
#                                     True                  135
# M              Equipment            False                7935
#                                     True                  598
#                Moving violation     False               12241
#                                     True                  779
#                Other                False                3456
#                                     True                  171
#                Registration/plates  False                2152
#                                     True                  267
#                Seat belt            False                2229
#                                     True                   88
#                Speeding             False               32157
#                                     True                  822
# Name: count, dtype: int64

# %%
df4.groupby(['driver_gender', 'search_conducted']).violation.value_counts()
# Out:
# driver_gender  search_conducted  violation
# F              False             Speeding               15347
#                                  Moving violation        3088
#                                  Equipment               2381
#                                  Registration/plates      946
#                                  Other                    651
#                                  Seat belt                627
#                True              Speeding                 135
#                                  Moving violation         116
#                                  Equipment                106
#                                  Registration/plates       67
#                                  Other                     39
#                                  Seat belt                  8
# M              False             Speeding               32157
#                                  Moving violation       12241
#                                  Equipment               7935
#                                  Other                   3456
#                                  Seat belt               2229
#                                  Registration/plates     2152
#                True              Speeding                 822
#                                  Moving violation         779
#                                  Equipment                598
#                                  Registration/plates      267
#                                  Other                    171
#                                  Seat belt                 88
# Name: count, dtype: int64

# %%
df5 = df.copy()
df5
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# 0           White                        Speeding          Speeding
# 1           White                        Speeding          Speeding
# 2           White                        Speeding          Speeding
# 3           White                Call for Service             Other
# 4           White                        Speeding          Speeding
# ...           ...                             ...               ...
# 91736       White                        Speeding          Speeding
# 91737       White  Equipment/Inspection Violation         Equipment
# 91738       White         Other Traffic Violation  Moving violation
# 91739       White                        Speeding          Speeding
# 91740    Hispanic                        Speeding          Speeding
#
#        search_conducted search_type   stop_outcome is_arrested stop_duration  \
# 0                 False         NaN       Citation       False      0-15 Min
# 1                 False         NaN       Citation       False      0-15 Min
# 2                 False         NaN       Citation       False      0-15 Min
# 3                 False         NaN  Arrest Driver        True     16-30 Min
# 4                 False         NaN       Citation       False      0-15 Min
# ...                 ...         ...            ...         ...           ...
# 91736             False         NaN        Warning       False      0-15 Min
# 91737             False         NaN        Warning       False      0-15 Min
# 91738             False         NaN        Warning       False      0-15 Min
# 91739             False         NaN       Citation       False      0-15 Min
# 91740             False         NaN       Citation       False      0-15 Min
#
#        drugs_related_stop
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# ...                   ...
# 91736               False
# 91737               False
# 91738               False
# 91739               False
# 91740               False
#
# [91741 rows x 14 columns]
