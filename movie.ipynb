# %%
 import pandas as pd
# !pip install ipython
from IPython.display import HTML
# Out:
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython) (71.0.4)
# Collecting jedi>=0.16 (from ipython)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython) (0.2.13)
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.8 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.19.1

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/movies_complete.csv')

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# 3      Comedy|Drama|Romance                             NaN                en
# 4                    Comedy  Father of the Bride Collection                en
#
#    budget_musd  revenue_musd  \
# 0         30.0    373.554033
# 1         65.0    262.797249
# 2          NaN           NaN
# 3         16.0     81.452156
# 4          NaN     76.578911
#
#                                 production_companies  ... vote_average  \
# 0                            Pixar Animation Studios  ...          7.7
# 1  TriStar Pictures|Teitler Film|Interscope Commu...  ...          6.9
# 2                        Warner Bros.|Lancaster Gate  ...          6.5
# 3             Twentieth Century Fox Film Corporation  ...          6.1
# 4          Sandollar Productions|Touchstone Pictures  ...          5.7
#
#    popularity  runtime                                           overview  \
# 0   21.946943     81.0  Led by Woody, Andy's toys live happily in his ...
# 1   17.015539    104.0  When siblings Judy and Peter discover an encha...
# 2   11.712900    101.0  A family wedding reignites the ancient feud be...
# 3    3.859495    127.0  Cheated on, mistreated and stepped on, the wom...
# 4    8.387519    106.0  Just when George Banks has recovered from his ...
#
#    spoken_languages                                        poster_path  \
# 0           English  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  English|Français  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2           English  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3           English  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4           English  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                                                 cast cast_size crew_size  \
# 0  Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...        13       106
# 1  Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...        26        16
# 2  Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...         7         4
# 3  Whitney Houston|Angela Bassett|Loretta Devine|...        10        10
# 4  Steve Martin|Diane Keaton|Martin Short|Kimberl...        12         7
#
#           director
# 0    John Lasseter
# 1     Joe Johnston
# 2    Howard Deutch
# 3  Forest Whitaker
# 4    Charles Shyer
#
# [5 rows x 22 columns]

# %%
df.tail()
# Out:
#            id                title  \
# 44686  439050               Subdue
# 44687  111109  Century of Birthing
# 44688   67758             Betrayal
# 44689  227506     Satan Triumphant
# 44690  461257             Queerama
#
#                                           tagline release_date  \
# 44686  Rising and falling between a man and woman          NaN
# 44687                                         NaN   2011-11-17
# 44688                      A deadly game of wits.   2003-08-01
# 44689                                         NaN   1917-10-21
# 44690                                         NaN   2017-06-09
#
#                       genres belongs_to_collection original_language  \
# 44686           Drama|Family                   NaN                fa
# 44687                  Drama                   NaN                tl
# 44688  Action|Drama|Thriller                   NaN                en
# 44689                    NaN                   NaN                en
# 44690                    NaN                   NaN                en
#
#        budget_musd  revenue_musd     production_companies  ... vote_average  \
# 44686          NaN           NaN                      NaN  ...          4.0
# 44687          NaN           NaN              Sine Olivia  ...          9.0
# 44688          NaN           NaN  American World Pictures  ...          3.8
# 44689          NaN           NaN                Yermoliev  ...          NaN
# 44690          NaN           NaN                      NaN  ...          NaN
#
#        popularity  runtime                                           overview  \
# 44686    0.072051     90.0        Rising and falling between a man and woman.
# 44687    0.178241    360.0  An artist struggles to finish his work while a...
# 44688    0.903007     90.0  When one of her hits goes wrong, a professiona...
# 44689    0.003503     87.0  In a small town live two brothers, one a minis...
# 44690    0.163015     75.0  50 years after decriminalisation of homosexual...
#
#        spoken_languages                                        poster_path  \
# 44686             فارسی  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687               NaN  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688           English  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689               NaN  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690           English  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                                                     cast cast_size crew_size  \
# 44686            Leila Hatami|Kourosh Tahami|Elham Korda         3         9
# 44687  Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...        11         6
# 44688  Erika Eleniak|Adam Baldwin|Julie du Page|James...        15         5
# 44689  Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...         5         2
# 44690                                                NaN         0         1
#
#                director
# 44686  Hamid Nematollah
# 44687          Lav Diaz
# 44688    Mark L. Lester
# 44689  Yakov Protazanov
# 44690     Daisy Asquith
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  object
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
#  14  runtime                43179 non-null  float64
#  15  overview               43740 non-null  object
#  16  spoken_languages       41094 non-null  object
#  17  poster_path            44467 non-null  object
#  18  cast                   42502 non-null  object
#  19  cast_size              44691 non-null  int64
#  20  crew_size              44691 non-null  int64
#  21  director               43960 non-null  object
# dtypes: float64(6), int64(3), object(13)
# memory usage: 7.5+ MB

# %%
df['genres'] [0]
# Out:
# 'Animation|Comedy|Family'

# %%
df.genres [0]
# Out:
# 'Animation|Comedy|Family'

# %%
df['cast'] [0]
# Out:
# 'Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette'

# %%
df.describe()
# Out:
#                   id  budget_musd  revenue_musd    vote_count  vote_average  \
# count   44691.000000  8854.000000   7385.000000  44691.000000  42077.000000
# mean   107186.242845    21.669886     68.968649    111.653778      6.003341
# std    111806.362236    34.359837    146.608966    495.322313      1.281060
# min         2.000000     0.000001      0.000001      0.000000      0.000000
# 25%     26033.500000     2.000000      2.405420      3.000000      5.300000
# 50%     59110.000000     8.200000     16.872671     10.000000      6.100000
# 75%    154251.000000    25.000000     67.642693     35.000000      6.800000
# max    469172.000000   380.000000   2787.965087  14075.000000     10.000000
#
#          popularity       runtime     cast_size     crew_size
# count  44691.000000  43179.000000  44691.000000  44691.000000
# mean       2.957460     97.566850     12.479090     10.313643
# std        6.040008     34.653409     12.124663     15.892154
# min        0.000000      1.000000      0.000000      0.000000
# 25%        0.402038     86.000000      6.000000      2.000000
# 50%        1.150055     95.000000     10.000000      6.000000
# 75%        3.768882    107.000000     15.000000     12.000000
# max      547.488298   1256.000000    313.000000    435.000000

# %%
df.hist(figsize=(20, 12), bins= 100)
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'budget_musd'}>,
#         <Axes: title={'center': 'revenue_musd'}>],
#        [<Axes: title={'center': 'vote_count'}>,
#         <Axes: title={'center': 'vote_average'}>,
#         <Axes: title={'center': 'popularity'}>],
#        [<Axes: title={'center': 'runtime'}>,
#         <Axes: title={'center': 'cast_size'}>,
#         <Axes: title={'center': 'crew_size'}>]], dtype=object)

# %%
df['budget_musd'].head(10)
# Out:
# 0    30.0
# 1    65.0
# 2     NaN
# 3    16.0
# 4     NaN
# 5    60.0
# 6    58.0
# 7     NaN
# 8    35.0
# 9    58.0
# Name: budget_musd, dtype: float64

# %%
df['budget_musd'].value_counts(dropna = False).head(20)
# Out:
# budget_musd
# NaN     35837
# 5.0       286
# 10.0      258
# 20.0      243
# 2.0       241
# 15.0      226
# 3.0       220
# 25.0      206
# 1.0       195
# 30.0      189
# 4.0       180
# 6.0       173
# 12.0      171
# 40.0      166
# 8.0       155
# 35.0      141
# 0.5       141
# 7.0       137
# 50.0      124
# 1.5       119
# Name: count, dtype: int64

# %%
df['vote_average'].value_counts(dropna = False).head(10)
# Out:
# vote_average
# NaN    2614
# 6.0    2421
# 5.0    1969
# 7.0    1859
# 6.5    1705
# 6.3    1583
# 5.5    1369
# 5.8    1358
# 6.4    1343
# 6.7    1328
# Name: count, dtype: int64

# %%
df.describe(include = 'object')
# Out:
#              title                 tagline release_date genres  \
# count        44691                   20284        44657  42586
# unique       41605                   20171        17225   4044
# top     Cinderella  Based on a true story.   2008-01-01  Drama
# freq            11                       7          133   4935
#
#        belongs_to_collection original_language       production_companies  \
# count                   4463             44681                      33356
# unique                  1691                89                      22537
# top          The Bowery Boys                en  Metro-Goldwyn-Mayer (MGM)
# freq                      29             31755                        741
#
#             production_countries                              overview  \
# count                      38835                                 43740
# unique                      2377                                 43715
# top     United States of America  Adaptation of the Jane Austen novel.
# freq                       17723                                     3
#
#        spoken_languages                                        poster_path  \
# count             41094                                              44467
# unique             1828                                              44456
# top             English  <img src='http://image.tmdb.org/t/p/w185//qW1o...
# freq              22189                                                  3
#
#                   cast   director
# count            42502      43960
# unique           42166      17349
# top     Georges Méliès  John Ford
# freq                24         66

# %%
df[df['title'] == 'Cinderella']
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
# 44633   98604  Cinderella                                 NaN   2012-02-14
#
#                                       genres  belongs_to_collection  \
# 984         Family|Fantasy|Animation|Romance  Cinderella Collection
# 12988  TV Movie|Family|Fantasy|Music|Romance                    NaN
# 23254                          Fantasy|Drama                    NaN
# 23265               Animation|Family|Fantasy                    NaN
# 28073                        Family|TV Movie                    NaN
# 28340           Romance|Fantasy|Family|Drama                    NaN
# 33805                  Comedy|Family|Fantasy                    NaN
# 35114                          Drama|Romance                    NaN
# 35116                                    NaN                    NaN
# 40439  Fantasy|Horror|Science Fiction|Family                    NaN
# 44633                         Comedy|Romance                    NaN
#
#       original_language  budget_musd  revenue_musd  \
# 984                  en          2.9    263.591415
# 12988                en          NaN           NaN
# 23254                en          NaN           NaN
# 23265                en          NaN           NaN
# 28073                en          NaN           NaN
# 28340                en         95.0    543.514353
# 33805                ru          NaN           NaN
# 35114                en          NaN           NaN
# 35116                en          NaN           NaN
# 40439                fr          NaN           NaN
# 44633                ru          NaN           NaN
#
#                                     production_companies  ... vote_average  \
# 984           RKO Radio Pictures|Walt Disney Productions  ...          6.8
# 12988  Walt Disney Television|Citadel Entertainment|S...  ...          6.1
# 23254                                                NaN  ...          5.4
# 23265                            GoodTimes Entertainment  ...          6.0
# 28073  Beta Film|Lux Vide|ARD/Degeto Film GmbH|Rai Fi...  ...          5.3
# 28340  Walt Disney Pictures|Genre Films|Beagle Pug Fi...  ...          6.7
# 33805                                            Lenfilm  ...          4.8
# 35114                                                NaN  ...          5.9
# 35116                                                NaN  ...          5.6
# 40439                           Star-Film|Georges Méliès  ...          5.5
# 44633             Channel One Russia|Central Partnership  ...          4.6
#
#        popularity  runtime                                           overview  \
# 984     14.436858     74.0  Cinderella has faith her dreams of a better li...
# 12988    2.102013     88.0  Updated version of the classic Rodgers and Ham...
# 23254    0.361288     52.0  Based on Charles Perrault's fairy tale: Cinder...
# 23265    2.154873     48.0  Cinderella, the beautiful and kind-hearted rag...
# 28073    0.987462    180.0  Once upon a time in post-war Rome: 13-year old...
# 28340   19.801128    105.0  When her father unexpectedly passes away, youn...
# 33805    0.486073     80.0  Based on a classic fairytale "Cinderella" bril...
# 35114    0.209552     77.0  The first of three TV-versions of the classic ...
# 35116    1.085134     90.0  Cinderella (named Zezolla) and her family live...
# 40439    1.301063      5.0  A fairy godmother magically turns Cinderella's...
# 44633    0.803588     91.0  Masha Krapivina - is yet beautiful, and not th...
#
#        spoken_languages                                        poster_path  \
# 984             English  <img src='http://image.tmdb.org/t/p/w185//avz6...
# 12988           English  <img src='http://image.tmdb.org/t/p/w185//54aw...
# 23254           English  <img src='http://image.tmdb.org/t/p/w185//bL1K...
# 23265         Afrikaans  <img src='http://image.tmdb.org/t/p/w185//rbzG...
# 28073           English  <img src='http://image.tmdb.org/t/p/w185//wjZK...
# 28340           English  <img src='http://image.tmdb.org/t/p/w185//iH4C...
# 33805           Pусский  <img src='http://image.tmdb.org/t/p/w185//p41r...
# 35114           English  <img src='http://image.tmdb.org/t/p/w185//cB6I...
# 35116           English  <img src='http://image.tmdb.org/t/p/w185//gMYk...
# 40439       No Language  <img src='http://image.tmdb.org/t/p/w185//cf0g...
# 44633           Pусский  <img src='http://image.tmdb.org/t/p/w185//nvGe...
#
#                                                     cast cast_size crew_size  \
# 984    Ilene Woods|Eleanor Audley|Lucille Bliss|Verna...        11        50
# 12988  Brandy Norwood|Whitney Houston|Whoopi Goldberg...         5         1
# 23254  Mary Pickford|Owen Moore|Isabel Vernon|Georgia...         7         2
# 23265  Tony Ail|Nathan Aswell|Chera Bailey|Kathleen B...         7         3
# 28073  Vanessa Hessler|Flavio Parenti|Natalia Wörner|...        14        11
# 28340  Lily James|Cate Blanchett|Richard Madden|Helen...        78        80
# 33805  Yanina Zhejmo|Aleksei Konsovsky|Faina Ranevska...         6         4
# 35114  Julie Andrews|Howard Lindsay|Howard Lindsay|Il...         9        10
# 35116  Kathleen Turner|Katrin Cartlidge|David Warner|...        10         6
# 40439  Georges Méliès|Barral|Bleuette Bernon|Carmely|...         6         2
# 44633  Kristina Asmus|Nikita Efremov|Artyom Tkachenko...        18         4
#
#                    director
# 984          Clyde Geronimi
# 12988         Robert Iscove
# 23254        James Kirkwood
# 23265      Toshiyuki Hiruma
# 28073      Christian Duguay
# 28340       Kenneth Branagh
# 33805  Nadezhda Kosheverova
# 35114          Ralph Nelson
# 35116         Beeban Kidron
# 40439        Georges Méliès
# 44633         Sergey Ivanov
#
# [11 rows x 22 columns]

# %%
df_best = df[['poster_path','title', 'budget_musd', 'revenue_musd', 'vote_count','vote_average', 'popularity']].copy()
df_best['profit_musd'] = df_best['budget_musd'].sub(df_best['revenue_musd'])
df_best['return'] = df_best['revenue_musd'].div(df_best['budget_musd'])

# %%
df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story         30.0    373.554033      5415.0
# 1                          Jumanji         65.0    262.797249      2413.0
# 2                 Grumpier Old Men          NaN           NaN        92.0
# 3                Waiting to Exhale         16.0     81.452156        34.0
# 4      Father of the Bride Part II          NaN     76.578911       173.0
# ...                            ...          ...           ...         ...
# 44686                       Subdue          NaN           NaN         1.0
# 44687          Century of Birthing          NaN           NaN         3.0
# 44688                     Betrayal          NaN           NaN         6.0
# 44689             Satan Triumphant          NaN           NaN         0.0
# 44690                     Queerama          NaN           NaN         0.0
#
#        vote_average  popularity  profit_musd     return
# 0               7.7   21.946943  -343.554033  12.451801
# 1               6.9   17.015539  -197.797249   4.043035
# 2               6.5   11.712900          NaN        NaN
# 3               6.1    3.859495   -65.452156   5.090760
# 4               5.7    8.387519          NaN        NaN
# ...             ...         ...          ...        ...
# 44686           4.0    0.072051          NaN        NaN
# 44687           9.0    0.178241          NaN        NaN
# 44688           3.8    0.903007          NaN        NaN
# 44689           NaN    0.003503          NaN        NaN
# 44690           NaN    0.163015          NaN        NaN
#
# [44691 rows x 9 columns]

# %%
df_best.columns = ['', 'Title', 'Budget', 'Revenue', 'Votes', 'Average Rating', 'Popularity', 'Profit', 'ROI']
df_best.set_index('Title', inplace = True)

# %%
df_best
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                                        ...
# Subdue                       <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing          <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                     <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant             <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                     <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              Budget     Revenue   Votes  Average Rating  \
# Title
# Toy Story                      30.0  373.554033  5415.0             7.7
# Jumanji                        65.0  262.797249  2413.0             6.9
# Grumpier Old Men                NaN         NaN    92.0             6.5
# Waiting to Exhale              16.0   81.452156    34.0             6.1
# Father of the Bride Part II     NaN   76.578911   173.0             5.7
# ...                             ...         ...     ...             ...
# Subdue                          NaN         NaN     1.0             4.0
# Century of Birthing             NaN         NaN     3.0             9.0
# Betrayal                        NaN         NaN     6.0             3.8
# Satan Triumphant                NaN         NaN     0.0             NaN
# Queerama                        NaN         NaN     0.0             NaN
#
#                              Popularity      Profit        ROI
# Title
# Toy Story                     21.946943 -343.554033  12.451801
# Jumanji                       17.015539 -197.797249   4.043035
# Grumpier Old Men              11.712900         NaN        NaN
# Waiting to Exhale              3.859495  -65.452156   5.090760
# Father of the Bride Part II    8.387519         NaN        NaN
# ...                                 ...         ...        ...
# Subdue                         0.072051         NaN        NaN
# Century of Birthing            0.178241         NaN        NaN
# Betrayal                       0.903007         NaN        NaN
# Satan Triumphant               0.003503         NaN        NaN
# Queerama                       0.163015         NaN        NaN
#
# [44691 rows x 8 columns]

# %%
df_best.iloc[0,0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>"

# %%
subset = df_best.iloc[:5, :2]
subset
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                              Budget
# Title
# Toy Story                      30.0
# Jumanji                        65.0
# Grumpier Old Men                NaN
# Waiting to Exhale              16.0
# Father of the Bride Part II     NaN

# %%
HTML(subset.to_html(escape = False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.0</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.0</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
#       <td>16.0</td>
#     </tr>
#     <tr>
#       <th>Father of the Bride Part II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Highest Rated Movies

# %%
df_best.sort_values('Average Rating', ascending = False)
# Out:
#                                                                                                \
# Title
# Portrait of a Young Man in Three Movements                                                NaN
# Brave Revolutionary                         <img src='http://image.tmdb.org/t/p/w185//zAb2...
# Other Voices Other Rooms                    <img src='http://image.tmdb.org/t/p/w185//4ifP...
# The Lion of Thebes                          <img src='http://image.tmdb.org/t/p/w185//tdOc...
# Katt Williams: Priceless: Afterlife         <img src='http://image.tmdb.org/t/p/w185//wKrH...
# ...                                                                                       ...
# Altar of Fire                               <img src='http://image.tmdb.org/t/p/w185//iJ78...
# The Wonders of Aladdin                      <img src='http://image.tmdb.org/t/p/w185//AvfX...
# Deep Hearts                                 <img src='http://image.tmdb.org/t/p/w185//8jI4...
# Satan Triumphant                            <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                                    <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                                             Budget  Revenue  Votes  \
# Title
# Portrait of a Young Man in Three Movements     NaN      NaN    1.0
# Brave Revolutionary                            NaN      NaN    1.0
# Other Voices Other Rooms                       NaN      NaN    1.0
# The Lion of Thebes                             NaN      NaN    1.0
# Katt Williams: Priceless: Afterlife            NaN      NaN    2.0
# ...                                            ...      ...    ...
# Altar of Fire                                  NaN      NaN    0.0
# The Wonders of Aladdin                         NaN      NaN    0.0
# Deep Hearts                                    NaN      NaN    0.0
# Satan Triumphant                               NaN      NaN    0.0
# Queerama                                       NaN      NaN    0.0
#
#                                             Average Rating  Popularity  \
# Title
# Portrait of a Young Man in Three Movements            10.0    0.036471
# Brave Revolutionary                                   10.0    0.318826
# Other Voices Other Rooms                              10.0    0.036680
# The Lion of Thebes                                    10.0    1.783625
# Katt Williams: Priceless: Afterlife                   10.0    0.476007
# ...                                                    ...         ...
# Altar of Fire                                          NaN    0.000000
# The Wonders of Aladdin                                 NaN    0.093498
# Deep Hearts                                            NaN    0.011025
# Satan Triumphant                                       NaN    0.003503
# Queerama                                               NaN    0.163015
#
#                                             Profit  ROI
# Title
# Portrait of a Young Man in Three Movements     NaN  NaN
# Brave Revolutionary                            NaN  NaN
# Other Voices Other Rooms                       NaN  NaN
# The Lion of Thebes                             NaN  NaN
# Katt Williams: Priceless: Afterlife            NaN  NaN
# ...                                            ...  ...
# Altar of Fire                                  NaN  NaN
# The Wonders of Aladdin                         NaN  NaN
# Deep Hearts                                    NaN  NaN
# Satan Triumphant                               NaN  NaN
# Queerama                                       NaN  NaN
#
# [44691 rows x 8 columns]

# %% [markdown]
# Highest ROI Movie

# %%
df_best.sort_values('ROI', ascending= False)
# Out:
#                                                                             \
# Title
# Less Than Zero           <img src='http://image.tmdb.org/t/p/w185//1GY0...
# Modern Times             <img src='http://image.tmdb.org/t/p/w185//7uoi...
# Welcome to Dongmakgol    <img src='http://image.tmdb.org/t/p/w185//5iGV...
# Aquí Entre Nos           <img src='http://image.tmdb.org/t/p/w185//oflx...
# The Karate Kid, Part II  <img src='http://image.tmdb.org/t/p/w185//mSne...
# ...                                                                    ...
# Subdue                   <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing      <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                 <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant         <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                 <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                            Budget     Revenue  Votes  Average Rating  \
# Title
# Less Than Zero           0.000001   12.396383   77.0             6.1
# Modern Times             0.000001    8.500000  881.0             8.1
# Welcome to Dongmakgol    0.000008   33.579813   49.0             7.7
# Aquí Entre Nos           0.000001    2.755584    3.0             6.0
# The Karate Kid, Part II  0.000113  115.103979  457.0             5.9
# ...                           ...         ...    ...             ...
# Subdue                        NaN         NaN    1.0             4.0
# Century of Birthing           NaN         NaN    3.0             9.0
# Betrayal                      NaN         NaN    6.0             3.8
# Satan Triumphant              NaN         NaN    0.0             NaN
# Queerama                      NaN         NaN    0.0             NaN
#
#                          Popularity      Profit           ROI
# Title
# Less Than Zero             4.028679  -12.396382  1.239638e+07
# Modern Times               8.159556   -8.499999  8.500000e+06
# Welcome to Dongmakgol      4.222195  -33.579805  4.197477e+06
# Aquí Entre Nos             0.230075   -2.755583  2.755584e+06
# The Karate Kid, Part II    9.231318 -115.103866  1.018619e+06
# ...                             ...         ...           ...
# Subdue                     0.072051         NaN           NaN
# Century of Birthing        0.178241         NaN           NaN
# Betrayal                   0.903007         NaN           NaN
# Satan Triumphant           0.003503         NaN           NaN
# Queerama                   0.163015         NaN           NaN
#
# [44691 rows x 8 columns]

# %% [markdown]
# Finding Movies That Have More Than 5 Milions of Budget
# And Sorting Them by ROI

# %%
df_best.loc[df_best['Budget'] >= 5].sort_values(by = 'ROI', ascending= False)
# Out:
#                                                                                                    \
# Title
# E.T. the Extra-Terrestrial                      <img src='http://image.tmdb.org/t/p/w185//cBfk...
# My Big Fat Greek Wedding                        <img src='http://image.tmdb.org/t/p/w185//3TB2...
# Star Wars                                       <img src='http://image.tmdb.org/t/p/w185//6FfC...
# Jaws                                            <img src='http://image.tmdb.org/t/p/w185//s2xc...
# Crocodile Dundee                                <img src='http://image.tmdb.org/t/p/w185//kiwO...
# ...                                                                                           ...
# The Blonde with Bare Breasts                    <img src='http://image.tmdb.org/t/p/w185//zBjp...
# Detroit                                         <img src='http://image.tmdb.org/t/p/w185//7APL...
# Good Guys Go to Heaven, Bad Guys Go to Pattaya  <img src='http://image.tmdb.org/t/p/w185//cfVB...
# The Visitors: Bastille Day                      <img src='http://image.tmdb.org/t/p/w185//kBlm...
# House of the Long Shadows                       <img src='http://image.tmdb.org/t/p/w185//21ZG...
#
#                                                    Budget     Revenue   Votes  \
# Title
# E.T. the Extra-Terrestrial                      10.500000  792.965326  3359.0
# My Big Fat Greek Wedding                         5.000000  368.744044   686.0
# Star Wars                                       11.000000  775.398007  6778.0
# Jaws                                             7.000000  470.654000  2628.0
# Crocodile Dundee                                 5.000000  328.203506   512.0
# ...                                                   ...         ...     ...
# The Blonde with Bare Breasts                     7.500000         NaN     3.0
# Detroit                                         34.000000         NaN    67.0
# Good Guys Go to Heaven, Bad Guys Go to Pattaya   5.402000         NaN   153.0
# The Visitors: Bastille Day                      25.868826         NaN   167.0
# House of the Long Shadows                        7.500000         NaN    18.0
#
#                                                 Average Rating  Popularity  \
# Title
# E.T. the Extra-Terrestrial                                 7.3   19.358546
# My Big Fat Greek Wedding                                   6.2    6.719949
# Star Wars                                                  8.1   42.149697
# Jaws                                                       7.5   19.726114
# Crocodile Dundee                                           6.3    7.791212
# ...                                                        ...         ...
# The Blonde with Bare Breasts                               4.0    0.882188
# Detroit                                                    7.3    9.797505
# Good Guys Go to Heaven, Bad Guys Go to Pattaya             5.3    5.613875
# The Visitors: Bastille Day                                 4.0    7.294920
# House of the Long Shadows                                  6.1    1.185515
#
#                                                     Profit        ROI
# Title
# E.T. the Extra-Terrestrial                     -782.465326  75.520507
# My Big Fat Greek Wedding                       -363.744044  73.748809
# Star Wars                                      -764.398007  70.490728
# Jaws                                           -463.654000  67.236286
# Crocodile Dundee                               -323.203506  65.640701
# ...                                                    ...        ...
# The Blonde with Bare Breasts                           NaN        NaN
# Detroit                                                NaN        NaN
# Good Guys Go to Heaven, Bad Guys Go to Pattaya         NaN        NaN
# The Visitors: Bastille Day                             NaN        NaN
# House of the Long Shadows                              NaN        NaN
#
# [5449 rows x 8 columns]

# %% [markdown]
# Filling Missing Value of Budget and Votes Columns

# %%
df_best['Budget'].fillna(0, inplace = True)
df_best['Votes'].fillna(0, inplace = True)
df_best.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44691 entries, Toy Story to Queerama
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0                   44467 non-null  object
#  1   Budget          44691 non-null  float64
#  2   Revenue         7385 non-null   float64
#  3   Votes           44691 non-null  float64
#  4   Average Rating  42077 non-null  float64
#  5   Popularity      44691 non-null  float64
#  6   Profit          5371 non-null   float64
#  7   ROI             5371 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 3.1+ MB

# %%
def best_worst(n , by , ascending = False, min_bud = 0, min_votes = 0):

    df2 = df_best.loc[(df_best['Budget'] >= min_bud) & (df_best['Votes'] >= min_votes),
                     ['', by]].sort_values(by = by, ascending = ascending).head(n).copy()
    return HTML(df2.to_html(escape= False))

# %% [markdown]
# Top Movies Sorted Based Highest Budget

# %%
best_worst(5, 'Budget')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.0</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.0</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.0</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//6ZYOpyhFZrAQIe1BuhqVgzfAdGZ.jpg' style='height:100px;'></td>
#       <td>270.0</td>
#     </tr>
#     <tr>
#       <th>Transformers: The Last Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//s5HQf2Gb3lIO2cRcFwNL9sn1o1o.jpg' style='height:100px;'></td>
#       <td>260.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Top Movies Sorted Based Highest Revenue

# %%
best_worst(5, 'Revenue')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.965087</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.223624</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.034188</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
#       <td>1519.557910</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//rhr4y79GpxQF9IsfJItRXVaoGs4.jpg' style='height:100px;'></td>
#       <td>1513.528810</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Top Movies Sorted Based Highest Profit

# %%
best_worst(5, 'Profit')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>165.710090</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>119.180039</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>111.007242</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//jfIpMh79fGRqYJ6PwZLCntzgxlF.jpg' style='height:100px;'></td>
#       <td>107.447384</td>
#     </tr>
#     <tr>
#       <th>The 13th Warrior</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7pyhR5K1iv67daYw0DfsmsersKA.jpg' style='height:100px;'></td>
#       <td>98.301101</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Find your next movie

# %%
df['genres'][0]
# Out:
# 'Animation|Comedy|Family'

# %%
marks_genres = df['genres'].str.contains('Action') & df['genres'].str.contains('Science Fiction')
marks_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
df['cast'] [0]
# Out:
# 'Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette'

# %% [markdown]
# Create Search Mask for Actors to Find Movies by Bruce Willis

# %%
marks_actor = df ['cast'].str.contains('Bruce Willis')
marks_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %% [markdown]
# V0014: What Are Most Common Words in Movie Titles and Tagline

# %%
from wordcloud import WordCloud

# %%
df['tagline'][1]
# Out:
# 'Roll the dice and unleash the excitement!'

# %%
df['overview'][1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
title = df['title'].dropna()
overview = df['overview'].dropna()
tagline = df['tagline'].dropna()

# %%
''.join(title)
# Out:
# 'Toy StoryJumanjiGrumpier Old MenWaiting to ExhaleFather of the Bride Part IIHeatSabrinaTom and HuckSudden DeathGoldenEyeThe American PresidentDracula: Dead and Loving ItBaltoNixonCutthroat IslandCasinoSense and SensibilityFour RoomsAce Ventura: When Nature CallsMoney TrainGet ShortyCopycatAssassinsPowderLeaving Las VegasOthelloNow and ThenPersuasionThe City of Lost ChildrenShanghai TriadDangerous MindsTwelve MonkeysWings of CourageBabeCarringtonDead Man WalkingAcross the Sea of TimeIt Takes TwoCluelessCry, the Beloved CountryRichard IIIDead PresidentsRestorationMortal KombatTo Die ForHow To Make An American QuiltSe7enPocahontasWhen Night Is FallingThe Usual SuspectsGuardian AngelMighty AphroditeLamericaThe Big GreenGeorgiaKids of the Round TableHome for the HolidaysThe PostmanThe ConfessionalThe Indian in the CupboardEye for an EyeMr. Holland\'s OpusDon\'t Be a Menace to South Central While Drinking Your Juice in the HoodTwo If by SeaBio-DomeLawnmower Man 2: Beyond CyberspaceTwo BitsFrench TwistFridayFrom Dusk Till DawnFair GameKicking and ScreamingLes MiserablesBed of RosesBig BullyScreamersNico IconThe Crossing GuardThe JurorThe White BalloonThings to Do in Denver When You\'re DeadAntonia\'s LineOnce Upon a Time... When We Were ColoredLast Summer in the HamptonsAngels and InsectsWhite SquallDunston Checks InBlack SheepNick of TimeThe Journey of August KingMary ReillyVampire in BrooklynBeautiful GirlsBroken ArrowA Midwinter\'s TaleLa HaineShoppingHeidi Fleiss: Hollywood MadamCity HallBottle RocketMr. WrongUnforgettableHappy GilmoreThe Bridges of Madison CountyNobody Loves MeMuppet Treasure IslandCatwalkHeadless Body in Topless BarBraveheartTaxi DriverRumble in the BronxBefore and AfterMargaret\'s MuseumHappiness Is in the FieldAnne Frank RememberedThe Young Poisoner\'s HandbookIf Lucy FellSteal Big Steal LittleRace the SunThe Boys of St. VincentBoomerangChungking ExpressThe Star MakerFlirting with DisasterThe Neverending Story III: Escape from FantasiaThe Silences of the PalaceJupiter\'s WifePie in the SkyAngelaFrankie StarlightJadeNueba YolSonic OutlawsDown PeriscopeFrom the Journals of Jean SebergMan of the YearThe Neon BibleTargetUp Close & PersonalThe BirdcageVirgin MaryThe Brothers McMullenBad BoysThe Amazing Panda AdventureThe Basketball DiariesAn Awfully Big AdventureAmateurApollo 13Rob RoyThe AddictionBatman ForeverBelle de JourBeyond RangoonBlue in the FaceCanadian BaconCasperClockersCongoCrimson TideCrumbDesperadoDevil in a Blue DressDie Hard: With a VengeanceThe Doom GenerationFeast of JulyFirst KnightFree Willy 2 - The Adventure HomeHackersJeffreyJohnny MnemonicJudge DreddJury DutyKidsLiving in OblivionLord of IllusionsLove & Human RemainsMad LoveMallratsMighty Morphin Power Rangers: The MovieMoonlight and ValentinoMute WitnessNadjaThe NetNine MonthsParty GirlThe ProphecyRecklessSafeThe Scarlet LetterShowgirlsSmokeSomething to Talk AboutSpeciesThe Stars Fell on HenriettaStrange DaysThe Umbrellas of CherbourgThe Tie That BindsThree WishesTotal EclipseTo Wong Foo, Thanks for Everything! Julie NewmarUnder Siege 2: Dark TerritoryUnstrung HeroesUnzippedA Walk in the CloudsWaterworldWhite Man\'s BurdenWild BillThe Browning VersionBushwhackedBurnt by the SunBefore the RainBefore SunriseBilly MadisonThe BabysitterBoys on the SideThe CureCastle FreakCircle of FriendsClerksDon Juan DeMarcoDisclosureDream ManDrop ZoneDestiny Turns on the RadioDeath and the MaidenDolores ClaiborneDumb and DumberEat Drink Man WomanExoticaExit to EdenEd WoodFrench KissForget ParisFar from Home: The Adventures of Yellow DogA Goofy MovieHideawayFlukeFarinelliGordyGumby: The MovieThe Glass ShieldHoop DreamsHeavenly CreaturesHouseguestImmortal BelovedHeavyweightsThe HuntedI.Q.Interview with the VampireJefferson in ParisThe Jerky BoysJuniorJust CauseA Kid in King Arthur\'s CourtKiss of DeathStar WarsLittle WomenA Little PrincessLadybird LadybirdL\'EnferLike Water for ChocolateLegends of the FallMajor PayneLittle OdessaMi Vida LocaLove AffairLosing  ...

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# 3      Comedy|Drama|Romance                             NaN                en
# 4                    Comedy  Father of the Bride Collection                en
#
#    budget_musd  revenue_musd  \
# 0         30.0    373.554033
# 1         65.0    262.797249
# 2          NaN           NaN
# 3         16.0     81.452156
# 4          NaN     76.578911
#
#                                 production_companies  ... vote_average  \
# 0                            Pixar Animation Studios  ...          7.7
# 1  TriStar Pictures|Teitler Film|Interscope Commu...  ...          6.9
# 2                        Warner Bros.|Lancaster Gate  ...          6.5
# 3             Twentieth Century Fox Film Corporation  ...          6.1
# 4          Sandollar Productions|Touchstone Pictures  ...          5.7
#
#    popularity  runtime                                           overview  \
# 0   21.946943     81.0  Led by Woody, Andy's toys live happily in his ...
# 1   17.015539    104.0  When siblings Judy and Peter discover an encha...
# 2   11.712900    101.0  A family wedding reignites the ancient feud be...
# 3    3.859495    127.0  Cheated on, mistreated and stepped on, the wom...
# 4    8.387519    106.0  Just when George Banks has recovered from his ...
#
#    spoken_languages                                        poster_path  \
# 0           English  <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1  English|Français  <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2           English  <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3           English  <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4           English  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                                                 cast cast_size crew_size  \
# 0  Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...        13       106
# 1  Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...        26        16
# 2  Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...         7         4
# 3  Whitney Houston|Angela Bassett|Loretta Devine|...        10        10
# 4  Steve Martin|Diane Keaton|Martin Short|Kimberl...        12         7
#
#           director
# 0    John Lasseter
# 1     Joe Johnston
# 2    Howard Deutch
# 3  Forest Whitaker
# 4    Charles Shyer
#
# [5 rows x 22 columns]

# %% [markdown]
# Create a Column For Franchise

# %%
df['Franchise'] = df['belongs_to_collection'].notna()

# %%
df['Franchise']
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: Franchise, Length: 44691, dtype: bool

# %%
df['Franchise'].value_counts()
# Out:
# Franchise
# False    40228
# True      4463
# Name: count, dtype: int64

# %% [markdown]
# Franchise vs. Stand-Alone: Average Revenue

# %%
df.groupby('Franchise')['revenue_musd'].mean()
# Out:
# Franchise
# False     44.742814
# True     165.708193
# Name: revenue_musd, dtype: float64

# %% [markdown]
# Franchise Vs. Stand-Alone : ROI & Profitability

# %%
df['ROI'] = df['revenue_musd'].div(df['budget_musd'])
df.groupby('Franchise')['ROI'].median()
# Out:
# Franchise
# False    1.619699
# True     3.709195
# Name: ROI, dtype: float64

# %%
df.groupby('Franchise')['popularity'].mean()
# Out:
# Franchise
# False    2.592726
# True     6.245051
# Name: popularity, dtype: float64

# %%
df.groupby('Franchise')['vote_average'].mean()
# Out:
# Franchise
# False    6.008787
# True     5.956806
# Name: vote_average, dtype: float64

# %%
df.groupby('Franchise').agg({
    'budget_musd': 'mean',
    'revenue_musd' : 'mean',
    'vote_average' : 'mean',
    'popularity' : 'mean',
    'ROI' : 'median',
    'vote_count' : 'mean'

})
# Out:
#            budget_musd  revenue_musd  vote_average  popularity       ROI  \
# Franchise
# False        18.047741     44.742814      6.008787    2.592726  1.619699
# True         38.319847    165.708193      5.956806    6.245051  3.709195
#
#            vote_count
# Franchise
# False       78.289550
# True       412.387856

# %%
df['belongs_to_collection'].head(5)
# Out:
# 0              Toy Story Collection
# 1                               NaN
# 2         Grumpy Old Men Collection
# 3                               NaN
# 4    Father of the Bride Collection
# Name: belongs_to_collection, dtype: object

# %%
df['belongs_to_collection'].value_counts()
# Out:
# belongs_to_collection
# The Bowery Boys                  29
# Totò Collection                  27
# Zatôichi: The Blind Swordsman    26
# James Bond Collection            26
# The Carry On Collection          25
#                                  ..
# Salt and Pepper Collection        1
# Deadpool Collection               1
# Ant-Man Collection                1
# Elvira Collection                 1
# Red Lotus Collection              1
# Name: count, Length: 1691, dtype: int64

# %%
franchise = df.groupby('belongs_to_collection').agg({
    'title' : 'count',
    'budget_musd' : ['sum', 'mean'],
    'revenue_musd' : ['sum', 'mean'],
    'popularity' : 'mean',
    'vote_average': 'mean',
    'ROI': 'median',
    'vote_count' : 'mean'
})

# %%
franchise
# Out:
#                                      title budget_musd       revenue_musd  \
#                                      count         sum  mean          sum
# belongs_to_collection
# ... Has Fallen Collection                2       130.0  65.0   366.780087
# 00 Schneider Filmreihe                   1         0.0   NaN     0.000000
# 08/15 Collection                         1         0.0   NaN     0.000000
# 100 Girls Collection                     2         0.0   NaN     0.000000
# 101 Dalmatians (Animated) Collection     2         4.0   4.0   215.880014
# ...                                    ...         ...   ...          ...
# Сказки Чуковского                        1         0.0   NaN     0.000000
# Чебурашка и крокодил Гена                1         0.0   NaN     0.000000
# Что Творят мужчины! (Коллекция)          2         2.0   2.0     0.000000
# 男はつらいよ シリーズ                              3         0.0   NaN     0.000000
# 식객 시리즈                                   2         0.0   NaN     0.000000
#
#                                                  popularity vote_average  \
#                                             mean       mean         mean
# belongs_to_collection
# ... Has Fallen Collection             183.390043  13.008090         6.00
# 00 Schneider Filmreihe                       NaN   1.931299         6.50
# 08/15 Collection                             NaN   0.628127         5.90
# 100 Girls Collection                         NaN   3.078652         5.15
# 101 Dalmatians (Animated) Collection  215.880014  13.063212         6.25
# ...                                          ...        ...          ...
# Сказки Чуковского                            NaN   0.731334         3.00
# Чебурашка и крокодил Гена                    NaN   0.881504         6.70
# Что Творят мужчины! (Коллекция)              NaN   1.299605         3.15
# 男はつらいよ シリーズ                                  NaN   0.038901         7.00
# 식객 시리즈                                       NaN   0.157245         4.95
#
#                                             ROI   vote_count
#                                          median         mean
# belongs_to_collection
# ... Has Fallen Collection              2.864804  2333.000000
# 00 Schneider Filmreihe                      NaN    16.000000
# 08/15 Collection                            NaN     4.000000
# 100 Girls Collection                        NaN    64.000000
# 101 Dalmatians (Animated) Collection  53.970003   937.000000
# ...                                         ...          ...
# Сказки Чуковского                           NaN     3.000000
# Чебурашка и крокодил Гена                   NaN     7.000000
# Что Творят мужчины! (Коллекция)             NaN     5.500000
# 男はつらいよ シリーズ                                 NaN     0.666667
# 식객 시리즈                                      NaN     3.500000
#
# [1691 rows x 9 columns]

# %%
franchise.nlargest(20, ('title', 'count'))
# Out:
#                                        title budget_musd             \
#                                        count         sum       mean
# belongs_to_collection
# The Bowery Boys                           29      0.0000        NaN
# Totò Collection                           27      0.0000        NaN
# James Bond Collection                     26   1539.6500  59.217308
# Zatôichi: The Blind Swordsman             26      0.0000        NaN
# The Carry On Collection                   25      0.0000        NaN
# Charlie Chan (Sidney Toler) Collection    21      0.0000        NaN
# Pokémon Collection                        20    250.7204  50.144080
# Godzilla (Showa) Collection               16      2.8100   0.562000
# Charlie Chan (Warner Oland) Collection    15      0.0000        NaN
# Dragon Ball Z (Movie) Collection          15      5.0000   5.000000
# Uuno Turhapuro                            15      0.0000        NaN
# Monster High Collection                   14      0.5000   0.500000
# The Land Before Time Collection           14     12.3000  12.300000
# George Carlin Comedy Collection           13      0.0000        NaN
# Sharpe Collection                         13      0.0000        NaN
# Friday the 13th Collection                12     84.4000   7.033333
# Johan Falk GSI Collection                 12      0.0000        NaN
# Sherlock Holmes (1939 series)             12      0.0000        NaN
# The Amityville Horror Collection          12     21.0200   5.255000
# An American Girl Collection               10      6.8000   6.800000
#
#                                        revenue_musd             popularity  \
#                                                 sum        mean       mean
# belongs_to_collection
# The Bowery Boys                            0.000000         NaN   0.198006
# Totò Collection                            0.000000         NaN   1.047324
# James Bond Collection                   7106.970239  273.345009  13.453502
# Zatôichi: The Blind Swordsman              0.000000         NaN   1.100603
# The Carry On Collection                    0.000000         NaN   3.220430
# Charlie Chan (Sidney Toler) Collection     0.000000         NaN   0.630996
# Pokémon Collection                       601.865958   66.873995   4.374284
# Godzilla (Showa) Collection                0.000000         NaN   3.422842
# Charlie Chan (Warner Oland) Collection     0.000000         NaN   0.664986
# Dragon Ball Z (Movie) Collection         112.121192   56.060596   6.183563
# Uuno Turhapuro                             0.000000         NaN   0.169261
# Monster High Collection                    0.000000         NaN   3.591922
# The Land Before Time Collection           84.460846   84.460846   4.905620
# George Carlin Comedy Collection            0.000000         NaN   1.296917
# Sharpe Collection                          0.000000         NaN   1.709641
# Friday the 13th Collection               464.898544   38.741545   9.760807
# Johan Falk GSI Collection                  0.000000         NaN   1.520858
# Sherlock Holmes (1939 series)              0.000000         NaN   2.876897
# The Amityville Horror Collection         213.347083   53.336771   7.179849
# An American Girl Collection                0.000000         NaN   1.940739
#
#                                        vote_average        ROI   vote_count
#                                                mean     median         mean
# belongs_to_collection
# The Bowery Boys                            6.675000        NaN     0.724138
# Totò Collection                            6.837037        NaN    18.037037
# James Bond Collection                      6.338462   6.128922  1284.307692
# Zatôichi: The Blind Swordsman              6.403846        NaN    11.192308
# The Carry On Collection                    6.168000        NaN    21.040000
# Charlie Chan (Sidney Toler) Collection     6.609524        NaN     5.809524
# Pokémon Collection                         6.055000   4.464976    71.100000
# Godzilla (Showa) Collection                5.975000        NaN    39.750000
# Charlie Chan (Warner Oland) Collection     6.658333        NaN     6.866667
# Dragon Ball Z (Movie) Collection           6.606667  12.353638   133.333333
# Uuno Turhapuro                             5.526667        NaN     3.866667
# Monster High Collection                    6.485714        NaN    12.571429
# The Land Before Time Collection            6.164286   6.866735    96.071429
# George Carlin Comedy Collection            7.469231        NaN    12.538462
# Sharpe Collection                          6.738462        NaN    13.230769
# Friday the 13th Collection                 5.425000   6.668557   326.583333
# Johan Falk GSI Collection                  6.500000        NaN     9.250000
# Sherlock Holmes (1939 series)              6.925000        NaN    21.583333
# The Amityville Horror Collection           4.358333   5.686691    91.916667
# An American Girl Collection                5.250000        NaN     8.700000

# %%
franchise.nlargest(20, ('revenue_musd', 'sum'))
# Out:
#                                     title budget_musd              \
#                                     count         sum        mean
# belongs_to_collection
# Harry Potter Collection                 8     1280.00  160.000000
# Star Wars Collection                    8      854.35  106.793750
# James Bond Collection                  26     1539.65   59.217308
# The Fast and the Furious Collection     8     1009.00  126.125000
# Pirates of the Caribbean Collection     5     1250.00  250.000000
# Transformers Collection                 5      965.00  193.000000
# Despicable Me Collection                6      299.00   74.750000
# The Twilight Collection                 5      385.00   77.000000
# Ice Age Collection                      5      429.00   85.800000
# Jurassic Park Collection                4      379.00   94.750000
# Shrek Collection                        5      535.00  133.750000
# The Hunger Games Collection             4      490.00  122.500000
# The Hobbit Collection                   3      750.00  250.000000
# The Avengers Collection                 2      500.00  250.000000
# The Lord of the Rings Collection        3      266.00   88.666667
# X-Men Collection                        6      983.00  163.833333
# Avatar Collection                       1      237.00  237.000000
# Mission: Impossible Collection          5      650.00  130.000000
# Spider-Man Collection                   3      597.00  199.000000
# The Dark Knight Collection              3      585.00  195.000000
#
#                                     revenue_musd               popularity  \
#                                              sum         mean        mean
# belongs_to_collection
# Harry Potter Collection              7707.367425   963.420928   26.253893
# Star Wars Collection                 7434.494790   929.311849   23.410919
# James Bond Collection                7106.970239   273.345009   13.453502
# The Fast and the Furious Collection  5125.098793   640.637349   10.799435
# Pirates of the Caribbean Collection  4521.576826   904.315365   53.972237
# Transformers Collection              4366.101244   873.220249   14.425077
# Despicable Me Collection             3691.070216   922.767554  106.715961
# The Twilight Collection              3342.107290   668.421458   29.500843
# Ice Age Collection                   3216.708553   643.341711   16.075234
# Jurassic Park Collection             3031.484143   757.871036   10.772810
# Shrek Collection                     2955.807008   738.951752   12.966705
# The Hunger Games Collection          2944.162634   736.040659   54.766747
# The Hobbit Collection                2935.523356   978.507785   25.205614
# The Avengers Collection              2924.961604  1462.480802   63.633534
# The Lord of the Rings Collection     2916.544743   972.181581   30.272873
# X-Men Collection                     2808.832317   468.138720    9.707541
# Avatar Collection                    2787.965087  2787.965087  185.070892
# Mission: Impossible Collection       2778.977995   555.795599   16.509710
# Spider-Man Collection                2496.346518   832.115506   22.620704
# The Dark Knight Collection           2463.716216   821.238739   57.418393
#
#                                     vote_average        ROI    vote_count
#                                             mean     median          mean
# belongs_to_collection
# Harry Potter Collection                 7.537500   6.165086   5983.250000
# Star Wars Collection                    7.375000   8.239637   5430.375000
# James Bond Collection                   6.338462   6.128922   1284.307692
# The Fast and the Furious Collection     6.662500   4.942154   3197.000000
# Pirates of the Caribbean Collection     6.880000   3.453009   5016.000000
# Transformers Collection                 6.140000   5.197167   3046.400000
# Despicable Me Collection                6.783333  12.761987   3041.333333
# The Twilight Collection                 5.840000  10.271932   2770.200000
# Ice Age Collection                      6.380000   8.261760   2643.800000
# Jurassic Park Collection                6.500000   7.027789   4608.750000
# Shrek Collection                        6.460000   5.562873   2344.200000
# The Hunger Games Collection             6.875000   6.267722   6543.500000
# The Hobbit Collection                   7.233333   3.833600   5981.333333
# The Avengers Collection                 7.350000   5.963190   9454.000000
# The Lord of the Rings Collection        8.033333  11.725157   8253.000000
# X-Men Collection                        6.816667   3.023632   4593.833333
# Avatar Collection                       7.200000  11.763566  12114.000000
# Mission: Impossible Collection          6.600000   4.548868   2801.000000
# Spider-Man Collection                   6.466667   3.918832   4505.666667
# The Dark Knight Collection              7.800000   4.339756   9681.000000

# %%
franchise.nlargest(20, ('revenue_musd', 'mean'))
# Out:
#                                     title budget_musd              \
#                                     count         sum        mean
# belongs_to_collection
# Avatar Collection                       1      237.00  237.000000
# The Avengers Collection                 2      500.00  250.000000
# Frozen Collection                       2      150.00  150.000000
# Finding Nemo Collection                 2      294.00  147.000000
# The Hobbit Collection                   3      750.00  250.000000
# The Lord of the Rings Collection        3      266.00   88.666667
# Harry Potter Collection                 8     1280.00  160.000000
# Star Wars Collection                    8      854.35  106.793750
# Despicable Me Collection                6      299.00   74.750000
# Pirates of the Caribbean Collection     5     1250.00  250.000000
# The Secret Life of Pets Collection      1       75.00   75.000000
# Transformers Collection                 5      965.00  193.000000
# Spider-Man Collection                   3      597.00  199.000000
# The Dark Knight Collection              3      585.00  195.000000
# Wonder Woman Collection                 1      149.00  149.000000
# Guardians of the Galaxy Collection      2      370.00  185.000000
# Fantastic Beasts Collection             1      180.00  180.000000
# Iron Man Collection                     3      540.00  180.000000
# The Lion King Collection                4       45.00   45.000000
# Deadpool Collection                     1       58.00   58.000000
#
#                                     revenue_musd               popularity  \
#                                              sum         mean        mean
# belongs_to_collection
# Avatar Collection                    2787.965087  2787.965087  185.070892
# The Avengers Collection              2924.961604  1462.480802   63.633534
# Frozen Collection                    1274.219009  1274.219009   16.878788
# Finding Nemo Collection              1968.906425   984.453213   19.987735
# The Hobbit Collection                2935.523356   978.507785   25.205614
# The Lord of the Rings Collection     2916.544743   972.181581   30.272873
# Harry Potter Collection              7707.367425   963.420928   26.253893
# Star Wars Collection                 7434.494790   929.311849   23.410919
# Despicable Me Collection             3691.070216   922.767554  106.715961
# Pirates of the Caribbean Collection  4521.576826   904.315365   53.972237
# The Secret Life of Pets Collection    875.457937   875.457937   11.013950
# Transformers Collection              4366.101244   873.220249   14.425077
# Spider-Man Collection                2496.346518   832.115506   22.620704
# The Dark Knight Collection           2463.716216   821.238739   57.418393
# Wonder Woman Collection               820.580447   820.580447  294.337037
# Guardians of the Galaxy Collection   1636.744770   818.372385  119.311296
# Fantastic Beasts Collection           809.342332   809.342332   41.051421
# Iron Man Collection                  2424.547547   808.182516   21.625895
# The Lion King Collection              788.241776   788.241776   11.482656
# Deadpool Collection                   783.112979   783.112979  187.860492
#
#                                     vote_average        ROI    vote_count
#                                             mean     median          mean
# belongs_to_collection
# Avatar Collection                       7.200000  11.763566  12114.000000
# The Avengers Collection                 7.350000   5.963190   9454.000000
# Frozen Collection                       7.100000   8.494793   3035.000000
# Finding Nemo Collection                 7.200000   7.573212   5312.500000
# The Hobbit Collection                   7.233333   3.833600   5981.333333
# The Lord of the Rings Collection        8.033333  11.725157   8253.000000
# Harry Potter Collection                 7.537500   6.165086   5983.250000
# Star Wars Collection                    7.375000   8.239637   5430.375000
# Despicable Me Collection                6.783333  12.761987   3041.333333
# Pirates of the Caribbean Collection     6.880000   3.453009   5016.000000
# The Secret Life of Pets Collection      5.900000  11.672772   3536.000000
# Transformers Collection                 6.140000   5.197167   3046.400000
# Spider-Man Collection                   6.466667   3.918832   4505.666667
# The Dark Knight Collection              7.800000   4.339756   9681.000000
# Wonder Woman Collection                 7.200000   5.507251   5025.000000
# Guardians of the Galaxy Collection      7.750000   4.433036   7436.000000
# Fantastic Beasts Collection             7.200000   4.496346   5612.000000
# Iron Man Collection                     6.933333   4.179816   8290.333333
# The Lion King Collection                6.750000  17.516484   1827.500000
# Deadpool Collection                     7.400000  13.501948  11444.000000

# %%
franchise[franchise[('vote_count', 'mean')] >= 1000].nlargest(20, ('vote_average', 'mean'))
# Out:
#                                     title budget_musd              \
#                                     count         sum        mean
# belongs_to_collection
# The Lord of the Rings Collection        3      266.00   88.666667
# The Godfather Collection                3       73.00   24.333333
# Blade Runner Collection                 1       28.00   28.000000
# The Man With No Name Collection         3        2.00    0.666667
# The Dark Knight Collection              3      585.00  195.000000
# Guardians of the Galaxy Collection      2      370.00  185.000000
# Kill Bill Collection                    2       60.00   30.000000
# Kingsman Collection                     1       81.00   81.000000
# How to Train Your Dragon Collection     2      310.00  155.000000
# Harry Potter Collection                 8     1280.00  160.000000
# Toy Story Collection                    3      320.00  106.666667
# Back to the Future Collection           3       99.00   33.000000
# Trainspotting Collection                2       22.00   11.000000
# Deadpool Collection                     1       58.00   58.000000
# The Incredibles Collection              1       92.00   92.000000
# Star Wars Collection                    8      854.35  106.793750
# The Avengers Collection                 2      500.00  250.000000
# The Lego Movie Collection               2      140.00   70.000000
# Tangled Collection                      2      260.00  260.000000
# The Space Odyssey Series                2       38.50   19.250000
#
#                                     revenue_musd               popularity  \
#                                              sum         mean        mean
# belongs_to_collection
# The Lord of the Rings Collection     2916.544743   972.181581   30.272873
# The Godfather Collection              429.375314   143.125105   31.641307
# Blade Runner Collection                33.139618    33.139618   96.272374
# The Man With No Name Collection        35.500000    11.833333   14.171278
# The Dark Knight Collection           2463.716216   821.238739   57.418393
# Guardians of the Galaxy Collection   1636.744770   818.372385  119.311296
# Kill Bill Collection                  333.108461   166.554231   23.397469
# Kingsman Collection                   414.351546   414.351546   28.224212
# How to Train Your Dragon Collection  1104.001807   552.000904   13.336685
# Harry Potter Collection              7707.367425   963.420928   26.253893
# Toy Story Collection                 1937.890605   645.963535   18.820369
# Back to the Future Collection         957.637345   319.212448   17.504121
# Trainspotting Collection               57.903789    28.951895   18.497172
# Deadpool Collection                   783.112979   783.112979  187.860492
# The Incredibles Collection            631.442092   631.442092   22.220214
# Star Wars Collection                 7434.494790   929.311849   23.410919
# The Avengers Collection              2924.961604  1462.480802   63.633534
# The Lego Movie Collection             781.111076   390.555538   16.744440
# Tangled Collection                    591.794936   591.794936   12.319364
# The Space Odyssey Series              109.100657    54.550329   14.988743
#
#                                     vote_average        ROI    vote_count
#                                             mean     median          mean
# belongs_to_collection
# The Lord of the Rings Collection        8.033333  11.725157   8253.000000
# The Godfather Collection                7.966667   3.657142   3677.000000
# Blade Runner Collection                 7.900000   1.183558   3833.000000
# The Man With No Name Collection         7.833333  25.000000   1422.666667
# The Dark Knight Collection              7.800000   4.339756   9681.000000
# Guardians of the Galaxy Collection      7.750000   4.433036   7436.000000
# Kill Bill Collection                    7.700000   5.551808   4576.000000
# Kingsman Collection                     7.600000   5.115451   6069.000000
# How to Train Your Dragon Collection     7.550000   3.600057   3741.000000
# Harry Potter Collection                 7.537500   6.165086   5983.250000
# Toy Story Collection                    7.533333   5.526299   4679.666667
# Back to the Future Collection           7.500000   8.300000   4381.000000
# Trainspotting Collection                7.450000   3.211738   1766.000000
# Deadpool Collection                     7.400000  13.501948  11444.000000
# The Incredibles Collection              7.400000   6.863501   5290.000000
# Star Wars Collection                    7.375000   8.239637   5430.375000
# The Avengers Collection                 7.350000   5.963190   9454.000000
# The Lego Movie Collection               7.350000   5.859362   2300.000000
# Tangled Collection                      7.250000   2.276134   1901.000000
# The Space Odyssey Series                7.250000   3.992869   1682.500000

# %%
df['director']
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
df['director'].value_counts().head(20)
# Out:
# director
# John Ford             66
# Michael Curtiz        65
# Werner Herzog         54
# Alfred Hitchcock      53
# Georges Méliès        49
# Woody Allen           49
# Jean-Luc Godard       46
# Sidney Lumet          46
# Charlie Chaplin       44
# Raoul Walsh           43
# William A. Wellman    42
# Henry Hathaway        41
# Richard Thorpe        40
# Ingmar Bergman        39
# Martin Scorsese       39
# Fritz Lang            38
# John Huston           38
# George Cukor          38
# Mervyn LeRoy          37
# Robert Altman         37
# Name: count, dtype: int64

# %%
plt.figure(figsize= (12, 8))
df['director'].value_counts().head(20).plot(kind = 'bar', fontsize = 15)
plt.title('Most Active Directors', fontsize = 20)
plt.ylabel('Number of Movies', fontsize = 15)
plt.show()

# %%
df.groupby('director')['revenue_musd'].sum().nlargest(20)
# Out:
# director
# Steven Spielberg     9256.621422
# Peter Jackson        6528.244659
# Michael Bay          6437.466781
# James Cameron        5900.610310
# David Yates          5334.563196
# Christopher Nolan    4747.408665
# Robert Zemeckis      4138.233542
# Tim Burton           4032.916124
# Ridley Scott         3917.529240
# Chris Columbus       3866.836869
# Roland Emmerich      3798.402596
# Ron Howard           3714.152341
# J.J. Abrams          3579.215315
# Gore Verbinski       3575.339236
# George Lucas         3341.550893
# Sam Raimi            3193.788606
# Francis Lawrence     3183.341910
# Clint Eastwood       3100.675162
# Bill Condon          3017.298095
# Joss Whedon          2963.831071
# Name: revenue_musd, dtype: float64

# %%
plt.figure(figsize=(12, 8))
df.groupby('director')['revenue_musd'].sum().nlargest(20).plot(kind = 'bar', fontsize = 15)
plt.title('Total Revenue', fontsize = 20)
plt.ylabel('Revenue MUSD', fontsize = 20)
plt.show()
