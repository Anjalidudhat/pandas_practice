# %%
# !pip install pandas-datareader
# !pip install numpy
# !pip install pandas
# !pip install pandas_datareader
# !pip install plotly

# %%
import pandas_datareader.data as web
import matplotlib.pyplot as plt

# %%
import pandas_datareader.data as web
import datetime as dt

# %%
start_date = "2020-01-1"
end_date = "2021-12-31"

# %%
import pandas_datareader.data as web
import datetime as dt
import yfinance as yf # Import yfinance as an alternative

start_date = "2023-08-1"
end_date = "2024-08-16"

# Use yfinance to fetch data
data = yf.download("ADANIPORTS.NS", start=start_date, end=end_date)

data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-08-01   778.950012   781.000000   761.599976   765.349976   762.080261
# 2023-08-02   767.000000   773.900024   751.549988   761.450012   758.196960
# 2023-08-03   761.450012   779.500000   753.400024   773.349976   770.046082
# 2023-08-04   776.450012   779.900024   768.750000   775.250000   771.937988
# 2023-08-07   777.049988   794.650024   771.200012   791.400024   788.019043
# ...                 ...          ...          ...          ...          ...
# 2024-08-08  1538.000000  1556.000000  1513.800049  1519.000000  1519.000000
# 2024-08-09  1541.500000  1543.500000  1519.000000  1533.800049  1533.800049
# 2024-08-12  1500.000000  1524.250000  1457.349976  1501.400024  1501.400024
# 2024-08-13  1505.849976  1517.449951  1479.500000  1483.449951  1483.449951
# ...

# %%
data.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-08-08  1538.000000  1556.000000  1513.800049  1519.000000  1519.000000
# 2024-08-09  1541.500000  1543.500000  1519.000000  1533.800049  1533.800049
# 2024-08-12  1500.000000  1524.250000  1457.349976  1501.400024  1501.400024
# 2024-08-13  1505.849976  1517.449951  1479.500000  1483.449951  1483.449951
# 2024-08-14  1488.000000  1488.000000  1452.000000  1461.949951  1461.949951
#
#              Volume
# Date
# 2024-08-08  2468123
# 2024-08-09  1503033
# 2024-08-12  9230512
# 2024-08-13  2485446
# 2024-08-14  2648057

# %%
close = data['Close']  # Capitalize 'Close'
ax = close.plot(title = "Tesla Stock price")
ax.set_xlabel("Date")
ax.set_ylabel("Close Price")  # Optionally, make the y-axis label clearer
ax.grid()
plt.show()
