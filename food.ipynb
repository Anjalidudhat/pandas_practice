# %%
import pandas as pd

# %%
df = pd.read_csv('/content/indian_dishes_times.csv')

# %%
df.head()
# Out:
#                    Dish  Serving Size  Preparation Time (minutes)  \
# 0  Paneer Butter Masala             3                          10
# 1  Paneer Butter Masala             4                          11
# 2  Paneer Butter Masala             5                          11
# 3  Paneer Butter Masala             6                          12
# 4             Aloo Gobi             2                          10
#
#    Cooking Time (minutes)                                             Source
# 0                      20  https://rakskitchen.net/paneer-butter-masala-r...
# 1                      25  https://harpalssokhi.com/recipe/dhaba-paneer-b...
# 2                      40  https://hebbarskitchen.com/paneer-butter-masal...
# 3                      40  https://myfoodstory.com/restaurant-style-panee...
# 4                      25    https://www.indianhealthyrecipes.com/aloo-gobi/

# %%
df.tail()
# Out:
#              Dish  Serving Size  Preparation Time (minutes)  \
# 11  Chicken Curry             8                          25
# 12     Fish Curry             2                          10
# 13     Fish Curry             4                          10
# 14     Fish Curry             6                          15
# 15     Fish Curry             8                          15
#
#     Cooking Time (minutes)                                             Source
# 11                      40  https://www.allrecipes.com/recipe/46822/indian...
# 12                      20  https://vegecravings.com/paneer-butter-masala-...
# 13                      25  https://vegecravings.com/paneer-butter-masala-...
# 14                      25  https://vegecravings.com/paneer-butter-masala-...
# 15                      30  https://vegecravings.com/paneer-butter-masala-...

# %%
df.columns
# Out:
# Index(['Dish', 'Serving Size', 'Preparation Time (minutes)',
#        'Cooking Time (minutes)', 'Source'],
#       dtype='object')

# %%
df.shape[0]
# Out:
# 16

# %%
df.shape[1]
# Out:
# 5

# %%
df.isnull().sum()
# Out:
# Dish                          0
# Serving Size                  0
# Preparation Time (minutes)    0
# Cooking Time (minutes)        0
# Source                        0
# dtype: int64

# %%
df['Serving Size']
# Out:
# 0     3
# 1     4
# 2     5
# 3     6
# 4     2
# 5     4
# 6     6
# 7     8
# 8     3
# 9     4
# 10    6
# 11    8
# 12    2
# 13    4
# 14    6
# 15    8
# Name: Serving Size, dtype: int64

# %%
df['Dish']
# Out:
# 0     Paneer Butter Masala
# 1     Paneer Butter Masala
# 2     Paneer Butter Masala
# 3     Paneer Butter Masala
# 4                Aloo Gobi
# 5                Aloo Gobi
# 6                Aloo Gobi
# 7                Aloo Gobi
# 8            Chicken Curry
# 9            Chicken Curry
# 10           Chicken Curry
# 11           Chicken Curry
# 12              Fish Curry
# 13              Fish Curry
# 14              Fish Curry
# 15              Fish Curry
# Name: Dish, dtype: object

# %%
df[df['Dish'] == 'Paneer Butter Masala']
# Out:
#                    Dish  Serving Size  Preparation Time (minutes)  \
# 0  Paneer Butter Masala             3                          10
# 1  Paneer Butter Masala             4                          11
# 2  Paneer Butter Masala             5                          11
# 3  Paneer Butter Masala             6                          12
#
#    Cooking Time (minutes)                                             Source
# 0                      20  https://rakskitchen.net/paneer-butter-masala-r...
# 1                      25  https://harpalssokhi.com/recipe/dhaba-paneer-b...
# 2                      40  https://hebbarskitchen.com/paneer-butter-masal...
# 3                      40  https://myfoodstory.com/restaurant-style-panee...

# %%
df[df['Dish'] == 'Aloo Gobi']
# Out:
#         Dish  Serving Size  Preparation Time (minutes)  \
# 4  Aloo Gobi             2                          10
# 5  Aloo Gobi             4                          10
# 6  Aloo Gobi             6                          15
# 7  Aloo Gobi             8                          15
#
#    Cooking Time (minutes)                                           Source
# 4                      25  https://www.indianhealthyrecipes.com/aloo-gobi/
# 5                      30  https://www.indianhealthyrecipes.com/aloo-gobi/
# 6                      30  https://www.indianhealthyrecipes.com/aloo-gobi/
# 7                      35  https://www.indianhealthyrecipes.com/aloo-gobi/

# %%
df[df['Preparation Time (minutes)'] == 10]
# Out:
#                     Dish  Serving Size  Preparation Time (minutes)  \
# 0   Paneer Butter Masala             3                          10
# 4              Aloo Gobi             2                          10
# 5              Aloo Gobi             4                          10
# 12            Fish Curry             2                          10
# 13            Fish Curry             4                          10
#
#     Cooking Time (minutes)                                             Source
# 0                       20  https://rakskitchen.net/paneer-butter-masala-r...
# 4                       25    https://www.indianhealthyrecipes.com/aloo-gobi/
# 5                       30    https://www.indianhealthyrecipes.com/aloo-gobi/
# 12                      20  https://vegecravings.com/paneer-butter-masala-...
# 13                      25  https://vegecravings.com/paneer-butter-masala-...

# %%
df[df['Preparation Time (minutes)'] < 15]
# Out:
#                     Dish  Serving Size  Preparation Time (minutes)  \
# 0   Paneer Butter Masala             3                          10
# 1   Paneer Butter Masala             4                          11
# 2   Paneer Butter Masala             5                          11
# 3   Paneer Butter Masala             6                          12
# 4              Aloo Gobi             2                          10
# 5              Aloo Gobi             4                          10
# 12            Fish Curry             2                          10
# 13            Fish Curry             4                          10
#
#     Cooking Time (minutes)                                             Source
# 0                       20  https://rakskitchen.net/paneer-butter-masala-r...
# 1                       25  https://harpalssokhi.com/recipe/dhaba-paneer-b...
# 2                       40  https://hebbarskitchen.com/paneer-butter-masal...
# ...

# %%
df2 =  pd.read_csv('/content/Global EV Data 2024.csv')

# %%
df2.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 1  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 2  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0    0.00039
# 1    0.00650
# 2   49.00000
# 3   49.00000
# 4  220.00000

# %%
df2.tail()
# Out:
#       region          category           parameter    mode  \
# 12649  World  Projection-STEPS      EV sales share    Cars
# 12650  World  Projection-STEPS      EV stock share    Cars
# 12651  World    Projection-APS  EV charging points      EV
# 12652  World    Projection-APS  EV charging points      EV
# 12653  World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain  year             unit       value
# 12649                       EV  2035          percent        55.0
# 12650                       EV  2035          percent        31.0
# 12651  Publicly available fast  2035  charging points   9400000.0
# 12652  Publicly available slow  2035  charging points  15000000.0
# 12653                       EV  2035          percent         9.0

# %%
df2.columns
# Out:
# Index(['region', 'category', 'parameter', 'mode', 'powertrain', 'year', 'unit',
#        'value'],
#       dtype='object')

# %%
df2.isnull().sum()
# Out:
# region        0
# category      0
# parameter     0
# mode          0
# powertrain    0
# year          0
# unit          0
# value         0
# dtype: int64

# %%
df2['category']
# Out:
# 0              Historical
# 1              Historical
# 2              Historical
# 3              Historical
# 4              Historical
#                ...
# 12649    Projection-STEPS
# 12650    Projection-STEPS
# 12651      Projection-APS
# 12652      Projection-APS
# 12653    Projection-STEPS
# Name: category, Length: 12654, dtype: object

# %%
df2[df2['region'] == 'World']
# Out:
#       region          category           parameter    mode  \
# 11404  World        Historical      EV sales share    Cars
# 11405  World        Historical      EV stock share    Cars
# 11406  World        Historical      EV sales share  Trucks
# 11407  World        Historical      EV stock share  Trucks
# 11408  World        Historical            EV sales    Vans
# ...      ...               ...                 ...     ...
# 12649  World  Projection-STEPS      EV sales share    Cars
# 12650  World  Projection-STEPS      EV stock share    Cars
# 12651  World    Projection-APS  EV charging points      EV
# 12652  World    Projection-APS  EV charging points      EV
# 12653  World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain  year             unit         value
# 11404                       EV  2010          percent  1.100000e-02
# 11405                       EV  2010          percent  2.300000e-03
# ...

# %%
df2['region']
# Out:
# 0        Australia
# 1        Australia
# 2        Australia
# 3        Australia
# 4        Australia
#            ...
# 12649        World
# 12650        World
# 12651        World
# 12652        World
# 12653        World
# Name: region, Length: 12654, dtype: object

# %%
df2[df2['region'] == 'Australia']
# Out:
#        region    category       parameter  mode powertrain  year      unit  \
# 0   Australia  Historical  EV stock share  Cars         EV  2011   percent
# 1   Australia  Historical  EV sales share  Cars         EV  2011   percent
# 2   Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 3   Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4   Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
# ..        ...         ...             ...   ...        ...   ...       ...
# 89  Australia  Historical        EV stock  Cars       FCEV  2023  Vehicles
# 90  Australia  Historical  EV sales share  Cars         EV  2023   percent
# 91  Australia  Historical        EV sales  Cars        BEV  2023  Vehicles
# 92  Australia  Historical        EV stock  Cars        BEV  2023  Vehicles
# 93  Australia  Historical        EV sales  Cars       FCEV  2023  Vehicles
#
#            value
# 0        0.00039
# 1        0.00650
# ...

# %%
df2[5:10]
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 5  Australia  Historical        EV sales  Cars        BEV  2012  Vehicles
# 6  Australia  Historical  EV sales share  Cars         EV  2012   percent
# 7  Australia  Historical  EV stock share  Cars         EV  2012   percent
# 8  Australia  Historical        EV stock  Cars       PHEV  2012  Vehicles
# 9  Australia  Historical        EV sales  Cars       PHEV  2012  Vehicles
#
#       value
# 5  170.0000
# 6    0.0300
# 7    0.0024
# 8   80.0000
# 9   80.0000

# %%
df2[df2['parameter'] == 'EV sales']
# Out:
#           region          category parameter  mode powertrain  year      unit  \
# 2      Australia        Historical  EV sales  Cars        BEV  2011  Vehicles
# 5      Australia        Historical  EV sales  Cars        BEV  2012  Vehicles
# 9      Australia        Historical  EV sales  Cars       PHEV  2012  Vehicles
# 10     Australia        Historical  EV sales  Cars       PHEV  2013  Vehicles
# 14     Australia        Historical  EV sales  Cars        BEV  2013  Vehicles
# ...          ...               ...       ...   ...        ...   ...       ...
# 12619      World  Projection-STEPS  EV sales  Vans       FCEV  2035  Vehicles
# 12620      World  Projection-STEPS  EV sales  Vans       PHEV  2035  Vehicles
# 12621      World  Projection-STEPS  EV sales  Cars        BEV  2035  Vehicles
# 12622      World  Projection-STEPS  EV sales  Cars       FCEV  2035  Vehicles
# 12623      World  Projection-STEPS  EV sales  Cars       PHEV  2035  Vehicles
#
#             value
# ...

# %%
df2[df2['parameter'] == 'EV stock']
# Out:
#           region          category parameter  mode powertrain  year      unit  \
# 3      Australia        Historical  EV stock  Cars        BEV  2011  Vehicles
# 4      Australia        Historical  EV stock  Cars        BEV  2012  Vehicles
# 8      Australia        Historical  EV stock  Cars       PHEV  2012  Vehicles
# 11     Australia        Historical  EV stock  Cars       PHEV  2013  Vehicles
# 15     Australia        Historical  EV stock  Cars        BEV  2013  Vehicles
# ...          ...               ...       ...   ...        ...   ...       ...
# 12631      World  Projection-STEPS  EV stock  Vans       FCEV  2035  Vehicles
# 12632      World  Projection-STEPS  EV stock  Vans       PHEV  2035  Vehicles
# 12633      World  Projection-STEPS  EV stock  Cars        BEV  2035  Vehicles
# 12634      World  Projection-STEPS  EV stock  Cars       FCEV  2035  Vehicles
# 12635      World  Projection-STEPS  EV stock  Cars       PHEV  2035  Vehicles
#
#              value
# ...

# %%
df2[df2['year'] == 2035]
# Out:
#       region          category           parameter    mode  \
# 2117   China    Projection-APS      EV sales share   Buses
# 2118   China    Projection-APS      EV stock share   Buses
# 2119   China    Projection-APS      EV stock share  Trucks
# 2120   China  Projection-STEPS  Electricity demand   Buses
# 2121   China  Projection-STEPS  Electricity demand  Trucks
# ...      ...               ...                 ...     ...
# 12649  World  Projection-STEPS      EV sales share    Cars
# 12650  World  Projection-STEPS      EV stock share    Cars
# 12651  World    Projection-APS  EV charging points      EV
# 12652  World    Projection-APS  EV charging points      EV
# 12653  World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain  year             unit       value
# 2117                        EV  2035          percent        72.0
# 2118                        EV  2035          percent        58.0
# ...

# %%
df2[df2['unit'] == 'charging points']
# Out:
#           region          category           parameter mode  \
# 38     Australia        Historical  EV charging points   EV
# 39     Australia        Historical  EV charging points   EV
# 44     Australia        Historical  EV charging points   EV
# 45     Australia        Historical  EV charging points   EV
# 54     Australia        Historical  EV charging points   EV
# ...          ...               ...                 ...  ...
# 12537      World  Projection-STEPS  EV charging points   EV
# 12586      World  Projection-STEPS  EV charging points   EV
# 12587      World  Projection-STEPS  EV charging points   EV
# 12651      World    Projection-APS  EV charging points   EV
# 12652      World    Projection-APS  EV charging points   EV
#
#                     powertrain  year             unit       value
# 38     Publicly available fast  2017  charging points        40.0
# 39     Publicly available slow  2017  charging points       440.0
# ...

# %%
df3 = pd.read_csv('/content/powerlifting_dataset.csv')

# %%
df3.head()
# Out:
#       Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0  Jessica Wilson   46        59 kg  Bench Press                 269
# 1        John Doe   60        83 kg  Bench Press                 179
# 2     Emily Davis   41       105 kg  Bench Press                 235
# 3     Emily Davis   33        66 kg        Squat                 359
# 4    Laura Taylor   56        74 kg     Deadlift                 221

# %%
df3.tail()
# Out:
#        Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 2995      John Doe   46        74 kg  Bench Press                 246
# 2996    Daniel Lee   39         Open     Deadlift                 244
# 2997  Sarah Thomas   62         Open        Squat                 148
# 2998   Chris Brown   32        93 kg  Bench Press                 333
# 2999    Daniel Lee   22        83 kg     Deadlift                 280

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Lifter Name         3000 non-null   object
#  1   Age                 3000 non-null   int64
#  2   Weight Class        3000 non-null   object
#  3   Lift Type           3000 non-null   object
#  4   Amount Lifted (kg)  3000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 117.3+ KB

# %%
df3.describe()
# Out:
#                Age  Amount Lifted (kg)
# count  3000.000000         3000.000000
# mean     41.064000          250.332667
# std      13.682628           86.281208
# min      18.000000          100.000000
# 25%      29.000000          176.750000
# 50%      41.000000          250.000000
# 75%      53.000000          325.250000
# max      64.000000          399.000000

# %%
df3.isnull().sum()
# Out:
# Lifter Name           0
# Age                   0
# Weight Class          0
# Lift Type             0
# Amount Lifted (kg)    0
# dtype: int64

# %%
df3['Lifter Name']
# Out:
# 0       Jessica Wilson
# 1             John Doe
# 2          Emily Davis
# 3          Emily Davis
# 4         Laura Taylor
#              ...
# 2995          John Doe
# 2996        Daniel Lee
# 2997      Sarah Thomas
# 2998       Chris Brown
# 2999        Daniel Lee
# Name: Lifter Name, Length: 3000, dtype: object

# %%
df3[['Lifter Name','Lift Type']]
# Out:
#          Lifter Name    Lift Type
# 0     Jessica Wilson  Bench Press
# 1           John Doe  Bench Press
# 2        Emily Davis  Bench Press
# 3        Emily Davis        Squat
# 4       Laura Taylor     Deadlift
# ...              ...          ...
# 2995        John Doe  Bench Press
# 2996      Daniel Lee     Deadlift
# 2997    Sarah Thomas        Squat
# 2998     Chris Brown  Bench Press
# 2999      Daniel Lee     Deadlift
#
# [3000 rows x 2 columns]

# %%
df3[df3['Lifter Name'] == 'John Doe']
# Out:
#      Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 1       John Doe   60        83 kg  Bench Press                 179
# 26      John Doe   52        74 kg     Deadlift                 136
# 29      John Doe   64       105 kg        Squat                 263
# 38      John Doe   63        52 kg     Deadlift                 284
# 42      John Doe   49         Open     Deadlift                 217
# ...          ...  ...          ...          ...                 ...
# 2980    John Doe   48        93 kg        Squat                 250
# 2987    John Doe   60       105 kg  Bench Press                 287
# 2991    John Doe   64        93 kg     Deadlift                 263
# 2992    John Doe   51        52 kg  Bench Press                 170
# 2995    John Doe   46        74 kg  Bench Press                 246
#
# [298 rows x 5 columns]

# %%
df3[df3['Age'] < 50df]
# Out:
#          Lifter Name  Age  Weight Class    Lift Type  Amount Lifted (kg)
# 0     Jessica Wilson   46           NaN  Bench Press                 269
# 2        Emily Davis   41           NaN  Bench Press                 235
# 3        Emily Davis   33           NaN        Squat                 359
# 6        Emily Davis   40           NaN     Deadlift                 132
# 7     Jessica Wilson   25           NaN  Bench Press                 178
# ...              ...  ...           ...          ...                 ...
# 2993    Laura Taylor   42           NaN        Squat                 187
# 2995        John Doe   46           NaN  Bench Press                 246
# 2996      Daniel Lee   39           NaN     Deadlift                 244
# 2998     Chris Brown   32           NaN  Bench Press                 333
# 2999      Daniel Lee   22           NaN     Deadlift                 280
#
# [2015 rows x 5 columns]

# %%
df3[df3['Age'] > 60]
# Out:
#            Lifter Name  Age  Weight Class    Lift Type  Amount Lifted (kg)
# 12    Matthew Anderson   64           NaN  Bench Press                 398
# 16        Laura Taylor   62           NaN     Deadlift                 396
# 17        Laura Taylor   62           NaN     Deadlift                 273
# 20      Jessica Wilson   62           NaN        Squat                 107
# 28      Jessica Wilson   63           NaN  Bench Press                 105
# ...                ...  ...           ...          ...                 ...
# 2937       Emily Davis   64           NaN     Deadlift                 165
# 2961   Michael Johnson   64           NaN     Deadlift                 209
# 2991          John Doe   64           NaN     Deadlift                 263
# 2994      Sarah Thomas   62           NaN  Bench Press                 191
# 2997      Sarah Thomas   62           NaN        Squat                 148
#
# [254 rows x 5 columns]

# %%
df3.isnull().sum()
# Out:
# Lifter Name              0
# Age                      0
# Weight Class          3000
# Lift Type                0
# Amount Lifted (kg)       0
# dtype: int64

# %%
df3 = df3.fillna(0)
df3
# Out:
#          Lifter Name  Age  Weight Class    Lift Type  Amount Lifted (kg)
# 0     Jessica Wilson   46           0.0  Bench Press                 269
# 1           John Doe   60           0.0  Bench Press                 179
# 2        Emily Davis   41           0.0  Bench Press                 235
# 3        Emily Davis   33           0.0        Squat                 359
# 4       Laura Taylor   56           0.0     Deadlift                 221
# ...              ...  ...           ...          ...                 ...
# 2995        John Doe   46           0.0  Bench Press                 246
# 2996      Daniel Lee   39           0.0     Deadlift                 244
# 2997    Sarah Thomas   62           0.0        Squat                 148
# 2998     Chris Brown   32           0.0  Bench Press                 333
# 2999      Daniel Lee   22           0.0     Deadlift                 280
#
# [3000 rows x 5 columns]

# %%
df3.fillna(0, inplace=True)  # Fill missing values with 0
df3
# Out:
#          Lifter Name  Age  Weight Class    Lift Type  Amount Lifted (kg)
# 0     Jessica Wilson   46           0.0  Bench Press                 269
# 1           John Doe   60           0.0  Bench Press                 179
# 2        Emily Davis   41           0.0  Bench Press                 235
# 3        Emily Davis   33           0.0        Squat                 359
# 4       Laura Taylor   56           0.0     Deadlift                 221
# ...              ...  ...           ...          ...                 ...
# 2995        John Doe   46           0.0  Bench Press                 246
# 2996      Daniel Lee   39           0.0     Deadlift                 244
# 2997    Sarah Thomas   62           0.0        Squat                 148
# 2998     Chris Brown   32           0.0  Bench Press                 333
# 2999      Daniel Lee   22           0.0     Deadlift                 280
#
# [3000 rows x 5 columns]

# %%
df3.isnull().sum()
# Out:
# Lifter Name           0
# Age                   0
# Weight Class          0
# Lift Type             0
# Amount Lifted (kg)    0
# dtype: int64

# %%
df3[df3['Amount Lifted (kg)'] > 200]
# Out:
#          Lifter Name  Age  Weight Class    Lift Type  Amount Lifted (kg)
# 0     Jessica Wilson   46           0.0  Bench Press                 269
# 2        Emily Davis   41           0.0  Bench Press                 235
# 3        Emily Davis   33           0.0        Squat                 359
# 4       Laura Taylor   56           0.0     Deadlift                 221
# 5       Sarah Thomas   56           0.0        Squat                 264
# ...              ...  ...           ...          ...                 ...
# 2991        John Doe   64           0.0     Deadlift                 263
# 2995        John Doe   46           0.0  Bench Press                 246
# 2996      Daniel Lee   39           0.0     Deadlift                 244
# 2998     Chris Brown   32           0.0  Bench Press                 333
# 2999      Daniel Lee   22           0.0     Deadlift                 280
#
# [2001 rows x 5 columns]

# %%
df3[10:50]
# Out:
#          Lifter Name  Age  Weight Class    Lift Type  Amount Lifted (kg)
# 10      Laura Taylor   31           0.0     Deadlift                 328
# 11        Daniel Lee   38           0.0     Deadlift                 347
# 12  Matthew Anderson   64           0.0  Bench Press                 398
# 13  Matthew Anderson   47           0.0  Bench Press                 396
# 14        Jane Smith   50           0.0  Bench Press                 111
# 15        Daniel Lee   37           0.0     Deadlift                 133
# 16      Laura Taylor   62           0.0     Deadlift                 396
# 17      Laura Taylor   62           0.0     Deadlift                 273
# 18  Matthew Anderson   40           0.0  Bench Press                 120
# 19        Jane Smith   40           0.0     Deadlift                 245
# 20    Jessica Wilson   62           0.0        Squat                 107
# 21      Sarah Thomas   55           0.0        Squat                 169
# ...

# %%
df3[df3['Lifter Name'] == 'Michael Johnson']
# Out:
#           Lifter Name  Age  Weight Class    Lift Type  Amount Lifted (kg)
# 8     Michael Johnson   55           0.0        Squat                 265
# 30    Michael Johnson   35           0.0  Bench Press                 217
# 46    Michael Johnson   55           0.0        Squat                 397
# 48    Michael Johnson   21           0.0  Bench Press                 363
# 69    Michael Johnson   61           0.0        Squat                 273
# ...               ...  ...           ...          ...                 ...
# 2943  Michael Johnson   48           0.0     Deadlift                 148
# 2947  Michael Johnson   24           0.0     Deadlift                 183
# 2949  Michael Johnson   60           0.0        Squat                 181
# 2961  Michael Johnson   64           0.0     Deadlift                 209
# 2983  Michael Johnson   31           0.0  Bench Press                 166
#
# [292 rows x 5 columns]

# %%
df3.hist(figsize=(12,20), bins=100)
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Weight Class'}>],
#        [<Axes: title={'center': 'Amount Lifted (kg)'}>, <Axes: >]],
#       dtype=object)

# %%
web = pd.read_csv('/content/web-show 250.csv')

# %%
web.head()
# Out:
#    Unnamed: 0               names relese_date run_time rating_tag  rating
# 0           0      1 Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 1           1   2 Planet Earth II        2016    6 eps       TV-G     9.5
# 2           2      3 Planet Earth        2006   11 eps      TV-PG     9.4
# 3           3  4 Band of Brothers        2001   10 eps      TV-MA     9.4
# 4           4         5 Chernobyl        2019    5 eps      TV-MA     9.3

# %%
web.tail()
# Out:
#      Unnamed: 0                           names relese_date run_time  \
# 245         245              21 The Vietnam War        2017   10 eps
# 246         246                     22 Sherlock   2010–2017   15 eps
# 247         247              23 Attack on Titan   2013–2023   98 eps
# 248         248  24 Batman: The Animated Series   1992–1995   85 eps
# 249         249                   25 The Office   2005–2013  188 eps
#
#     rating_tag  rating
# 245      TV-MA     9.1
# 246      TV-14     9.1
# 247      TV-MA     9.1
# 248      TV-PG     9.0
# 249      TV-14     9.0

# %%
web.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   250 non-null    int64
#  1   names        250 non-null    object
#  2   relese_date  250 non-null    object
#  3   run_time     250 non-null    object
#  4   rating_tag   250 non-null    object
#  5   rating       250 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 11.8+ KB

# %%
web.isnull().sum()
# Out:
# Unnamed: 0     0
# names          0
# relese_date    0
# run_time       0
# rating_tag     0
# rating         0
# dtype: int64

# %%
web.head()
# Out:
#                 names relese_date run_time rating_tag  rating
# 0      1 Breaking Bad   2008–2013   62 eps      TV-MA     9.5
# 1   2 Planet Earth II        2016    6 eps       TV-G     9.5
# 2      3 Planet Earth        2006   11 eps      TV-PG     9.4
# 3  4 Band of Brothers        2001   10 eps      TV-MA     9.4
# 4         5 Chernobyl        2019    5 eps      TV-MA     9.3

# %%
web.isnull().sum()
# Out:
# names          0
# relese_date    0
# run_time       0
# rating_tag     0
# rating         0
# dtype: int64

# %%
web[web['names'] == '3 Planet Earth']
# Out:
#               names relese_date run_time rating_tag  rating
# 2    3 Planet Earth        2006   11 eps      TV-PG     9.4
# 27   3 Planet Earth        2006   11 eps      TV-PG     9.4
# 52   3 Planet Earth        2006   11 eps      TV-PG     9.4
# 77   3 Planet Earth        2006   11 eps      TV-PG     9.4
# 102  3 Planet Earth        2006   11 eps      TV-PG     9.4
# 127  3 Planet Earth        2006   11 eps      TV-PG     9.4
# 152  3 Planet Earth        2006   11 eps      TV-PG     9.4
# 177  3 Planet Earth        2006   11 eps      TV-PG     9.4
# 202  3 Planet Earth        2006   11 eps      TV-PG     9.4
# 227  3 Planet Earth        2006   11 eps      TV-PG     9.4

# %%
web[web['relese_date'] == '1992–1995']
# Out:
#                               names relese_date run_time rating_tag  rating
# 23   24 Batman: The Animated Series   1992–1995   85 eps      TV-PG     9.0
# 48   24 Batman: The Animated Series   1992–1995   85 eps      TV-PG     9.0
# 73   24 Batman: The Animated Series   1992–1995   85 eps      TV-PG     9.0
# 98   24 Batman: The Animated Series   1992–1995   85 eps      TV-PG     9.0
# 123  24 Batman: The Animated Series   1992–1995   85 eps      TV-PG     9.0
# 148  24 Batman: The Animated Series   1992–1995   85 eps      TV-PG     9.0
# 173  24 Batman: The Animated Series   1992–1995   85 eps      TV-PG     9.0
# 198  24 Batman: The Animated Series   1992–1995   85 eps      TV-PG     9.0
# 223  24 Batman: The Animated Series   1992–1995   85 eps      TV-PG     9.0
# 248  24 Batman: The Animated Series   1992–1995   85 eps      TV-PG     9.0

# %%
web[web['rating'] < 9.5]
# Out:
#                               names relese_date run_time rating_tag  rating
# 2                    3 Planet Earth        2006   11 eps      TV-PG     9.4
# 3                4 Band of Brothers        2001   10 eps      TV-MA     9.4
# 4                       5 Chernobyl        2019    5 eps      TV-MA     9.3
# 5                        6 The Wire   2002–2008   60 eps      TV-MA     9.3
# 6      7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV     9.3
# ..                              ...         ...      ...        ...     ...
# 245              21 The Vietnam War        2017   10 eps      TV-MA     9.1
# 246                     22 Sherlock   2010–2017   15 eps      TV-14     9.1
# 247              23 Attack on Titan   2013–2023   98 eps      TV-MA     9.1
# 248  24 Batman: The Animated Series   1992–1995   85 eps      TV-PG     9.0
# 249                   25 The Office   2005–2013  188 eps      TV-14     9.0
#
# [230 rows x 5 columns]

# %%
web[web['rating_tag'] == 'TV-Y7-FV']
# Out:
#                             names relese_date run_time rating_tag  rating
# 6    7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV     9.3
# 31   7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV     9.3
# 56   7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV     9.3
# 81   7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV     9.3
# 106  7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV     9.3
# 131  7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV     9.3
# 156  7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV     9.3
# 181  7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV     9.3
# 206  7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV     9.3
# 231  7 Avatar: The Last Airbender   2005–2008   62 eps   TV-Y7-FV     9.3

# %%
web.hist(figsize=(12,20), bins=100)
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
a = pd.read_csv('/content/1990sClassicHits.csv')

# %%
a.head()
# Out:
#                  Track          Artist Duration  Time_Signature  Danceability  \
# 0  Everybody Everybody       Black Box     4:11               4         0.645
# 1         Close To You     Maxi Priest     3:45               4         0.590
# 2               Do Me!  Bell Biv DeVoe     3:56               4         0.615
# 3           Everything     Jody Watley     4:05               4         0.704
# 4        What It Takes       Aerosmith     3:21               4         0.672
#
#    Energy  Key  Loudness  Mode  Speechiness  Acousticness  Instrumentalness  \
# 0   0.795    7   -12.095     1       0.0527        0.3470          0.003890
# 1   0.727    6    -7.955     1       0.0706        0.0259          0.000065
# 2   0.534    9    -6.719     0       0.0386        0.1060          0.000018
# 3   0.225    6   -14.454     0       0.0994        0.9020          0.657000
# 4   0.655   10    -5.021     0       0.0310        0.0362          0.000000
#
# ...

# %%
a.tail()
# Out:
#                        Track                                Artist Duration  \
# 914           I’m Your Angel              R. Kelly and Celine Dion     3:12
# 915        Taking Everything                         Gerald Levert     5:25
# 916     What’s It Gonna Be?!          Busta Rhymes featuring Janet     2:41
# 917     Almost Doesn’t Count                                Brandy     3:38
# 918  It Ain’t My Fault 1 & 2  Silkk the Shocker Featuring Mystikal     3:30
#
#      Time_Signature  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# 914               4         0.648   0.331    4   -10.952     1       0.0274
# 915               4         0.689   0.710    3    -5.395     0       0.0413
# 916               4         0.710   0.742    9    -4.699     0       0.0339
# 917               4         0.682   0.543    0    -7.063     0       0.0454
# 918               4         0.743   0.567    4   -12.468     0       0.2570
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 919 entries, 0 to 918
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Track             919 non-null    object
#  1   Artist            919 non-null    object
#  2   Duration          919 non-null    object
#  3   Time_Signature    919 non-null    int64
#  4   Danceability      919 non-null    float64
#  5   Energy            919 non-null    float64
#  6   Key               919 non-null    int64
#  7   Loudness          919 non-null    float64
#  8   Mode              919 non-null    int64
#  9   Speechiness       919 non-null    float64
#  10  Acousticness      919 non-null    float64
#  11  Instrumentalness  919 non-null    float64
#  12  Liveness          919 non-null    float64
#  13  Valence           919 non-null    float64
#  14  Tempo             919 non-null    float64
#  15  Popularity        919 non-null    int64
# ...

# %%
a.describe()
# Out:
#        Time_Signature  Danceability      Energy         Key    Loudness  \
# count      919.000000    919.000000  919.000000  919.000000  919.000000
# mean         3.947769      0.622967    0.623548    5.412405   -8.349071
# std          0.286769      0.154782    0.203975    3.514783    3.892821
# min          1.000000      0.135000    0.001340    0.000000  -42.950000
# 25%          4.000000      0.518500    0.479500    2.000000  -10.166500
# 50%          4.000000      0.631000    0.639000    6.000000   -7.599000
# 75%          4.000000      0.738000    0.780000    9.000000   -5.751000
# max          5.000000      0.979000    0.999000   11.000000    0.919000
#
#              Mode  Speechiness  Acousticness  Instrumentalness    Liveness  \
# count  919.000000   919.000000    919.000000        919.000000  919.000000
# mean     0.655060     0.075793      0.230068          0.052947    0.171865
# std      0.475608     0.079570      0.256284          0.180214    0.138296
# ...

# %%
a.isnull().sum()
# Out:
# Track               0
# Artist              0
# Duration            0
# Time_Signature      0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Popularity          0
# Year                0
# dtype: int64

# %%
a['Track']
# Out:
# 0          Everybody Everybody
# 1                 Close To You
# 2                       Do Me!
# 3                   Everything
# 4                What It Takes
#                 ...
# 914             I’m Your Angel
# 915          Taking Everything
# 916       What’s It Gonna Be?!
# 917       Almost Doesn’t Count
# 918    It Ain’t My Fault 1 & 2
# Name: Track, Length: 919, dtype: object

# %%
a.isnull().sum()
# Out:
# Track               0
# Artist              0
# Duration            0
# Time_Signature      0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Popularity          0
# Year                0
# dtype: int64
