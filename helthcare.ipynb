# %%
import pandas as pd

# %%
df = pd.read_csv('/content/healthcare_dataset.csv')

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df.tail()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 48496       AlICiA SMIth   58    Male         A+         Arthritis
# 48497      cHrIsTY BAker   32  Female         A+         Arthritis
# 48498  LindSay DICKErsoN   26    Male         O-            Cancer
# 48499       josEph lynCH   37    Male        AB+         Arthritis
# 48500        jiLl maRtIn   27  Female         B+          Diabetes
#
#       Date of Admission          Doctor                    Hospital  \
# 48496        2022-05-04  Michelle Smith  Ryan Garner Blackwell, and
# 48497        2020-02-07      Mary Davis                    Rice Ltd
# 48498        2019-07-05   Olivia Wright                Brennan-Reid
# 48499        2019-09-20    Rachel Huynh    Houston Glenn, and Perez
# 48500        2020-11-28      Kyle Smith                         NaN
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 48496              Aetna    16964.415013        443.0         Urgent
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48501 entries, 0 to 48500
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                48501 non-null  object
#  1   Age                 48501 non-null  int64
#  2   Gender              48501 non-null  object
#  3   Blood Type          48501 non-null  object
#  4   Medical Condition   48501 non-null  object
#  5   Date of Admission   48501 non-null  object
#  6   Doctor              48501 non-null  object
#  7   Hospital            48500 non-null  object
#  8   Insurance Provider  48500 non-null  object
#  9   Billing Amount      48500 non-null  float64
#  10  Room Number         48500 non-null  float64
#  11  Admission Type      48500 non-null  object
#  12  Discharge Date      48500 non-null  object
#  13  Medication          48500 non-null  object
#  14  Test Results        48500 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  48501.000000    48500.000000  48500.000000
# mean      51.597988    25563.788862    301.097711
# std       19.575619    14213.507307    115.170124
# min       18.000000    -2008.492140    101.000000
# 25%       35.000000    13250.792775    202.000000
# 50%       52.000000    25544.938022    302.000000
# 75%       69.000000    37850.164225    400.000000
# max       85.000000    52764.276736    500.000000

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              1
# Insurance Provider    1
# Billing Amount        1
# Room Number           1
# Admission Type        1
# Discharge Date        1
# Medication            1
# Test Results          1
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df.shape[0]
# Out:
# 48501

# %%
df.shape[1]
# Out:
# 15

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number           float64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df = df.fillna(0)
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 48496       AlICiA SMIth   58    Male         A+         Arthritis
# 48497      cHrIsTY BAker   32  Female         A+         Arthritis
# 48498  LindSay DICKErsoN   26    Male         O-            Cancer
# 48499       josEph lynCH   37    Male        AB+         Arthritis
# 48500        jiLl maRtIn   27  Female         B+          Diabetes
#
#       Date of Admission            Doctor                    Hospital  \
# 0            2024-01-31     Matthew Smith             Sons and Miller
# ...

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df[df['Gender'] == 'Female']
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 2             DaNnY sMitH   76  Female         A-           Obesity
# 3            andrEw waTtS   28  Female         O+          Diabetes
# 4           adrIENNE bEll   43  Female        AB+            Cancer
# 6          edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7      CHrisTInA MARtinez   20  Female         A+            Cancer
# ...                   ...  ...     ...        ...               ...
# 48489          Mary bRaDY   49  Female         A+          Diabetes
# 48493      mR. mARK bates   79  Female        AB-           Obesity
# 48495       MIchael YouNg   58  Female         O+          Diabetes
# 48497       cHrIsTY BAker   32  Female         A+         Arthritis
# 48500         jiLl maRtIn   27  Female         B+          Diabetes
#
#       Date of Admission               Doctor                     Hospital  \
# 2            2022-09-22     Tiffany Mitchell                     Cook PLC
# ...

# %%
df[df['Gender'] == 'Female'].select_dtypes(include='number').sum()
# Out:
# Age               1.254084e+06
# Billing Amount    6.192882e+08
# Room Number       7.326291e+06
# dtype: float64

# %%
df[df['Gender'] == 'Male']
# Out:
#                     Name  Age Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30   Male         B-            Cancer
# 1           LesLie TErRy   62   Male         A+           Obesity
# 5          EMILY JOHNSOn   36   Male         A+            Asthma
# 8        JASmINe aGuIlaR   82   Male        AB+            Asthma
# 10      mIchElLe daniELs   72   Male         O+            Cancer
# ...                  ...  ...    ...        ...               ...
# 48492       DannY HOWARd   36   Male         B-            Asthma
# 48494    nichoLas WeAvEr   71   Male        AB-         Arthritis
# 48496       AlICiA SMIth   58   Male         A+         Arthritis
# 48498  LindSay DICKErsoN   26   Male         O-            Cancer
# 48499       josEph lynCH   37   Male        AB+         Arthritis
#
#       Date of Admission           Doctor                    Hospital  \
# 0            2024-01-31    Matthew Smith             Sons and Miller
# ...

# %%
df[df['Gender'] == 'Male'].select_dtypes(include='number').sum()
# Out:
# Age               1.248470e+06
# Billing Amount    6.205556e+08
# Room Number       7.276948e+06
# dtype: float64

# %%
df[df['Blood Type'] == 'A+']
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 1            LesLie TErRy   62    Male         A+           Obesity
# 5           EMILY JOHNSOn   36    Male         A+            Asthma
# 7      CHrisTInA MARtinez   20  Female         A+            Cancer
# 12          connOR HANsEn   75  Female         A+          Diabetes
# 16          haley perkins   63  Female         A+         Arthritis
# ...                   ...  ...     ...        ...               ...
# 48486        JAMES cartEr   71  Female         A+      Hypertension
# 48489          Mary bRaDY   49  Female         A+          Diabetes
# 48490   BRENDA sTrICkLaND   37    Male         A+         Arthritis
# 48496        AlICiA SMIth   58    Male         A+         Arthritis
# 48497       cHrIsTY BAker   32  Female         A+         Arthritis
#
#       Date of Admission            Doctor                     Hospital  \
# 1            2019-08-20   Samantha Davies                      Kim Inc
# ...

# %%
df[df['Medical Condition'] == 'Asthma']
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 5        EMILY JOHNSOn   36    Male         A+            Asthma
# 8      JASmINe aGuIlaR   82    Male        AB+            Asthma
# 13        rObeRt bAuer   68  Female        AB+            Asthma
# 19      dANIEL schmIdt   63    Male         B+            Asthma
# 20       tIMOTHY burNs   67  Female         A-            Asthma
# ...                ...  ...     ...        ...               ...
# 48482    kIMBErLy CoBb   51  Female         O+            Asthma
# 48487     JoAnna ElLis   65    Male        AB+            Asthma
# 48488    keITH sALINAS   31    Male         B-            Asthma
# 48491     JOANNe daVIs   36    Male         O-            Asthma
# 48492     DannY HOWARd   36    Male         B-            Asthma
#
#       Date of Admission           Doctor          Hospital Insurance Provider  \
# 5            2023-12-20    Taylor Newton    Nunez-Humphrey   UnitedHealthcare
# ...

# %%
df[df['Age'] < 30]
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 3            andrEw waTtS   28  Female         O+          Diabetes
# 6          edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7      CHrisTInA MARtinez   20  Female         A+            Cancer
# 31        JAmES pattERson   23  Female         A+         Arthritis
# 35         DAvID AndErSON   25  Female        AB+            Asthma
# ...                   ...  ...     ...        ...               ...
# 48452       JAsOn lEONARD   27  Female         B+           Obesity
# 48468         rOnniE TOdD   26  Female        AB-           Obesity
# 48481       mELanIe ReYes   23    Male        AB-           Obesity
# 48498   LindSay DICKErsoN   26    Male         O-            Cancer
# 48500         jiLl maRtIn   27  Female         B+          Diabetes
#
#       Date of Admission            Doctor                     Hospital  \
# 3            2020-11-18       Kevin Wells   Hernandez Rogers and Vang,
# ...

# %%
df[df['Date of Admission'] == '2021-12-28']
# Out:
#                        Name  Age  Gender Blood Type Medical Condition  \
# 7        CHrisTInA MARtinez   20  Female         A+            Cancer
# 1637       ChristINa barber   42    Male        AB-           Obesity
# 2200          dougLAS RIVAs   72    Male         B-            Cancer
# 3924           EmilY HUnteR   40  Female         A+            Asthma
# 5380           SCoTt garNEr   77    Male        AB+            Cancer
# 6526           CAthy FLoRES   19    Male        AB-          Diabetes
# 7556             Jose WHite   48  Female        AB-         Arthritis
# 9372   KiMbERly menDOzA PHD   64  Female         A+           Obesity
# 9902            viCkI sMITh   19    Male         A+          Diabetes
# 11612            Bryan huFf   19    Male         O+      Hypertension
# 12077           mARIo BaTES   57    Male        AB-      Hypertension
# 12607         MoRgaN MilLeR   55  Female        AB+            Cancer
# ...

# %%
df[(df['Doctor'] == 'Jorge Torres') | (df['Doctor'] == 'Patrick Kennedy')]
# Out:
#                Name  Age  Gender Blood Type Medical Condition  \
# 3924   EmilY HUnteR   40  Female         A+            Asthma
# 35138  dAniEl gREEn   54  Female         B+           Obesity
#
#       Date of Admission           Doctor                      Hospital  \
# 3924         2021-12-28     Jorge Torres       Lucas, Ward and Leonard
# 35138        2021-12-28  Patrick Kennedy  Castillo and Johnson, Adkins
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 3924    UnitedHealthcare    10749.631883        396.0         Urgent
# 35138         Blue Cross      990.015823        194.0         Urgent
#
#       Discharge Date  Medication  Test Results
# 3924      2022-01-18     Aspirin  Inconclusive
# 35138     2022-01-15  Penicillin  Inconclusive

# %%
df[df['Hospital'] == 'LLC Hernandez']
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 567          SCoTT KIng   66    Male         O+          Diabetes
# 752    mR. RobeRT DaVIS   76  Female         B+            Cancer
# 915         aMBer NiXoN   40    Male         O+         Arthritis
# 5401          TylEr Cox   23    Male         B-          Diabetes
# 15923        ryaN youNg   29  Female         B+           Obesity
# 16933     jeREMy dOdsOn   81  Female         O-           Obesity
# 21429     caNdACe oLseN   61    Male        AB-         Arthritis
# 24571      niCoLe WElls   53    Male         B-            Cancer
# 27181   AnGelA HATFieLD   52  Female         A-      Hypertension
# 48452     JAsOn lEONARD   27  Female         B+           Obesity
#
#       Date of Admission            Doctor       Hospital Insurance Provider  \
# 567          2020-01-11   Jessica Jackson  LLC Hernandez              Aetna
# 752          2023-03-16     Kenneth White  LLC Hernandez              Aetna
# ...

# %%
df['Insurance Provider']
# Out:
# 0              Blue Cross
# 1                Medicare
# 2                   Aetna
# 3                Medicare
# 4                   Aetna
#                ...
# 48496               Aetna
# 48497               Aetna
# 48498    UnitedHealthcare
# 48499    UnitedHealthcare
# 48500                   0
# Name: Insurance Provider, Length: 48501, dtype: object

# %%
df[df['Insurance Provider'] == 'Aetna']
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 2              DaNnY sMitH   76  Female         A-           Obesity
# 4            adrIENNE bEll   43  Female        AB+            Cancer
# 21      ChRISToPHEr BRiGhT   48    Male         B+            Asthma
# 22         KatHRYn StewArt   58  Female         O+         Arthritis
# 23     dR. EilEEn thomPsoN   59    Male         A+            Asthma
# ...                    ...  ...     ...        ...               ...
# 48479        AndrES FaRmEr   42  Female         B+          Diabetes
# 48490    BRENDA sTrICkLaND   37    Male         A+         Arthritis
# 48492         DannY HOWARd   36    Male         B-            Asthma
# 48496         AlICiA SMIth   58    Male         A+         Arthritis
# 48497        cHrIsTY BAker   32  Female         A+         Arthritis
#
#       Date of Admission             Doctor                     Hospital  \
# ...

# %%
df[df['Billing Amount'] < 1000]
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 20          tIMOTHY burNs   67  Female         A-            Asthma
# 132       ashLEy ERIcKSoN   32  Female        AB-            Cancer
# 312    ANgeL RaNDOlPH ddS   74  Female         A+            Asthma
# 799     CHRisTOPHer wEiss   49  Female        AB-            Asthma
# 1018        AsHley WaRnER   60    Male         A+      Hypertension
# ...                   ...  ...     ...        ...               ...
# 48000     HOLLY RoDrIguEz   43    Male         O+           Obesity
# 48044         wAnDa CHaSE   60    Male         O-      Hypertension
# 48063       KristA conLEY   21  Female         O+          Diabetes
# 48488       keITH sALINAS   31    Male         B-            Asthma
# 48500         jiLl maRtIn   27  Female         B+          Diabetes
#
#       Date of Admission              Doctor                   Hospital  \
# 20           2023-06-28        Krista Smith                  Jones LLC
# ...

# %%
df[df['Billing Amount'] < 1000] ['Billing Amount'].sum()
# Out:
# 121725.32575079364

# %%
df[['Room Number', 'Admission Type']]
# Out:
#        Room Number Admission Type
# 0            328.0         Urgent
# 1            265.0      Emergency
# 2            205.0      Emergency
# 3            450.0       Elective
# 4            458.0         Urgent
# ...            ...            ...
# 48496        443.0         Urgent
# 48497        174.0      Emergency
# 48498        367.0       Elective
# 48499        151.0       Elective
# 48500          0.0              0
#
# [48501 rows x 2 columns]

# %%
df[df['Discharge Date'] == '2019-11-23']
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 132       ashLEy ERIcKSoN   32  Female        AB-            Cancer
# 1746         haYleY crAIg   21    Male         O+      Hypertension
# 3022         Erica wagNER   45    Male         B-          Diabetes
# 3904          brIaN DaVIs   60  Female         O+           Obesity
# 4958       jESSiCa bReWER   79  Female         O-            Cancer
# 7975       KAyLA GOnZALeZ   74  Female         O+            Asthma
# 9656         stEvEn dAvis   60    Male         O-            Asthma
# 10216        RYAn staNlEy   55  Female        AB+            Asthma
# 11466         amBer lOpEZ   74    Male         A-            Asthma
# 13413     NicoLe PhiLlips   74    Male         B-          Diabetes
# 14053       tHomaS aDKIns   76    Male        AB-         Arthritis
# 15341      KrISta hoLlAnd   45    Male         O-            Asthma
# 22277          JaNet rioS   73    Male         A-      Hypertension
# ...

# %%
df[df['Medication'] == 'Lipitor']
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 11          aaRon MARtiNeZ   38  Female         A-      Hypertension
# 13            rObeRt bAuer   68  Female        AB+            Asthma
# 21      ChRISToPHEr BRiGhT   48    Male         B+            Asthma
# 22         KatHRYn StewArt   58  Female         O+         Arthritis
# 23     dR. EilEEn thomPsoN   59    Male         A+            Asthma
# ...                    ...  ...     ...        ...               ...
# 48479        AndrES FaRmEr   42  Female         B+          Diabetes
# 48488        keITH sALINAS   31    Male         B-            Asthma
# 48490    BRENDA sTrICkLaND   37    Male         A+         Arthritis
# 48493       mR. mARK bates   79  Female        AB-           Obesity
# 48497        cHrIsTY BAker   32  Female         A+         Arthritis
#
#       Date of Admission               Doctor                     Hospital  \
# ...

# %%
df[df['Test Results'] == 'Normal']
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 0         Bobby JacksOn   30    Male         B-            Cancer
# 2           DaNnY sMitH   76  Female         A-           Obesity
# 5         EMILY JOHNSOn   36    Male         A+            Asthma
# 10     mIchElLe daniELs   72    Male         O+            Cancer
# 13         rObeRt bAuer   68  Female        AB+            Asthma
# ...                 ...  ...     ...        ...               ...
# 48492      DannY HOWARd   36    Male         B-            Asthma
# 48493    mR. mARK bates   79  Female        AB-           Obesity
# 48494   nichoLas WeAvEr   71    Male        AB-         Arthritis
# 48495     MIchael YouNg   58  Female         O+          Diabetes
# 48496      AlICiA SMIth   58    Male         A+         Arthritis
#
#       Date of Admission               Doctor                    Hospital  \
# 0            2024-01-31        Matthew Smith             Sons and Miller
# ...

# %%
df['Same'] = df.apply(lambda row: row['Hospital'] == row['Room Number'], axis=1)
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 48496       AlICiA SMIth   58    Male         A+         Arthritis
# 48497      cHrIsTY BAker   32  Female         A+         Arthritis
# 48498  LindSay DICKErsoN   26    Male         O-            Cancer
# 48499       josEph lynCH   37    Male        AB+         Arthritis
# 48500        jiLl maRtIn   27  Female         B+          Diabetes
#
#       Date of Admission            Doctor                    Hospital  \
# 0            2024-01-31     Matthew Smith             Sons and Miller
# ...

# %%
df['Same'] = df.apply(lambda row: row['Hospital'] == 'Cook PLC' and row['Room Number'] == 265.0, axis=1)
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 48496       AlICiA SMIth   58    Male         A+         Arthritis
# 48497      cHrIsTY BAker   32  Female         A+         Arthritis
# 48498  LindSay DICKErsoN   26    Male         O-            Cancer
# 48499       josEph lynCH   37    Male        AB+         Arthritis
# 48500        jiLl maRtIn   27  Female         B+          Diabetes
#
#       Date of Admission            Doctor                    Hospital  \
# 0            2024-01-31     Matthew Smith             Sons and Miller
# ...

# %%
df[df['Blood Type'] == 'AB+']
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# 8        JASmINe aGuIlaR   82    Male        AB+            Asthma
# 13          rObeRt bAuer   68  Female        AB+            Asthma
# 14          bROOkE brady   44  Female        AB+            Cancer
# 24        PAUl hEndERsOn   72  Female        AB+      Hypertension
# ...                  ...  ...     ...        ...               ...
# 48480      cHriSTY NOvAk   54    Male        AB+         Arthritis
# 48484       ROBeRTa HAll   31  Female        AB+         Arthritis
# 48485  sAmUEL mcCuLLoUGh   51  Female        AB+          Diabetes
# 48487       JoAnna ElLis   65    Male        AB+            Asthma
# 48499       josEph lynCH   37    Male        AB+         Arthritis
#
#       Date of Admission            Doctor                    Hospital  \
# 4            2022-09-19    Kathleen Hanna                 White-White
# ...

# %%
df[10:100]
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 10   mIchElLe daniELs   72    Male         O+            Cancer
# 11     aaRon MARtiNeZ   38  Female         A-      Hypertension
# 12      connOR HANsEn   75  Female         A+          Diabetes
# 13       rObeRt bAuer   68  Female        AB+            Asthma
# 14       bROOkE brady   44  Female        AB+            Cancer
# ..                ...  ...     ...        ...               ...
# 95  cathERinE gArDnEr   79  Female         A-      Hypertension
# 96      ANNE THOMPSoN   76  Female         O+          Diabetes
# 97        TOdd coopeR   55  Female         A+          Diabetes
# 98      PhILLIP lyOnS   53    Male         B-            Cancer
# 99          MaRk foRD   18    Male         B+            Asthma
#
#    Date of Admission              Doctor                       Hospital  \
# 10        2020-04-19         John Duncan                Schaefer-Porter
# ...

# %%
df[-1:]
# Out:
#               Name  Age  Gender Blood Type Medical Condition  \
# 48500  jiLl maRtIn   27  Female         B+          Diabetes
#
#       Date of Admission      Doctor Hospital Insurance Provider  \
# 48500        2020-11-28  Kyle Smith        0                  0
#
#        Billing Amount  Room Number Admission Type Discharge Date Medication  \
# 48500             0.0          0.0              0              0          0
#
#       Test Results   Same
# 48500            0  False

# %%
df[50:60]
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 50          mIchael LiU   30    Male        AB-      Hypertension
# 51       STepHaNie kEnt   42  Female         A-            Cancer
# 52          JessE BaNks   67  Female        AB+            Cancer
# 53            PeGGY LEe   24  Female         A-           Obesity
# 54     TAmARa hErNAndez   84  Female         B-            Asthma
# 55  mR. DAVID pIERce Md   73  Female         A-      Hypertension
# 56        beThaNY MoOrE   55  Female         A+            Cancer
# 57        MIChael MIllS   23    Male         O-      Hypertension
# 58           kyle Wiley   40  Female        AB-            Cancer
# 59    jACqUeLINE jORdaN   51    Male         O+      Hypertension
#
#    Date of Admission               Doctor                        Hospital  \
# 50        2024-04-05         Vicki Nguyen   Fernandez and Phillips, Singh
# 51        2019-06-15            Mary Moss                   Beck-Galloway
# ...

# %%
df[:10]
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 0       Bobby JacksOn   30    Male         B-            Cancer
# 1        LesLie TErRy   62    Male         A+           Obesity
# 2         DaNnY sMitH   76  Female         A-           Obesity
# 3        andrEw waTtS   28  Female         O+          Diabetes
# 4       adrIENNE bEll   43  Female        AB+            Cancer
# 5       EMILY JOHNSOn   36    Male         A+            Asthma
# 6      edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7  CHrisTInA MARtinez   20  Female         A+            Cancer
# 8     JASmINe aGuIlaR   82    Male        AB+            Asthma
# 9    ChRISTopher BerG   58  Female        AB-            Cancer
#
#   Date of Admission            Doctor                     Hospital  \
# 0        2024-01-31     Matthew Smith              Sons and Miller
# 1        2019-08-20   Samantha Davies                      Kim Inc
# ...

# %%
df[:-10]
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 48486       JAMES cartEr   71  Female         A+      Hypertension
# 48487       JoAnna ElLis   65    Male        AB+            Asthma
# 48488      keITH sALINAS   31    Male         B-            Asthma
# 48489         Mary bRaDY   49  Female         A+          Diabetes
# 48490  BRENDA sTrICkLaND   37    Male         A+         Arthritis
#
#       Date of Admission            Doctor                    Hospital  \
# 0            2024-01-31     Matthew Smith             Sons and Miller
# ...

# %%
df[100:200]
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 100        mARcUS ZAmorA   69    Male         O+         Arthritis
# 101          KaTiE hENry   70    Male         B+          Diabetes
# 102       wilLIAm morTON   21    Male         A+          Diabetes
# 103       KaTRina maRTin   47    Male         A-          Diabetes
# 104         HunTeR mckAy   85    Male         A-         Arthritis
# ..                   ...  ...     ...        ...               ...
# 195        Mark lAWrencE   19  Female         O-          Diabetes
# 196           JOhN eLlis   83  Female         A-      Hypertension
# 197  MRs. TiFFAny DeNnIs   26    Male         O-          Diabetes
# 198        cyNTHIa HuANG   51    Male         O+         Arthritis
# 199     meLiSSA LawRENcE   20    Male         O+           Obesity
#
#     Date of Admission             Doctor                           Hospital  \
# 100        2021-11-13      Jeremiah Wolf      Hernandez, Ritter and Huffman
# ...

# %%
df[['Name', 'Insurance Provider']]
# Out:
#                     Name Insurance Provider
# 0          Bobby JacksOn         Blue Cross
# 1           LesLie TErRy           Medicare
# 2            DaNnY sMitH              Aetna
# 3           andrEw waTtS           Medicare
# 4          adrIENNE bEll              Aetna
# ...                  ...                ...
# 48496       AlICiA SMIth              Aetna
# 48497      cHrIsTY BAker              Aetna
# 48498  LindSay DICKErsoN   UnitedHealthcare
# 48499       josEph lynCH   UnitedHealthcare
# 48500        jiLl maRtIn                  0
#
# [48501 rows x 2 columns]

# %%
df.hist(figsize = (20,12), bins = 100)
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Billing Amount'}>],
#        [<Axes: title={'center': 'Room Number'}>, <Axes: >]], dtype=object)
