# %%
import pandas as pd

# %%
house = pd.read_csv('/content/Bengaluru_House_Data.csv')

# %%
house
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
house.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
house.tail()
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
house.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
house.shape[0]
# Out:
# 13320

# %%
house.shape[1]
# Out:
# 9

# %%
house.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
house = house.fillna(0)
house
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
house.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
house['location']
# Out:
# 0        Electronic City Phase II
# 1                Chikka Tirupathi
# 2                     Uttarahalli
# 3              Lingadheeranahalli
# 4                        Kothanur
#                    ...
# 13315                  Whitefield
# 13316               Richards Town
# 13317       Raja Rajeshwari Nagar
# 13318             Padmanabhanagar
# 13319                Doddathoguru
# Name: location, Length: 13320, dtype: object

# %%
house['location'] == 'Uttarahalli'
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 13315    False
# 13316    False
# 13317    False
# 13318    False
# 13319    False
# Name: location, Length: 13320, dtype: bool

# %%
house[house['location'] == 'Uttarahalli']
# Out:
#                   area_type   availability     location       size  society  \
# 2            Built-up  Area  Ready To Move  Uttarahalli      3 BHK        0
# 39           Built-up  Area  Ready To Move  Uttarahalli      2 BHK        0
# 336          Built-up  Area  Ready To Move  Uttarahalli      2 BHK  Sungspr
# 546    Super built-up  Area  Ready To Move  Uttarahalli      2 BHK        0
# 761    Super built-up  Area  Ready To Move  Uttarahalli      2 BHK  Siayayo
# ...                     ...            ...          ...        ...      ...
# 13037        Built-up  Area  Ready To Move  Uttarahalli  3 Bedroom        0
# 13088  Super built-up  Area  Ready To Move  Uttarahalli      3 BHK  Ayaya A
# 13230  Super built-up  Area  Ready To Move  Uttarahalli      3 BHK  Aklia R
# 13271  Super built-up  Area  Ready To Move  Uttarahalli      2 BHK  Ayaya A
# 13313  Super built-up  Area  Ready To Move  Uttarahalli      3 BHK  Aklia R
#
#       total_sqft  bath  balcony   price
# ...

# %%
house[house['location'] == 'Uttarahalli'].shape[0]
# Out:
# 186

# %%
house[house['availability'] == 'Ready To Move']
# Out:
#                   area_type   availability               location       size  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area  Ready To Move            Uttarahalli      3 BHK
# 3      Super built-up  Area  Ready To Move     Lingadheeranahalli      3 BHK
# 4      Super built-up  Area  Ready To Move               Kothanur      2 BHK
# 5      Super built-up  Area  Ready To Move             Whitefield      2 BHK
# ...                     ...            ...                    ...        ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout      3 BHK
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
# ...

# %%
house['society']
# Out:
# 0        Coomee
# 1        Theanmp
# 2              0
# 3        Soiewre
# 4              0
#           ...
# 13315    ArsiaEx
# 13316          0
# 13317    Mahla T
# 13318    SollyCl
# 13319          0
# Name: society, Length: 13320, dtype: object

# %%
house.loc[(house['area_type'] == 'Built-up Area') & (house['size'] == '3 BHK')]
# Out:
# Empty DataFrame
# Columns: [area_type, availability, location, size, society, total_sqft, bath, balcony, price]
# Index: []

# %%
house.iloc[10:20, 1:6]
# Out:
#      availability               location       size  society total_sqft
# 10         18-Feb             Whitefield      3 BHK        0       1800
# 11  Ready To Move             Whitefield  4 Bedroom  Prrry M       2785
# 12  Ready To Move     7th Phase JP Nagar      2 BHK  Shncyes       1000
# 13  Ready To Move              Gottigere      2 BHK        0       1100
# 14  Ready To Move               Sarjapur  3 Bedroom  Skityer       2250
# 15  Ready To Move            Mysore Road      2 BHK  PrntaEn       1175
# 16  Ready To Move          Bisuvanahalli      3 BHK  Prityel       1180
# 17  Ready To Move  Raja Rajeshwari Nagar      3 BHK  GrrvaGr       1540
# 18  Ready To Move  Ramakrishnappa Layout      3 BHK  PeBayle       2770
# 19  Ready To Move     Manayata Tech Park      2 BHK        0       1100
