# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Books.csv')
# Out:
# <ipython-input-76-d640ef7c1484>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Books.csv')

# %%
df.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
df.tail()
# Out:
#               ISBN                                         Book-Title  \
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                 Book-Author Year-Of-Publication  \
# 271355       Paula Danziger                1988
# 271356           Teri Sloat                1991
# 271357     Christine Wicker                2004
# 271358                Plato                1996
# 271359  Christopher  Biffle                2000
#
#                                                Publisher  \
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# ...

# %%
df.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
df.shape[0]
# Out:
# 271360

# %%
df.shape[1]
# Out:
# 8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
df.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# ...

# %%
df.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
df = df.fillna(0)
df
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
df.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# dtype: int64

# %%
df['Book-Title']
# Out:
# 0                                       Classical Mythology
# 1                                              Clara Callan
# 2                                      Decision in Normandy
# 3         Flu: The Story of the Great Influenza Pandemic...
# 4                                    The Mummies of Urumchi
#                                 ...
# 271355                           There's a Bat in Bunk Five
# 271356                              From One to One Hundred
# 271357    Lily Dale : The True Story of the Town that Ta...
# 271358                          Republic (World's Classics)
# 271359    A Guided Tour of Rene Descartes' Meditations o...
# Name: Book-Title, Length: 271360, dtype: object

# %%
df['Image-URL-S']
# Out:
# 0         http://images.amazon.com/images/P/0195153448.0...
# 1         http://images.amazon.com/images/P/0002005018.0...
# 2         http://images.amazon.com/images/P/0060973129.0...
# 3         http://images.amazon.com/images/P/0374157065.0...
# 4         http://images.amazon.com/images/P/0393045218.0...
#                                 ...
# 271355    http://images.amazon.com/images/P/0440400988.0...
# 271356    http://images.amazon.com/images/P/0525447644.0...
# 271357    http://images.amazon.com/images/P/006008667X.0...
# 271358    http://images.amazon.com/images/P/0192126040.0...
# 271359    http://images.amazon.com/images/P/0767409752.0...
# Name: Image-URL-S, Length: 271360, dtype: object

# %%
df[['Year-Of-Publication','Publisher']]
# Out:
#        Year-Of-Publication                                         Publisher
# 0                     2002                           Oxford University Press
# 1                     2001                             HarperFlamingo Canada
# 2                     1991                                   HarperPerennial
# 3                     1999                              Farrar Straus Giroux
# 4                     1999                        W. W. Norton &amp; Company
# ...                    ...                                               ...
# 271355                1988                   Random House Childrens Pub (Mm)
# 271356                1991                                      Dutton Books
# 271357                2004                                HarperSanFrancisco
# 271358                1996                           Oxford University Press
# 271359                2000  McGraw-Hill Humanities/Social Sciences/Languages
#
# [271360 rows x 2 columns]

# %%
df2 = pd.read_csv('/content/Ratings.csv')

# %%
df2.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
df2.tail()
# Out:
#          User-ID         ISBN  Book-Rating
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8

# %%
df2.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
df.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271360               271360
# unique      271360          242135           102023                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271360                                             271360
# unique      16808                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  Image-URL-L
# count                                              271360       271360
# unique                                             271044       271042
# ...

# %%
df2 = df2.fillna(0)
df2
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
df2.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
df['ISBN']
# Out:
# 0         0195153448
# 1         0002005018
# 2         0060973129
# 3         0374157065
# 4         0393045218
#              ...
# 271355    0440400988
# 271356    0525447644
# 271357    006008667X
# 271358    0192126040
# 271359    0767409752
# Name: ISBN, Length: 271360, dtype: object

# %%
df2.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')

# %%
df2[['User-ID', 'Book-Rating']]
# Out:
#          User-ID  Book-Rating
# 0         276725            0
# 1         276726            5
# 2         276727            0
# 3         276729            3
# 4         276729            6
# ...          ...          ...
# 1149775   276704            9
# 1149776   276706            0
# 1149777   276709           10
# 1149778   276721           10
# 1149779   276723            8
#
# [1149780 rows x 2 columns]

# %%
user = pd.read_csv('/content/Users.csv')

# %%
user
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
user.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
user.columns
# Out:
# Index(['User-ID', 'Location', 'Age'], dtype='object')

# %%
user.drop('User-ID', axis=1, inplace=True)

# %%
user
# Out:
#                                   Location   Age
# 0                       nyc, new york, usa   NaN
# 1                stockton, california, usa  18.0
# 2          moscow, yukon territory, russia   NaN
# 3                porto, v.n.gaia, portugal  17.0
# 4       farnborough, hants, united kingdom   NaN
# ...                                    ...   ...
# 278853               portland, oregon, usa   NaN
# 278854  tacoma, washington, united kingdom  50.0
# 278855           brampton, ontario, canada   NaN
# 278856           knoxville, tennessee, usa   NaN
# 278857                dublin, n/a, ireland   NaN
#
# [278858 rows x 2 columns]

# %%
user.isnull().sum()
# Out:
# Location         0
# Age         110762
# dtype: int64

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Location  278858 non-null  object
#  1   Age       168096 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 4.3+ MB

# %%
user.describe()
# Out:
#                  Age
# count  168096.000000
# mean       34.751434
# std        14.428097
# min         0.000000
# 25%        24.000000
# 50%        32.000000
# 75%        44.000000
# max       244.000000

# %%
user = user.fillna(50)
user
# Out:
#                                   Location   Age
# 0                       nyc, new york, usa  50.0
# 1                stockton, california, usa  18.0
# 2          moscow, yukon territory, russia  50.0
# 3                porto, v.n.gaia, portugal  17.0
# 4       farnborough, hants, united kingdom  50.0
# ...                                    ...   ...
# 278853               portland, oregon, usa  50.0
# 278854  tacoma, washington, united kingdom  50.0
# 278855           brampton, ontario, canada  50.0
# 278856           knoxville, tennessee, usa  50.0
# 278857                dublin, n/a, ireland  50.0
#
# [278858 rows x 2 columns]

# %%
user.isnull().sum()
# Out:
# Location    0
# Age         0
# dtype: int64

# %%
user['Location']
# Out:
# 0                         nyc, new york, usa
# 1                  stockton, california, usa
# 2            moscow, yukon territory, russia
# 3                  porto, v.n.gaia, portugal
# 4         farnborough, hants, united kingdom
#                          ...
# 278853                 portland, oregon, usa
# 278854    tacoma, washington, united kingdom
# 278855             brampton, ontario, canada
# 278856             knoxville, tennessee, usa
# 278857                  dublin, n/a, ireland
# Name: Location, Length: 278858, dtype: object

# %%
user['Age']
# Out:
# 0         50.0
# 1         18.0
# 2         50.0
# 3         17.0
# 4         50.0
#           ...
# 278853    50.0
# 278854    50.0
# 278855    50.0
# 278856    50.0
# 278857    50.0
# Name: Age, Length: 278858, dtype: float64

# %%
merged_df = pd.concat([df,df2,user], axis = 1, join = 'inner')
merged_df
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271360 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271360 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271360 non-null  object
#  8   User-ID              271360 non-null  int64
#  9   ISBN                 271360 non-null  object
#  10  Book-Rating          271360 non-null  int64
#  11  Location             271360 non-null  object
#  12  Age                  271360 non-null  float64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 26.9+ MB

# %%
merged_df.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            0
# User-ID                0
# ISBN                   0
# Book-Rating            0
# Location               0
# Age                    0
# dtype: int64

# %%
merged_df.describe()
# Out:
#             User-ID   Book-Rating            Age
# count  271360.00000  271360.00000  271360.000000
# mean    40495.42322       2.97224      40.846890
# std     48566.47871       3.88175      13.441125
# min         2.00000       0.00000       0.000000
# 25%     16634.00000       0.00000      29.000000
# 50%     32483.00000       0.00000      49.000000
# 75%     49529.00000       7.00000      50.000000
# max    278854.00000      10.00000     244.000000

# %%
merged_df[['Publisher','Book-Rating']]
# Out:
#                                                Publisher  Book-Rating
# 0                                Oxford University Press            0
# 1                                  HarperFlamingo Canada            5
# 2                                        HarperPerennial            0
# 3                                   Farrar Straus Giroux            3
# 4                             W. W. Norton &amp; Company            6
# ...                                                  ...          ...
# 271355                   Random House Childrens Pub (Mm)            0
# 271356                                      Dutton Books            0
# 271357                                HarperSanFrancisco            0
# 271358                           Oxford University Press            0
# 271359  McGraw-Hill Humanities/Social Sciences/Languages            0
#
# [271360 rows x 2 columns]

# %%
merged_df[merged_df['Age'] < 50]
# Out:
#               ISBN                                         Book-Title  \
# 1       0002005018                                       Clara Callan
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 9       074322678X            Where You'll Find Me: And Other Stories
# 10      0771074670                        Nights Below Station Street
# 12      0887841740                                 The Middle Stories
# ...            ...                                                ...
# 271352  1845170423                                  Cocktail Classics
# 271353  014002803X                                  Anti Death League
# 271355  0440400988                         There's a Bat in Bunk Five
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 1       Richard Bruce Wright                2001
# ...

# %%
merged_df[merged_df['Age'] > 50]
# Out:
#               ISBN                                         Book-Title  \
# 5       0399135782                             The Kitchen God's Wife
# 24      0439095026                       Tell Me This Isn't Happening
# 43      0061099686                                           Downtown
# 62      0679865691                         Haveli (Laurel Leaf Books)
# 88      0375509038  The Right Man : The Surprise Presidency of Geo...
# ...            ...                                                ...
# 271297  067975475X                             Skinned Alive: Stories
# 271306  1843096595                            Papercrafts and Origami
# 271317  359610601X  Der gelbe Stern: Die Judenvernichtung in Europ...
# 271326  0070542023                       Basic Scientific Subroutines
# 271340  3596156904                                              Amok.
#
#                    Book-Author Year-Of-Publication                 Publisher  \
# ...

# %%
merged_df[merged_df['Book-Rating'] > 0]
# Out:
#               ISBN                                         Book-Title  \
# 1       0002005018                                       Clara Callan
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# 6       0425176428  What If?: The World's Foremost Military Histor...
# 7       0671870432                                    PLEADING GUILTY
# ...            ...                                                ...
# 271342  0130897930                 Core Web Programming (2nd Edition)
# 271351  1582380805  Tropical Rainforests: 230 Species in Full Colo...
# 271352  1845170423                                  Cocktail Classics
# 271353  014002803X                                  Anti Death League
# 271354  0449906736      Flashpoints: Promise and Peril in a New World
#
#                   Book-Author Year-Of-Publication  \
# 1        Richard Bruce Wright                2001
# ...

# %%
merged_df[merged_df['Publisher'] == 'HarperFlamingo Canada']
# Out:
#               ISBN                                         Book-Title  \
# 1       0002005018                                       Clara Callan
# 13961   0002005395                                          Deafening
# 48704   0002006588                                          Vancouver
# 69955   0002255081                                          Spadework
# 72119   0002005050                                       The Romantic
# 73234   0002554119  Labyrinth of Desire: Women, Passion, and Roman...
# 84815   0002255103                     Our Lady of the Lost and Found
# 130669  0002000288                   Farley: The Life of Farley Mowat
# 130697  0002255243                                     The Ash Garden
# 140651  0002557290       From Stone Orchard: A collection of memories
# 187357  0002000202  Black Berry, Sweet Juice: On Being Black and W...
# 187410  0002006502  The Devil Is Clever: A Memoir of My Romanian M...
# ...

# %%
merged_df[merged_df['Year-Of-Publication'] == 1995]
# Out:
#               ISBN                                         Book-Title  \
# 43      0061099686                                           Downtown
# 62      0679865691                         Haveli (Laurel Leaf Books)
# 79      1569871213                Black Beauty (Illustrated Classics)
# 103     0553347594                      McDonald's: Behind the Arches
# 105     067976397X                       Corelli's Mandolin : A Novel
# ...            ...                                                ...
# 271153  1550544535           The Original Six: Old-Time Hockey Trivia
# 271230  9626345268  Moby Dick (Classic Literature with Classical M...
# 271252  1853914266  Really Useful: Student Book (Really Useful Ser...
# 271314  1563332442  Two Thousand Sixty-Nine: A Science Fiction Tri...
# 271336  3893312307  Die Vereinten Nationen: Zwischen Anspruch und ...
#
#                    Book-Author Year-Of-Publication  \
# 43         Anne Rivers Siddons                1995
# ...

# %%
merged_df.sort_values(by = 'User-ID')
# Out:
#             ISBN                                         Book-Title  \
# 9561  2845950470                                            Poesies
# 9562  0671447807                                     Tales of Power
# 9564  8466306773                                   Instinto de Inez
# 9580  0394711920                             Appointment in Samarra
# 9579  076790592X  Tuesdays with Morrie: An Old Man, a Young Man,...
# ...          ...                                                ...
# 9556  0671028820                         Celtika (The Merlin Codex)
# 9557  2070404722                             Prisonniers du paradis
# 9558  2070415066                                               Geai
# 9559  2841722171  AprÃ?Â¨s-demains : Cent vues imprenables sur l...
# 9560  2266091328                                Le cercle des loups
#
#                Book-Author Year-Of-Publication  \
# 9561        Arthur Rimbaud                   0
# 9562      Carlos Castaneda                1981
# ...
