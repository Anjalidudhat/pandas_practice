# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Healthcare-Diabetes.csv')

# %%
df.head()
# Out:
#    Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0   1            6      148             72             35        0  33.6
# 1   2            1       85             66             29        0  26.6
# 2   3            8      183             64              0        0  23.3
# 3   4            1       89             66             23       94  28.1
# 4   5            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2763  2764            2       75             64             24       55  29.7
# 2764  2765            8      179             72             42      130  32.7
# 2765  2766            6       85             78              0        0  31.2
# 2766  2767            0      129            110             46      130  67.1
# 2767  2768            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 2763                     0.370   33        0
# 2764                     0.719   36        1
# 2765                     0.382   42        0
# 2766                     0.319   26        1
# 2767                     0.547   25        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        2768 non-null   int64
#  1   Pregnancies               2768 non-null   int64
#  2   Glucose                   2768 non-null   int64
#  3   BloodPressure             2768 non-null   int64
#  4   SkinThickness             2768 non-null   int64
#  5   Insulin                   2768 non-null   int64
#  6   BMI                       2768 non-null   float64
#  7   DiabetesPedigreeFunction  2768 non-null   float64
#  8   Age                       2768 non-null   int64
#  9   Outcome                   2768 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 216.4 KB

# %%
df.describe()
# Out:
#                 Id  Pregnancies      Glucose  BloodPressure  SkinThickness  \
# count  2768.000000  2768.000000  2768.000000    2768.000000    2768.000000
# mean   1384.500000     3.742775   121.102601      69.134393      20.824422
# std     799.197097     3.323801    32.036508      19.231438      16.059596
# min       1.000000     0.000000     0.000000       0.000000       0.000000
# 25%     692.750000     1.000000    99.000000      62.000000       0.000000
# 50%    1384.500000     3.000000   117.000000      72.000000      23.000000
# 75%    2076.250000     6.000000   141.000000      80.000000      32.000000
# max    2768.000000    17.000000   199.000000     122.000000     110.000000
#
#            Insulin          BMI  DiabetesPedigreeFunction          Age  \
# count  2768.000000  2768.000000               2768.000000  2768.000000
# mean     80.127890    32.137392                  0.471193    33.132225
# std     112.301933     8.076127                  0.325669    11.777230
# ...

# %%
df.shape[0]
# Out:
# 2768

# %%
df.shape[1]
# Out:
# 10

# %%
df.isnull().sum()
# Out:
# Id                          0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['Pregnancies']
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
#        ..
# 2763    2
# 2764    8
# 2765    6
# 2766    0
# 2767    2
# Name: Pregnancies, Length: 2768, dtype: int64

# %%
df['BloodPressure']
# Out:
# 0        72
# 1        66
# 2        64
# 3        66
# 4        40
#        ...
# 2763     64
# 2764     72
# 2765     78
# 2766    110
# 2767     72
# Name: BloodPressure, Length: 2768, dtype: int64

# %%
df[['BloodPressure', 'BMI']]
# Out:
#       BloodPressure   BMI
# 0                72  33.6
# 1                66  26.6
# 2                64  23.3
# 3                66  28.1
# 4                40  43.1
# ...             ...   ...
# 2763             64  29.7
# 2764             72  32.7
# 2765             78  31.2
# 2766            110  67.1
# 2767             72  30.1
#
# [2768 rows x 2 columns]

# %%
df[df['Age'] == 50]
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        1            6      148             72             35        0  33.6
# 21      22            8       99             84              0        0  35.4
# 473    474            7      136             90              0        0  29.9
# 548    549            1      164             82             43       67  32.8
# 614    615           11      138             74             26      144  36.1
# 618    619            9      112             82             24        0  28.2
# 642    643            6      147             80              0        0  29.5
# 749    750            6      162             62              0        0  24.3
# 1241  1242            7      136             90              0        0  29.9
# 1316  1317            1      164             82             43       67  32.8
# 1382  1383           11      138             74             26      144  36.1
# ...

# %%
df[df['Age'] > 50]
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8        9            2      197             70             45      543  30.5
# 9       10            8      125             96              0        0   0.0
# 12      13           10      139             80              0        0  27.1
# 13      14            1      189             60             23      846  30.1
# 14      15            5      166             72             19      175  25.8
# ...    ...          ...      ...            ...            ...      ...   ...
# 2704  2705            4      146             92              0        0  31.2
# 2712  2713            5      132             80              0        0  26.8
# 2718  2719            0      105             84              0        0  27.9
# 2729  2730            3      128             78              0        0  21.1
# 2737  2738            5      147             78              0        0  33.7
#
# ...

# %%
df[df['BloodPressure'] > 70]
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        1            6      148             72             35        0  33.6
# 5        6            5      116             74              0        0  25.6
# 9       10            8      125             96              0        0   0.0
# 10      11            4      110             92              0        0  37.6
# 11      12           10      168             74              0        0  38.0
# ...    ...          ...      ...            ...            ...      ...   ...
# 2759  2760            6      102             82              0        0  30.8
# 2764  2765            8      179             72             42      130  32.7
# 2765  2766            6       85             78              0        0  31.2
# 2766  2767            0      129            110             46      130  67.1
# 2767  2768            2       81             72             15       76  30.1
#
# ...

# %%
df[df['Glucose'] > 150]
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2        3            8      183             64              0        0  23.3
# 8        9            2      197             70             45      543  30.5
# 11      12           10      168             74              0        0  38.0
# 13      14            1      189             60             23      846  30.1
# 14      15            5      166             72             19      175  25.8
# ...    ...          ...      ...            ...            ...      ...   ...
# 2743  2744            8      188             78              0        0  47.9
# 2744  2745            7      152             88             44        0  50.0
# 2748  2749           17      163             72             41      114  40.9
# 2749  2750            4      151             90             38        0  29.7
# 2764  2765            8      179             72             42      130  32.7
#
# ...

# %%
df[df['Glucose'] == 150]
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 54      55            7      150             66             42      342  34.7
# 304    305            3      150             76              0        0  21.0
# 603    604            7      150             78             29      126  35.2
# 822    823            7      150             66             42      342  34.7
# 1072  1073            3      150             76              0        0  21.0
# 1371  1372            7      150             78             29      126  35.2
# 1542  1543            3      150             76              0        0  21.0
# 1828  1829            7      150             78             29      126  35.2
# 1999  2000            3      150             76              0        0  21.0
# 2459  2460            7      150             78             29      126  35.2
# 2643  2644            7      150             66             42      342  34.7
#
# ...

# %%
df.loc[(df['Pregnancies'] == 7) & (df['Age'] == 37)]
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 41      42            7      133             84              0        0  40.2
# 222    223            7      119              0              0        0  25.2
# 282    283            7      133             88             15      155  32.4
# 555    556            7      124             70             33      215  25.5
# 809    810            7      133             84              0        0  40.2
# 990    991            7      119              0              0        0  25.2
# 1050  1051            7      133             88             15      155  32.4
# 1323  1324            7      124             70             33      215  25.5
# 1780  1781            7      124             70             33      215  25.5
# 2148  2149            7      119              0              0        0  25.2
# 2208  2209            7      133             88             15      155  32.4
# ...

# %%
df.loc[(df['BloodPressure'] == 84) & (df['SkinThickness'] == 33)]
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 209    210            7      184             84             33        0  35.5
# 415    416            3      173             84             33      474  35.7
# 745    746           12      100             84             33      105  30.0
# 977    978            7      184             84             33        0  35.5
# 1183  1184            3      173             84             33      474  35.7
# 1513  1514           12      100             84             33      105  30.0
# 1653  1654            3      173             84             33      474  35.7
# 1970  1971           12      100             84             33      105  30.0
# 2135  2136            7      184             84             33        0  35.5
# 2242  2243            3      173             84             33      474  35.7
# 2436  2437            3      173             84             33      474  35.7
# ...

# %%
df.iloc[50:81, 1:5]
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness
# 50            1      103             80             11
# 51            1      101             50             15
# 52            5       88             66             21
# 53            8      176             90             34
# 54            7      150             66             42
# 55            1       73             50             10
# 56            7      187             68             39
# 57            0      100             88             60
# 58            0      146             82              0
# 59            0      105             64             41
# 60            2       84              0              0
# 61            8      133             72              0
# 62            5       44             62              0
# 63            2      141             58             34
# 64            7      114             66              0
# 65            5       99             74             27
# ...
