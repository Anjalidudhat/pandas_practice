# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/us_baby_names.csv')

# %%
df.head()
# Out:
#    Year       Name Gender  Count
# 0  1880       Mary      F   7065
# 1  1880       Anna      F   2604
# 2  1880       Emma      F   2003
# 3  1880  Elizabeth      F   1939
# 4  1880     Minnie      F   1746

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957046 entries, 0 to 1957045
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Year    int64
#  1   Name    object
#  2   Gender  object
#  3   Count   int64
# dtypes: int64(2), object(2)
# memory usage: 59.7+ MB

# %%
df.describe()
# Out:
#                Year         Count
# count  1.957046e+06  1.957046e+06
# mean   1.975563e+03  1.796856e+02
# std    3.419121e+01  1.522804e+03
# min    1.880000e+03  5.000000e+00
# 25%    1.952000e+03  7.000000e+00
# 50%    1.985000e+03  1.200000e+01
# 75%    2.004000e+03  3.200000e+01
# max    2.018000e+03  9.968900e+04

# %%
df.nunique()
# Out:
# Year        139
# Name      98400
# Gender        2
# Count     13720
# dtype: int64

# %%
df ['Gender'] = df['Gender'].astype ('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957046 entries, 0 to 1957045
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Year    int64
#  1   Name    object
#  2   Gender  category
#  3   Count   int64
# dtypes: category(1), int64(2), object(1)
# memory usage: 46.7+ MB

# %%
names = df[df['Year'] == 2018].copy()
names
# Out:
#          Year      Name Gender  Count
# 1925013  2018      Emma      F  18688
# 1925014  2018    Olivia      F  17921
# 1925015  2018       Ava      F  14924
# 1925016  2018  Isabella      F  14464
# 1925017  2018    Sophia      F  13928
# ...       ...       ...    ...    ...
# 1957041  2018     Zylas      M      5
# 1957042  2018     Zyran      M      5
# 1957043  2018     Zyrie      M      5
# 1957044  2018     Zyron      M      5
# 1957045  2018     Zzyzx      M      5
#
# [32033 rows x 4 columns]

# %%
names[names ['Gender'] == "F"].nlargest(10, 'Count')
# Out:
#          Year       Name Gender  Count
# 1925013  2018       Emma      F  18688
# 1925014  2018     Olivia      F  17921
# 1925015  2018        Ava      F  14924
# 1925016  2018   Isabella      F  14464
# 1925017  2018     Sophia      F  13928
# 1925018  2018  Charlotte      F  12940
# 1925019  2018        Mia      F  12642
# 1925020  2018     Amelia      F  12301
# 1925021  2018     Harper      F  10582
# 1925022  2018     Evelyn      F  10376

# %%
def most_pop(year, gender, n):
  return df[(df ['Year'] == year) & (df['Gender'] == gender)].nlargest(n, 'Count')
most_pop(2018, 'M', 10)
# Out:
#          Year      Name Gender  Count
# 1943042  2018      Liam      M  19837
# 1943043  2018      Noah      M  18267
# 1943044  2018   William      M  14516
# 1943045  2018     James      M  13525
# 1943046  2018    Oliver      M  13389
# 1943047  2018  Benjamin      M  13381
# 1943048  2018    Elijah      M  12886
# 1943049  2018     Lucas      M  12585
# 1943050  2018     Mason      M  12435
# 1943051  2018     Logan      M  12352

# %%
most_pop(2018, 'F', 10)
# Out:
#          Year       Name Gender  Count
# 1925013  2018       Emma      F  18688
# 1925014  2018     Olivia      F  17921
# 1925015  2018        Ava      F  14924
# 1925016  2018   Isabella      F  14464
# 1925017  2018     Sophia      F  13928
# 1925018  2018  Charlotte      F  12940
# 1925019  2018        Mia      F  12642
# 1925020  2018     Amelia      F  12301
# 1925021  2018     Harper      F  10582
# 1925022  2018     Evelyn      F  10376

# %%
f_2018 = most_pop(2018, 'F', 20)
f_2018
# Out:
#          Year       Name Gender  Count
# 1925013  2018       Emma      F  18688
# 1925014  2018     Olivia      F  17921
# 1925015  2018        Ava      F  14924
# 1925016  2018   Isabella      F  14464
# 1925017  2018     Sophia      F  13928
# 1925018  2018  Charlotte      F  12940
# 1925019  2018        Mia      F  12642
# 1925020  2018     Amelia      F  12301
# 1925021  2018     Harper      F  10582
# 1925022  2018     Evelyn      F  10376
# 1925023  2018    Abigail      F   9796
# 1925024  2018      Emily      F   8656
# 1925025  2018  Elizabeth      F   8513
# 1925026  2018       Mila      F   8126
# 1925027  2018       Ella      F   8055
# 1925028  2018      Avery      F   8053
# 1925029  2018      Sofia      F   7621
# 1925030  2018     Camila      F   7473
# 1925031  2018       Aria      F   7394
# 1925032  2018   Scarlett      F   7182

# %%
f_1880 = most_pop(1880, 'F', 20)
f_1880
# Out:
#     Year       Name Gender  Count
# 0   1880       Mary      F   7065
# 1   1880       Anna      F   2604
# 2   1880       Emma      F   2003
# 3   1880  Elizabeth      F   1939
# 4   1880     Minnie      F   1746
# 5   1880   Margaret      F   1578
# 6   1880        Ida      F   1472
# 7   1880      Alice      F   1414
# 8   1880     Bertha      F   1320
# 9   1880      Sarah      F   1288
# 10  1880      Annie      F   1258
# 11  1880      Clara      F   1226
# 12  1880       Ella      F   1156
# 13  1880   Florence      F   1063
# 14  1880       Cora      F   1045
# 15  1880     Martha      F   1040
# 16  1880      Laura      F   1012
# 17  1880     Nellie      F    995
# 18  1880      Grace      F    982
# 19  1880     Carrie      F    949

# %%
f_2018[['Name', 'Count']].merge(f_1880[['Name', 'Count']], how = 'inner', on = 'Name')
# Out:
#         Name  Count_x  Count_y
# 0       Emma    18688     2003
# 1  Elizabeth     8513     1939
# 2       Ella     8055     1156

# %%
f = f_2018[['Name', 'Count']].merge(f_1880[['Name', 'Count']], how = 'inner', on = 'Name', suffixes = ('_2018', '_1880'))
f
# Out:
#         Name  Count_2018  Count_1880
# 0       Emma       18688        2003
# 1  Elizabeth        8513        1939
# 2       Ella        8055        1156

# %%
m_2018 = most_pop(2018, 'M', 20)
m_1880 = most_pop(1880, 'M', 20)
m_ever = m_2018[['Name', 'Count']].merge(m_1880[['Name', 'Count']], how = 'inner', on = 'Name', suffixes = ('_2018', '_1880'))
m_ever
# Out:
#       Name  Count_2018  Count_1880
# 0  William       14516        9532
# 1    James       13525        5927
# 2    Henry       10649        2444

# %%
df = pd.read_csv('/content/us_baby_names.csv')
df.head()
# Out:
#    Year       Name Gender  Count
# 0  1880       Mary      F   7065
# 1  1880       Anna      F   2604
# 2  1880       Emma      F   2003
# 3  1880  Elizabeth      F   1939
# 4  1880     Minnie      F   1746

# %%
df.groupby(['Name', 'Gender']) ['Count'].sum().reset_index(level = -1)
# Out:
#         Gender  Count
# Name
# Aaban        M    114
# Aabha        F     35
# Aabid        M     16
# Aabidah      F      5
# Aabir        M     10
# ...        ...    ...
# Zyvion       M      5
# Zyvon        M      7
# Zyyanna      F      6
# Zyyon        M      6
# Zzyzx        M     10
#
# [109173 rows x 2 columns]

# %%
agg = df.groupby(['Name', 'Gender']).agg(Total = ('Count', "sum"),
                                        No_Year = ('Count', 'count'),
                                        First_Year = ('Year', 'min'),
                                        Last_Year = ('Year', 'max'),
                                        Max_Count = ('Count', 'max'))
agg
# Out:
#                 Total  No_Year  First_Year  Last_Year  Max_Count
# Name    Gender
# Aaban   M         114       11        2007       2018         16
# Aabha   F          35        5        2011       2016          9
# Aabid   M          16        3        2003       2018          6
# Aabidah F           5        1        2018       2018          5
# Aabir   M          10        2        2016       2018          5
# ...               ...      ...         ...        ...        ...
# Zyvion  M           5        1        2009       2009          5
# Zyvon   M           7        1        2015       2015          7
# Zyyanna F           6        1        2010       2010          6
# Zyyon   M           6        1        2014       2014          6
# Zzyzx   M          10        2        2010       2018          5
#
# [109173 rows x 5 columns]

# %%
agg = df.groupby(['Name', 'Gender']).agg(Total = ('Count', "sum"),
                                        No_Year = ('Count', 'count'),
                                        First_Year = ('Year', 'min'),
                                        Last_Year = ('Year', 'max'),
                                        Max_Count = ('Count', 'max')).reset_index() # Reset the index to include 'Name' and 'Gender' as columns
agg[(agg['Name'] == 'Mary') & (agg['Gender'] == 'F')]
# Out:
#        Name Gender    Total  No_Year  First_Year  Last_Year  Max_Count
# 68679  Mary      F  4125675      139        1880       2018      73985

# %%
agg.groupby('Gender').apply(lambda x:x.nlargest(10,'Total'))
# Out:
#                     Name Gender    Total  No_Year  First_Year  Last_Year  \
# Gender
# F      68679        Mary      F  4125675      139        1880       2018
#        30706   Elizabeth      F  1638349      139        1880       2018
#        79184    Patricia      F  1572016      135        1884       2018
#        46567    Jennifer      F  1467207      101        1916       2018
#        62973       Linda      F  1452668      139        1880       2018
#        11699     Barbara      F  1434397      139        1880       2018
#        67371    Margaret      F  1248985      139        1880       2018
#        94540       Susan      F  1121703      139        1880       2018
#        28575     Dorothy      F  1107635      139        1880       2018
#        87546       Sarah      F  1077746      139        1880       2018
# M      43582       James      M  5164280      139        1880       2018
#        48388        John      M  5124817      139        1880       2018
#        84427      Robert      M  4820129      139        1880       2018
#        71023     Michael      M  4362731      139        1880       2018
#        104615    William      M  4117369      139        1880       2018
#        24204       David      M  3621322      139        1880       2018
#        49192      Joseph      M  2613304      139        1880       2018
#        83864     Richard      M  2565301      139        1880       2018
#        18299     Charles      M  2392779      139        1880       2018
#        98544      Thomas      M  2311849      139        1880       2018
#
#                Max_Count
# Gender
# F      68679       73985
#        30706       20744
#        79184       56442
#        46567       63603
#        62973       99689
#        11699       48792
#        67371       28467
#        94540       47402
#        28575       39999
#        87546       28484
# M      43582       94757
#        48388       88319
#        84427       91640
#        71023       92704
#        104615      66989
#        24204       86253
#        49192       32732
#        83864       58868
#        18299       40770
#        98544       48652

# %%
all_times = agg.groupby('Gender').apply(lambda x: x.nlargest(10, 'Total')).reset_index(drop = True)

all_times
# Out:
#          Name Gender    Total  No_Year  First_Year  Last_Year  Max_Count
# 0        Mary      F  4125675      139        1880       2018      73985
# 1   Elizabeth      F  1638349      139        1880       2018      20744
# 2    Patricia      F  1572016      135        1884       2018      56442
# 3    Jennifer      F  1467207      101        1916       2018      63603
# 4       Linda      F  1452668      139        1880       2018      99689
# 5     Barbara      F  1434397      139        1880       2018      48792
# 6    Margaret      F  1248985      139        1880       2018      28467
# 7       Susan      F  1121703      139        1880       2018      47402
# 8     Dorothy      F  1107635      139        1880       2018      39999
# 9       Sarah      F  1077746      139        1880       2018      28484
# 10      James      M  5164280      139        1880       2018      94757
# 11       John      M  5124817      139        1880       2018      88319
# 12     Robert      M  4820129      139        1880       2018      91640
# 13    Michael      M  4362731      139        1880       2018      92704
# 14    William      M  4117369      139        1880       2018      66989
# 15      David      M  3621322      139        1880       2018      86253
# 16     Joseph      M  2613304      139        1880       2018      32732
# 17    Richard      M  2565301      139        1880       2018      58868
# 18    Charles      M  2392779      139        1880       2018      40770
# 19     Thomas      M  2311849      139        1880       2018      48652

# %%
df
# Out:
#          Year       Name Gender  Count
# 0        1880       Mary      F   7065
# 1        1880       Anna      F   2604
# 2        1880       Emma      F   2003
# 3        1880  Elizabeth      F   1939
# 4        1880     Minnie      F   1746
# ...       ...        ...    ...    ...
# 1957041  2018      Zylas      M      5
# 1957042  2018      Zyran      M      5
# 1957043  2018      Zyrie      M      5
# 1957044  2018      Zyron      M      5
# 1957045  2018      Zzyzx      M      5
#
# [1957046 rows x 4 columns]

# %%
  df.groupby(['Year', 'Gender']) ['Count']. transform('sum')
# Out:
# 0            90994
# 1            90994
# 2            90994
# 3            90994
# 4            90994
#             ...
# 1957041    1800392
# 1957042    1800392
# 1957043    1800392
# 1957044    1800392
# 1957045    1800392
# Name: Count, Length: 1957046, dtype: int64

# %%
df['Popularity'] = df['Count'].div(df.groupby(['Year', 'Gender']) ['Count'].transform('sum')) * 1000000
df
# Out:
#          Year       Name Gender  Count    Popularity
# 0        1880       Mary      F   7065  77642.481922
# 1        1880       Anna      F   2604  28617.271468
# 2        1880       Emma      F   2003  22012.440381
# 3        1880  Elizabeth      F   1939  21309.097303
# 4        1880     Minnie      F   1746  19188.078335
# ...       ...        ...    ...    ...           ...
# 1957041  2018      Zylas      M      5      2.777173
# 1957042  2018      Zyran      M      5      2.777173
# 1957043  2018      Zyrie      M      5      2.777173
# 1957044  2018      Zyron      M      5      2.777173
# 1957045  2018      Zzyzx      M      5      2.777173
#
# [1957046 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957046 entries, 0 to 1957045
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Year        int64
#  1   Name        object
#  2   Gender      object
#  3   Count       int64
#  4   Popularity  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 74.7+ MB

# %%
df.groupby(['Year', 'Gender']) ['Count'].apply(lambda x: x.rank(ascending = False))
# Out:
# Year  Gender
# 1880  F       0              1.0
#               1              2.0
#               2              3.0
#               3              4.0
#               4              5.0
#                           ...
# 2018  M       1957041    13042.0
#               1957042    13042.0
#               1957043    13042.0
#               1957044    13042.0
#               1957045    13042.0
# Name: Count, Length: 1957046, dtype: float64

# %%
df["Rank"] = df.groupby(["Year", "Gender"])["Count"].rank(ascending=False, method='dense')
df
# Out:
#          Year       Name Gender  Count    Popularity   Rank
# 0        1880       Mary      F   7065  77642.481922    1.0
# 1        1880       Anna      F   2604  28617.271468    2.0
# 2        1880       Emma      F   2003  22012.440381    3.0
# 3        1880  Elizabeth      F   1939  21309.097303    4.0
# 4        1880     Minnie      F   1746  19188.078335    5.0
# ...       ...        ...    ...    ...           ...    ...
# 1957041  2018      Zylas      M      5      2.777173  912.0
# 1957042  2018      Zyran      M      5      2.777173  912.0
# 1957043  2018      Zyrie      M      5      2.777173  912.0
# 1957044  2018      Zyron      M      5      2.777173  912.0
# 1957045  2018      Zzyzx      M      5      2.777173  912.0
#
# [1957046 rows x 6 columns]

# %%
df[(df['Year'] == 2018) & (df['Gender'] == 'M')].head(50)
# Out:
#          Year         Name Gender  Count    Popularity  Rank
# 1943042  2018         Liam      M  19837  11018.156046   1.0
# 1943043  2018         Noah      M  18267  10146.123733   2.0
# 1943044  2018      William      M  14516   8062.688570   3.0
# 1943045  2018        James      M  13525   7512.252887   4.0
# 1943046  2018       Oliver      M  13389   7436.713782   5.0
# 1943047  2018     Benjamin      M  13381   7432.270306   6.0
# 1943048  2018       Elijah      M  12886   7157.330181   7.0
# 1943049  2018        Lucas      M  12585   6990.144369   8.0
# 1943050  2018        Mason      M  12435   6906.829179   9.0
# 1943051  2018        Logan      M  12352   6860.728108  10.0
# 1943052  2018    Alexander      M  11989   6659.105350  11.0
# 1943053  2018        Ethan      M  11854   6584.121680  12.0
# 1943054  2018        Jacob      M  11770   6537.465174  13.0
# 1943055  2018      Michael      M  11620   6454.149985  14.0
# 1943056  2018       Daniel      M  11173   6205.870721  15.0
# 1943057  2018        Henry      M  10649   5914.822994  16.0
# 1943058  2018      Jackson      M  10323   5733.751316  17.0
# 1943059  2018    Sebastian      M  10054   5584.339411  18.0
# 1943060  2018        Aiden      M   9979   5542.681816  19.0
# 1943061  2018      Matthew      M   9924   5512.132913  20.0
# 1943062  2018       Samuel      M   9734   5406.600340  21.0
# 1943063  2018        David      M   9697   5386.049260  22.0
# 1943064  2018       Joseph      M   9555   5307.177548  23.0
# 1943065  2018       Carter      M   9312   5172.206942  24.0
# 1943066  2018         Owen      M   9288   5158.876511  25.0
# 1943067  2018        Wyatt      M   9127   5069.451542  26.0
# 1943068  2018         John      M   9119   5065.008065  27.0
# 1943069  2018         Jack      M   8834   4906.709206  28.0
# 1943070  2018         Luke      M   8577   4763.962515  29.0
# 1943071  2018       Jayden      M   8553   4750.632085  30.0
# 1943072  2018        Dylan      M   8549   4748.410346  31.0
# 1943073  2018      Grayson      M   8538   4742.300566  32.0
# 1943074  2018         Levi      M   8440   4687.867975  33.0
# 1943075  2018        Isaac      M   8417   4675.092980  34.0
# 1943076  2018      Gabriel      M   8335   4629.547343  35.0
# 1943077  2018       Julian      M   8307   4613.995174  36.0
# 1943078  2018        Mateo      M   8169   4537.345200  37.0
# 1943079  2018      Anthony      M   8003   4445.143058  38.0
# 1943080  2018        Jaxon      M   7701   4277.401810  39.0
# 1943081  2018      Lincoln      M   7368   4092.442090  40.0
# 1943082  2018       Joshua      M   7364   4090.220352  41.0
# 1943083  2018  Christopher      M   7261   4033.010589  42.0
# 1943084  2018       Andrew      M   7234   4018.013855  43.0
# 1943085  2018     Theodore      M   7020   3899.150852  44.0
# 1943086  2018        Caleb      M   6929   3848.606304  45.0
# 1943087  2018         Ryan      M   6905   3835.275873  46.0
# 1943088  2018        Asher      M   6802   3778.066110  47.0
# 1943089  2018       Nathan      M   6790   3771.400895  48.0
# 1943090  2018       Thomas      M   6779   3765.291114  49.0
# 1943091  2018          Leo      M   6719   3731.965039  50.0

# %%
df[(df['Year'] == 2018) & (df['Gender'] == 'M')] ['Popularity'].sum()
# Out:
# 999999.9999999999

# %%
df.loc[(['Name'] == 'Mary') & (df['Gender'] == 'F'), 'Popularity'].shift()
# Out:
# Series([], Name: Popularity, dtype: float64)

# %%
df['pop_lag1'] = df.groupby(['Name', 'Gender'])['Popularity'].shift()
df
# Out:
#          Year       Name Gender  Count    Popularity   Rank  pop_lag1
# 0        1880       Mary      F   7065  77642.481922    1.0       NaN
# 1        1880       Anna      F   2604  28617.271468    2.0       NaN
# 2        1880       Emma      F   2003  22012.440381    3.0       NaN
# 3        1880  Elizabeth      F   1939  21309.097303    4.0       NaN
# 4        1880     Minnie      F   1746  19188.078335    5.0       NaN
# ...       ...        ...    ...    ...           ...    ...       ...
# 1957041  2018      Zylas      M      5      2.777173  912.0  3.798491
# 1957042  2018      Zyran      M      5      2.777173  912.0  3.138835
# 1957043  2018      Zyrie      M      5      2.777173  912.0  2.713208
# 1957044  2018      Zyron      M      5      2.777173  912.0  8.139624
# 1957045  2018      Zzyzx      M      5      2.777173  912.0  2.608955
#
# [1957046 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1957046 entries, 0 to 1957045
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Year        int64
#  1   Name        object
#  2   Gender      object
#  3   Count       int64
#  4   Popularity  float64
#  5   Rank        float64
#  6   pop_lag1    float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 104.5+ MB

# %%
df[df['Name'] == 'Ashanti']
# Out:
#          Year     Name Gender  Count  Popularity   Rank    pop_lag1
# 700697   1970  Ashanti      F     14    8.008489  778.0         NaN
# 708512   1970  Ashanti      M     14    7.530493  663.0         NaN
# 714597   1971  Ashanti      F     21   12.623576  755.0    8.008489
# 724746   1971  Ashanti      M      8    4.522444  669.0    7.530493
# 729787   1972  Ashanti      F     21   13.805626  741.0   12.623576
# ...       ...      ...    ...    ...         ...    ...         ...
# 1827752  2015  Ashanti      F    157   88.179806  798.0  103.234494
# 1857597  2015  Ashanti      M      5    2.615696  919.0    2.636333
# 1860841  2016  Ashanti      F    161   91.155535  809.0   88.179806
# 1893982  2017  Ashanti      F    140   81.436162  813.0   91.155535
# 1926397  2018  Ashanti      F    161   95.437891  788.0   81.436162
#
# [88 rows x 7 columns]
